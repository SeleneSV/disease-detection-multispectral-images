# %% [markdown]
# <div style="font-family:'Georgia','Times New Roman',Times,serif; width:80%; margin:20px auto; padding:10px 20px 20px 20px; background:#ffffff; border-left:20px solid #003366; box-shadow:0 5px 20px rgba(0,0,0,0.1); text-align:center; border-radius:8px;">
#
#   <div style="display:flex; align-items:center; justify-content:center; gap:20px; margin-bottom:15px; padding-bottom:1px; border-bottom:2px solid #eeeeee;">
#     <img src="assets/Logotipo_de_la_Universidad_Nacional_de_Colombia.svg.png" alt="Logo Universidad" style="max-width:80px; height:auto;">
#     <div style="font-size:1.1em; color:#003366; font-weight:bold; text-align:left;">Universidad Nacional de Colombia</div>
#   </div>
#
#   <h1 style="color:#003366; font-size:2.2em; margin:0.6em 0; font-weight:bold; line-height:1.2;">Detección de enfermedades en plantas de maíz y fríjol común con Inteligencia Artificial e imágenes multiespectrales</h1>
#   <h2 style="color:#444444; font-size:1.4em; margin-bottom:0.8em; font-weight:normal; font-style:italic;">Entrenamiento de red neuronal densa con datos de fríjol</h2>
#
#   <div style="margin-bottom:0em; font-size:1.1em; color:#222222;">
#     <p style="text-align:center; margin:0;"><strong>Autor:</strong> Selene Solano Vera</p>
#   </div>
#
#   <div style="margin:1.0em 0 1.0em 0; padding:0.8em 0; color:#666666; font-size:1em;">Medellín, Febrero de 2026</div>
#
#   <div style="height:0.1rem;"></div>
#
# </div>

# %% [markdown]
# # Utilidades y Configuración Inicial
#
# Esta sección incluye la importación de bibliotecas necesarias para el entrenamiento de una red neuronal profunda (DNN) con TensorFlow/Keras para la clasificación de deficiencia de fósforo en plantas de frijol.

# %%
# TensorFlow y Keras para construcción y entrenamiento de redes neuronales
import tensorflow as tf                     
from tensorflow.keras import Model          

# Manipulación de datos
import pandas as pd                         
import numpy as np                          
import pickle                               
import warnings
import joblib                             

# Visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn para preprocesamiento y evaluación
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import StandardScaler        
from sklearn.preprocessing import LabelEncoder          
from sklearn.metrics import accuracy_score              
from sklearn.metrics import precision_score             
from sklearn.metrics import f1_score                    
from sklearn.metrics import cohen_kappa_score           
from sklearn.metrics import confusion_matrix            
from sklearn.metrics import classification_report       
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Configuración del tema visual de seaborn
sns.set_theme(style="whitegrid", palette="viridis")

# Configuración de parámetros globales de matplotlib
plt.rcParams['figure.figsize'] = (12, 7)    # Tamaño de figura predeterminado en pulgadas
plt.rcParams['axes.titlesize'] = 18         # Tamaño de fuente para títulos
plt.rcParams['axes.labelsize'] = 14         # Tamaño de fuente para etiquetas de ejes

# Suprimir advertencias para mantener limpia la salida del notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Carga del Dataset
#
# Se carga el conjunto de datos de plantas de frijol con información multiespectral para el entrenamiento de la red neuronal profunda.

# %%
# Carga del dataset desde archivos CSV (train y test ya separados por build_dataset.ipynb)
df_train = pd.read_csv("datasets/dataset_frijol_fix_obj_train.csv")
df_test = pd.read_csv("datasets/dataset_frijol_fix_obj_test.csv")

print(f"Train shape: {df_train.shape}")
print(f"Test shape: {df_test.shape}")
print(f"Columnas: {df_train.columns.tolist()}")
print(f"\nDistribución de la clase objetivo (Train):")
print(df_train['tratamiento'].value_counts().sort_index())
print(f"\nDistribución de la clase objetivo (Test):")
print(df_test['tratamiento'].value_counts().sort_index())
# Out:
# Dataset shape: (3314450, 6)
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'tratamiento', 'banda']
#
# Distribución de la clase objetivo:
# tratamiento
# 1    970720
# 2    853790
# 3    669480
# 4    820460
# Name: count, dtype: int64
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3314450 entries, 0 to 3314449
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   pixel_relativo_x  float64
#  1   pixel_relativo_y  float64
#  2   intensidad        int64
#  3   genotipo          int64
#  4   tratamiento       int64
#  5   banda             int64
# dtypes: float64(2), int64(4)
# memory usage: 151.7 MB
# None

# %% [markdown]
# # 2. Preparación de los Datos
#
# Esta fase comprende la transformación de los datos crudos al formato requerido por la red neuronal.

# %% [markdown]
# ## 2.1. Codificación de la clase objetivo
#
# Las redes neuronales requieren que las etiquetas de clase sean enteros consecutivos comenzando desde 0. Se utiliza LabelEncoder para transformar los tratamientos [1, 2, 3, 4] a [0, 1, 2, 3].

# %%
# Definición de características predictoras (posición, genotipo y 10 bandas espectrales)
band_cols = ['int_444', 'int_475', 'int_531', 'int_560', 'int_650',
             'int_668', 'int_705', 'int_717', 'int_740', 'int_848']
feature_columns = ['pixel_relativo_x', 'pixel_relativo_y', 'genotipo'] + band_cols

X_train = df_train[feature_columns].values
X_test = df_test[feature_columns].values

y_train_raw = df_train['tratamiento'].values
y_test_raw = df_test['tratamiento'].values

print(f"Train features shape: {X_train.shape}")
print(f"Test features shape: {X_test.shape}")

# Codificación de etiquetas: convierte tratamientos [1,2,3,4] a [0,1,2,3]
label_encoder = LabelEncoder()
label_encoder.fit(y_train_raw)
y_train = label_encoder.transform(y_train_raw)
y_test = label_encoder.transform(y_test_raw)

print(f"Original labels: {np.unique(y_train_raw)}")
print(f"Encoded labels: {np.unique(y_train)}")
print(f"Label mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")
# Out:
# Features shape: (3314450, 5)
# Target shape: (3314450,)
# Original labels: [1 2 3 4]
# Encoded labels: [0 1 2 3]
# Label mapping: {np.int64(1): 0, np.int64(2): 1, np.int64(3): 2, np.int64(4): 3}

# %% [markdown]
# ## 2.2 División del dataset en entrenamiento y prueba
#
# El split ya fue realizado en `build_dataset.ipynb` de forma estratificada por objeto (70% train, 30% test). Los archivos `dataset_frijol_fix_obj_train.csv` y `dataset_frijol_fix_obj_test.csv` contienen los conjuntos ya separados, garantizando que ningún objeto aparezca en ambos conjuntos.

# %%
# División provista por build_dataset.ipynb (split estratificado por objeto)
# Los conjuntos ya están separados en los archivos CSV de entrada
print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Test set - Features: {X_test.shape}, Labels: {y_test.shape}")

print(f"\nTraining set class distribution:")
train_unique, train_counts = np.unique(y_train, return_counts=True)
for class_label, count in zip(train_unique, train_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_train)*100:.1f}%)")

print(f"\nTest set class distribution:")
test_unique, test_counts = np.unique(y_test, return_counts=True)
for class_label, count in zip(test_unique, test_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_test)*100:.1f}%)")
# Out:
# Training set - Features: (2651560, 5), Labels: (2651560,)
# Test set - Features: (662890, 5), Labels: (662890,)
#
# Training set class distribution:
#   Class 0: 776576 (29.3%)
#   Class 1: 683032 (25.8%)
#   Class 2: 535584 (20.2%)
#   Class 3: 656368 (24.8%)
#
# Test set class distribution:
#   Class 0: 194144 (29.3%)
#   Class 1: 170758 (25.8%)
#   Class 2: 133896 (20.2%)
#   Class 3: 164092 (24.8%)

# %% [markdown]
# ## 2.3. Estandarización de características

# %%
# Inicialización y aplicación del estandarizador
scaler = StandardScaler()

# Ajuste con datos de entrenamiento y transformación
X_train_scaled = scaler.fit_transform(X_train)
# Transformación del conjunto de prueba usando los mismos parámetros
X_test_scaled = scaler.transform(X_test)

# Conversión a tipos de datos compatibles con TensorFlow
X_train_scaled = X_train_scaled.astype(np.float32)
X_test_scaled = X_test_scaled.astype(np.float32)
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

print(f"\nData types after conversion:")
print(f"X_train: {X_train_scaled.dtype}, y_train: {y_train.dtype}")
print(f"X_test: {X_test_scaled.dtype}, y_test: {y_test.dtype}")
# Out:
# Data types after conversion:
# X_train: float32, y_train: int32
# X_test: float32, y_test: int32

# %% [markdown]
# ## 2.3 Convertir a formato dataset de TensorFlow

# %%
# Definición del tamaño de batch para el entrenamiento
BATCH_SIZE = 1000  # Número de muestras procesadas simultáneamente

# Creación del dataset de entrenamiento con optimizaciones
train_ds = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
train_ds = train_ds.shuffle(buffer_size=10000, seed=42)  # Mezcla con buffer para aleatoriedad
train_ds = train_ds.batch(BATCH_SIZE)                    # Agrupa en batches
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)           # Carga anticipada automática

# Creación del dataset de prueba (sin shuffling)
test_ds = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print(f"Training dataset created with batch size: {BATCH_SIZE}")
print(f"Test dataset created with batch size: {BATCH_SIZE}")

# Verificación de la estructura del dataset
for batch_features, batch_labels in train_ds.take(1):
    print(f"\nBatch verification:")
    print(f"Features batch shape: {batch_features.shape}")
    print(f"Labels batch shape: {batch_labels.shape}")
    print(f"Features dtype: {batch_features.dtype}")
    print(f"Labels dtype: {batch_labels.dtype}")
    break
# Out:
# Training dataset created with batch size: 1000
# Test dataset created with batch size: 1000
#
# Batch verification:
# Features batch shape: (1000, 5)
# Labels batch shape: (1000,)
# Features dtype: <dtype: 'float32'>
# Labels dtype: <dtype: 'int32'>

# %% [markdown]
# # 3. Construcción de la Arquitectura de Red Neuronal
#
# Se implementa una Red Neuronal Profunda (Deep Neural Network - DNN) utilizando la API funcional de Keras.

# %%
class InitialModel(Model):
  def __init__(self, input_shape=(13,), num_classes=4, **kwargs):
    super(InitialModel, self).__init__(**kwargs)
    self.input_shape_val = input_shape
    self.num_classes = num_classes
    
    # Capa de entrada
    self.input_layer = tf.keras.layers.InputLayer(input_shape=input_shape)
    
    # Primera capa oculta
    self.dense1 = tf.keras.layers.Dense(512, activation='relu')

    # Segunda capa oculta
    self.dense2 = tf.keras.layers.Dense(256, activation='relu')

    # Tecera capa oculta
    self.dense3 = tf.keras.layers.Dense(128, activation='relu')

     # Cuarta capa oculta
    self.dense4 = tf.keras.layers.Dense(128, activation='relu')

    # Quinta capa oculta
    self.dense5 = tf.keras.layers.Dense(64, activation='relu')
    
    # Capa de salida
    self.out = tf.keras.layers.Dense(num_classes, activation='softmax')

  def call(self, inputs, training=None):
    
    x = self.dense1(inputs)
    x = self.dense2(x)
    x = self.dense3(x)
    x = self.dense4(x)
    x = self.dense5(x)
    return self.out(x)

  def get_config(self):
    config = super(InitialModel, self).get_config()
    config.update({
        "input_shape": self.input_shape_val,
        "num_classes": self.num_classes,
    })
    return config

# Instanciar el modelo
model = InitialModel(input_shape=(13,), num_classes=4)
# Out:
# d:\1. Biblioteca Usuario\Documents\UNAL\MAESTRÍA\TESIS\disease-detection-multispectral-images\.venv\Lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
# Definición de la función de pérdida y optimizador
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()   # Para clasificación multiclase con etiquetas enteras
optimizer = tf.keras.optimizers.Adam()                          # Optimizador Adam con learning rate adaptativo

# %%
# Definición de métricas para monitorear el entrenamiento
train_loss = tf.keras.metrics.Mean(name='train_loss')                              # Pérdida promedio de entrenamiento
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy') # Exactitud de entrenamiento

test_loss = tf.keras.metrics.Mean(name='test_loss')                                # Pérdida promedio de validación
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')   # Exactitud de validación

# %%
# Implementación manual de callbacks para control del entrenamiento

best_val_loss = float('inf')  # Mejor pérdida de validación observada
best_weights = None           # Pesos del modelo con mejor rendimiento
patience_lr = 3               # Épocas sin mejora antes de reducir LR
patience_es = 4               # Épocas sin mejora antes de detener entrenamiento
lr_counter = 0                # Contador para reducción de LR
es_counter = 0                # Contador para early stopping
lr_factor = 0.2               # Factor de reducción del learning rate (nuevo_lr = lr × 0.2)
min_lr = 0.00001              # Learning rate mínimo permitido

print("Manual callbacks initialized:")
print(f"  LR reduction: patience={patience_lr}, factor={lr_factor}, min_lr={min_lr}")
print(f"  Early stopping: patience={patience_es}, restore_best_weights=True")
# Out:
# Manual callbacks initialized:
#   LR reduction: patience=3, factor=0.2, min_lr=1e-05
#   Early stopping: patience=4, restore_best_weights=True

# %% [markdown]
# # 4. Entrenamiento del Modelo
#
# Esta sección implementa el loop de entrenamiento personalizado con TensorFlow.

# %%
@tf.function  # Compilación a grafo estático para mayor eficiencia
def train_step(data, labels):
  """
  Ejecuta un paso de entrenamiento: forward pass, cálculo de pérdida y backpropagation.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  with tf.GradientTape() as tape:
    predictions = model(data, training=True)  # Forward pass con modo entrenamiento
    loss = loss_object(labels, predictions)   # Cálculo de pérdida
  gradients = tape.gradient(loss, model.trainable_variables)  # Backpropagation
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))  # Actualización de pesos

  train_loss(loss)                     # Actualización de métrica de pérdida
  train_accuracy(labels, predictions)  # Actualización de métrica de exactitud

# %%
@tf.function  # Compilación para optimización
def test_step(data, labels):
  """
  Ejecuta evaluación en conjunto de validación/prueba sin actualización de pesos.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  predictions = model(data, training=False)   # Forward pass sin dropout/regularización
  t_loss = loss_object(labels, predictions)   # Cálculo de pérdida

  test_loss(t_loss)                    # Actualización de métrica de pérdida
  test_accuracy(labels, predictions)   # Actualización de métrica de exactitud

# %%
EPOCHS = 100

train_batches = len(X_train_scaled) // BATCH_SIZE + (1 if len(X_train_scaled) % BATCH_SIZE != 0 else 0)
test_batches = len(X_test_scaled) // BATCH_SIZE + (1 if len(X_test_scaled) % BATCH_SIZE != 0 else 0)

print(f"Training for up to {EPOCHS} epochs (with early stopping)")
print(f"Training batches per epoch: {train_batches}")
print(f"Test batches per epoch: {test_batches}")

# Resetear métricasa antes del entrenamiento
train_loss.reset_state()
train_accuracy.reset_state()
test_loss.reset_state()
test_accuracy.reset_state()

for epoch in range(EPOCHS):
  print(f"\nEpoch {epoch+1}/{EPOCHS}")
  
  # Entrenamiento
  for batch_idx, (data, labels) in enumerate(train_ds):
    train_step(data, labels)

  # Prueba
  for test_data, test_labels in test_ds:
    test_step(test_data, test_labels)

  # Obtener métricas actuales
  current_train_loss = train_loss.result().numpy()
  current_train_acc = train_accuracy.result().numpy() * 100
  current_test_loss = test_loss.result().numpy()
  current_test_acc = test_accuracy.result().numpy() * 100
  current_lr = optimizer.learning_rate.numpy()

  # Resultados épocas
  template = 'Epoch {}, Loss: {:.4f}, Accuracy: {:.2f}%, Test Loss: {:.4f}, Test Accuracy: {:.2f}%, LR: {:.6f}'
  print(template.format(epoch+1,
                        current_train_loss,
                        current_train_acc,
                        current_test_loss,
                        current_test_acc,
                        current_lr))

  # Verificar si la pérdida en validación mejora
  if current_test_loss < best_val_loss:
    print(f"  ✓ Validation loss improved from {best_val_loss:.4f} to {current_test_loss:.4f}")
    best_val_loss = current_test_loss
    best_weights = model.get_weights()  # Salvar mejores pesos
    lr_counter = 0  # Resetear contador LR
    es_counter = 0  # Resetear contador early stopping
  else:
    lr_counter += 1
    es_counter += 1
    print(f"  ✗ Validation loss did not improve (best: {best_val_loss:.4f})")
    
    # Reducción del Learning rate
    if lr_counter >= patience_lr:
      old_lr = optimizer.learning_rate.numpy()
      new_lr = max(old_lr * lr_factor, min_lr)
      if new_lr != old_lr:
        optimizer.learning_rate.assign(new_lr)
        print(f"  → Reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
        lr_counter = 0  # Resetear contador LR
      else:
        print(f"  → Learning rate already at minimum ({min_lr:.6f})")
    
    # Lógica de Early stopping
    if es_counter >= patience_es:
      print(f"\n Early stopping triggered! No improvement for {patience_es} epochs.")
      print(f"  Restoring best weights from epoch {epoch+1-patience_es}")
      model.set_weights(best_weights)  # Restaurar lo pesos
      break

  # Resetear las métricas para la siguiente época
  train_loss.reset_state()
  train_accuracy.reset_state()
  test_loss.reset_state()
  test_accuracy.reset_state()

print("\nTraining completed!")
print(f"Best validation loss: {best_val_loss:.4f}")
# Out:
# Training for up to 100 epochs (with early stopping)
# Training batches per epoch: 2652
# Test batches per epoch: 663
#
# Epoch 1/100
# Epoch 1, Loss: 0.8806, Accuracy: 59.54%, Test Loss: 0.6582, Test Accuracy: 69.64%, LR: 0.001000
#   ✓ Validation loss improved from inf to 0.6582
#
# Epoch 2/100
# Epoch 2, Loss: 0.6003, Accuracy: 72.37%, Test Loss: 0.5826, Test Accuracy: 73.21%, LR: 0.001000
#   ✓ Validation loss improved from 0.6582 to 0.5826
#
# Epoch 3/100
# Epoch 3, Loss: 0.5569, Accuracy: 74.19%, Test Loss: 0.5432, Test Accuracy: 74.72%, LR: 0.001000
#   ✓ Validation loss improved from 0.5826 to 0.5432
#
# Epoch 4/100
# Epoch 4, Loss: 0.5369, Accuracy: 75.01%, Test Loss: 0.5336, Test Accuracy: 75.16%, LR: 0.001000
#   ✓ Validation loss improved from 0.5432 to 0.5336
#
# Epoch 5/100
# Epoch 5, Loss: 0.5234, Accuracy: 75.53%, Test Loss: 0.5188, Test Accuracy: 75.70%, LR: 0.001000
#   ✓ Validation loss improved from 0.5336 to 0.5188
#
# Epoch 6/100
# Epoch 6, Loss: 0.5131, Accuracy: 75.93%, Test Loss: 0.5024, Test Accuracy: 76.43%, LR: 0.001000
#   ✓ Validation loss improved from 0.5188 to 0.5024
#
# Epoch 7/100
# Epoch 7, Loss: 0.5052, Accuracy: 76.24%, Test Loss: 0.5050, Test Accuracy: 76.24%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5024)
#
# Epoch 8/100
# Epoch 8, Loss: 0.4982, Accuracy: 76.50%, Test Loss: 0.4990, Test Accuracy: 76.40%, LR: 0.001000
#   ✓ Validation loss improved from 0.5024 to 0.4990
#
# Epoch 9/100
# Epoch 9, Loss: 0.4926, Accuracy: 76.73%, Test Loss: 0.4951, Test Accuracy: 76.60%, LR: 0.001000
#   ✓ Validation loss improved from 0.4990 to 0.4951
#
# Epoch 10/100
# Epoch 10, Loss: 0.4876, Accuracy: 76.87%, Test Loss: 0.4849, Test Accuracy: 77.04%, LR: 0.001000
#   ✓ Validation loss improved from 0.4951 to 0.4849
#
# Epoch 11/100
# Epoch 11, Loss: 0.4829, Accuracy: 77.10%, Test Loss: 0.4804, Test Accuracy: 77.19%, LR: 0.001000
#   ✓ Validation loss improved from 0.4849 to 0.4804
#
# Epoch 12/100
# Epoch 12, Loss: 0.4787, Accuracy: 77.28%, Test Loss: 0.4818, Test Accuracy: 77.14%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4804)
#
# Epoch 13/100
# Epoch 13, Loss: 0.4750, Accuracy: 77.41%, Test Loss: 0.4780, Test Accuracy: 77.26%, LR: 0.001000
#   ✓ Validation loss improved from 0.4804 to 0.4780
#
# Epoch 14/100
# Epoch 14, Loss: 0.4720, Accuracy: 77.49%, Test Loss: 0.4684, Test Accuracy: 77.65%, LR: 0.001000
#   ✓ Validation loss improved from 0.4780 to 0.4684
#
# Epoch 15/100
# Epoch 15, Loss: 0.4684, Accuracy: 77.63%, Test Loss: 0.4759, Test Accuracy: 77.43%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4684)
#
# Epoch 16/100
# Epoch 16, Loss: 0.4658, Accuracy: 77.73%, Test Loss: 0.4676, Test Accuracy: 77.59%, LR: 0.001000
#   ✓ Validation loss improved from 0.4684 to 0.4676
#
# Epoch 17/100
# Epoch 17, Loss: 0.4631, Accuracy: 77.82%, Test Loss: 0.4629, Test Accuracy: 77.82%, LR: 0.001000
#   ✓ Validation loss improved from 0.4676 to 0.4629
#
# Epoch 18/100
# Epoch 18, Loss: 0.4602, Accuracy: 77.92%, Test Loss: 0.4658, Test Accuracy: 77.61%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4629)
#
# Epoch 19/100
# Epoch 19, Loss: 0.4584, Accuracy: 77.98%, Test Loss: 0.4563, Test Accuracy: 78.02%, LR: 0.001000
#   ✓ Validation loss improved from 0.4629 to 0.4563
#
# Epoch 20/100
# Epoch 20, Loss: 0.4564, Accuracy: 78.06%, Test Loss: 0.4612, Test Accuracy: 77.85%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4563)
#
# Epoch 21/100
# Epoch 21, Loss: 0.4549, Accuracy: 78.12%, Test Loss: 0.4551, Test Accuracy: 78.01%, LR: 0.001000
#   ✓ Validation loss improved from 0.4563 to 0.4551
#
# Epoch 22/100
# Epoch 22, Loss: 0.4527, Accuracy: 78.21%, Test Loss: 0.4562, Test Accuracy: 77.95%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4551)
#
# Epoch 23/100
# Epoch 23, Loss: 0.4510, Accuracy: 78.29%, Test Loss: 0.4531, Test Accuracy: 78.09%, LR: 0.001000
#   ✓ Validation loss improved from 0.4551 to 0.4531
#
# Epoch 24/100
# Epoch 24, Loss: 0.4488, Accuracy: 78.35%, Test Loss: 0.4477, Test Accuracy: 78.31%, LR: 0.001000
#   ✓ Validation loss improved from 0.4531 to 0.4477
#
# Epoch 25/100
# Epoch 25, Loss: 0.4472, Accuracy: 78.43%, Test Loss: 0.4499, Test Accuracy: 78.27%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4477)
#
# Epoch 26/100
# Epoch 26, Loss: 0.4459, Accuracy: 78.45%, Test Loss: 0.4501, Test Accuracy: 78.24%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4477)
#
# Epoch 27/100
# Epoch 27, Loss: 0.4447, Accuracy: 78.53%, Test Loss: 0.4555, Test Accuracy: 77.97%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.4477)
#   → Reducing learning rate from 0.001000 to 0.000200
#
# Epoch 28/100
# Epoch 28, Loss: 0.4109, Accuracy: 79.91%, Test Loss: 0.4161, Test Accuracy: 79.70%, LR: 0.000200
#   ✓ Validation loss improved from 0.4477 to 0.4161
#
# Epoch 29/100
# Epoch 29, Loss: 0.4079, Accuracy: 80.00%, Test Loss: 0.4134, Test Accuracy: 79.77%, LR: 0.000200
#   ✓ Validation loss improved from 0.4161 to 0.4134
#
# Epoch 30/100
# Epoch 30, Loss: 0.4063, Accuracy: 80.08%, Test Loss: 0.4141, Test Accuracy: 79.71%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4134)
#
# Epoch 31/100
# Epoch 31, Loss: 0.4052, Accuracy: 80.09%, Test Loss: 0.4140, Test Accuracy: 79.70%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4134)
#
# Epoch 32/100
# Epoch 32, Loss: 0.4041, Accuracy: 80.16%, Test Loss: 0.4128, Test Accuracy: 79.71%, LR: 0.000200
#   ✓ Validation loss improved from 0.4134 to 0.4128
#
# Epoch 33/100
# Epoch 33, Loss: 0.4035, Accuracy: 80.16%, Test Loss: 0.4129, Test Accuracy: 79.76%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4128)
#
# Epoch 34/100
# Epoch 34, Loss: 0.4027, Accuracy: 80.18%, Test Loss: 0.4106, Test Accuracy: 79.85%, LR: 0.000200
#   ✓ Validation loss improved from 0.4128 to 0.4106
#
# Epoch 35/100
# Epoch 35, Loss: 0.4021, Accuracy: 80.22%, Test Loss: 0.4099, Test Accuracy: 79.88%, LR: 0.000200
#   ✓ Validation loss improved from 0.4106 to 0.4099
#
# Epoch 36/100
# Epoch 36, Loss: 0.4015, Accuracy: 80.23%, Test Loss: 0.4098, Test Accuracy: 79.84%, LR: 0.000200
#   ✓ Validation loss improved from 0.4099 to 0.4098
#
# Epoch 37/100
# Epoch 37, Loss: 0.4008, Accuracy: 80.26%, Test Loss: 0.4086, Test Accuracy: 79.90%, LR: 0.000200
#   ✓ Validation loss improved from 0.4098 to 0.4086
#
# Epoch 38/100
# Epoch 38, Loss: 0.4004, Accuracy: 80.27%, Test Loss: 0.4083, Test Accuracy: 79.96%, LR: 0.000200
#   ✓ Validation loss improved from 0.4086 to 0.4083
#
# Epoch 39/100
# Epoch 39, Loss: 0.3999, Accuracy: 80.29%, Test Loss: 0.4082, Test Accuracy: 79.93%, LR: 0.000200
#   ✓ Validation loss improved from 0.4083 to 0.4082
#
# Epoch 40/100
# Epoch 40, Loss: 0.3994, Accuracy: 80.30%, Test Loss: 0.4080, Test Accuracy: 79.86%, LR: 0.000200
#   ✓ Validation loss improved from 0.4082 to 0.4080
#
# Epoch 41/100
# Epoch 41, Loss: 0.3990, Accuracy: 80.33%, Test Loss: 0.4083, Test Accuracy: 79.87%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4080)
#
# Epoch 42/100
# Epoch 42, Loss: 0.3986, Accuracy: 80.35%, Test Loss: 0.4086, Test Accuracy: 79.86%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4080)
#
# Epoch 43/100
# Epoch 43, Loss: 0.3981, Accuracy: 80.34%, Test Loss: 0.4085, Test Accuracy: 79.85%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.4080)
#   → Reducing learning rate from 0.000200 to 0.000040
#
# Epoch 44/100
# Epoch 44, Loss: 0.3901, Accuracy: 80.75%, Test Loss: 0.3989, Test Accuracy: 80.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.4080 to 0.3989
#
# Epoch 45/100
# Epoch 45, Loss: 0.3893, Accuracy: 80.78%, Test Loss: 0.3990, Test Accuracy: 80.28%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3989)
#
# Epoch 46/100
# Epoch 46, Loss: 0.3890, Accuracy: 80.79%, Test Loss: 0.3987, Test Accuracy: 80.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.3989 to 0.3987
#
# Epoch 47/100
# Epoch 47, Loss: 0.3888, Accuracy: 80.80%, Test Loss: 0.3985, Test Accuracy: 80.29%, LR: 0.000040
#   ✓ Validation loss improved from 0.3987 to 0.3985
#
# Epoch 48/100
# Epoch 48, Loss: 0.3886, Accuracy: 80.80%, Test Loss: 0.3984, Test Accuracy: 80.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.3985 to 0.3984
#
# Epoch 49/100
# Epoch 49, Loss: 0.3885, Accuracy: 80.81%, Test Loss: 0.3984, Test Accuracy: 80.28%, LR: 0.000040
#   ✓ Validation loss improved from 0.3984 to 0.3984
#
# Epoch 50/100
# Epoch 50, Loss: 0.3883, Accuracy: 80.81%, Test Loss: 0.3982, Test Accuracy: 80.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.3984 to 0.3982
#
# Epoch 51/100
# Epoch 51, Loss: 0.3882, Accuracy: 80.82%, Test Loss: 0.3982, Test Accuracy: 80.28%, LR: 0.000040
#   ✓ Validation loss improved from 0.3982 to 0.3982
#
# Epoch 52/100
# Epoch 52, Loss: 0.3880, Accuracy: 80.83%, Test Loss: 0.3981, Test Accuracy: 80.28%, LR: 0.000040
#   ✓ Validation loss improved from 0.3982 to 0.3981
#
# Epoch 53/100
# Epoch 53, Loss: 0.3879, Accuracy: 80.83%, Test Loss: 0.3980, Test Accuracy: 80.29%, LR: 0.000040
#   ✓ Validation loss improved from 0.3981 to 0.3980
#
# Epoch 54/100
# Epoch 54, Loss: 0.3877, Accuracy: 80.83%, Test Loss: 0.3979, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3980 to 0.3979
#
# Epoch 55/100
# Epoch 55, Loss: 0.3876, Accuracy: 80.84%, Test Loss: 0.3979, Test Accuracy: 80.30%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3979)
#
# Epoch 56/100
# Epoch 56, Loss: 0.3875, Accuracy: 80.84%, Test Loss: 0.3978, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3979 to 0.3978
#
# Epoch 57/100
# Epoch 57, Loss: 0.3873, Accuracy: 80.85%, Test Loss: 0.3977, Test Accuracy: 80.29%, LR: 0.000040
#   ✓ Validation loss improved from 0.3978 to 0.3977
#
# Epoch 58/100
# Epoch 58, Loss: 0.3872, Accuracy: 80.86%, Test Loss: 0.3980, Test Accuracy: 80.28%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3977)
#
# Epoch 59/100
# Epoch 59, Loss: 0.3871, Accuracy: 80.85%, Test Loss: 0.3976, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3977 to 0.3976
#
# Epoch 60/100
# Epoch 60, Loss: 0.3870, Accuracy: 80.86%, Test Loss: 0.3975, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3976 to 0.3975
#
# Epoch 61/100
# Epoch 61, Loss: 0.3869, Accuracy: 80.88%, Test Loss: 0.3974, Test Accuracy: 80.31%, LR: 0.000040
#   ✓ Validation loss improved from 0.3975 to 0.3974
#
# Epoch 62/100
# Epoch 62, Loss: 0.3868, Accuracy: 80.88%, Test Loss: 0.3973, Test Accuracy: 80.31%, LR: 0.000040
#   ✓ Validation loss improved from 0.3974 to 0.3973
#
# Epoch 63/100
# Epoch 63, Loss: 0.3867, Accuracy: 80.88%, Test Loss: 0.3972, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3973 to 0.3972
#
# Epoch 64/100
# Epoch 64, Loss: 0.3865, Accuracy: 80.88%, Test Loss: 0.3974, Test Accuracy: 80.31%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3972)
#
# Epoch 65/100
# Epoch 65, Loss: 0.3865, Accuracy: 80.88%, Test Loss: 0.3972, Test Accuracy: 80.30%, LR: 0.000040
#   ✓ Validation loss improved from 0.3972 to 0.3972
#
# Epoch 66/100
# Epoch 66, Loss: 0.3864, Accuracy: 80.89%, Test Loss: 0.3971, Test Accuracy: 80.33%, LR: 0.000040
#   ✓ Validation loss improved from 0.3972 to 0.3971
#
# Epoch 67/100
# Epoch 67, Loss: 0.3862, Accuracy: 80.90%, Test Loss: 0.3971, Test Accuracy: 80.30%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3971)
#
# Epoch 68/100
# Epoch 68, Loss: 0.3861, Accuracy: 80.90%, Test Loss: 0.3971, Test Accuracy: 80.31%, LR: 0.000040
#   ✓ Validation loss improved from 0.3971 to 0.3971
#
# Epoch 69/100
# Epoch 69, Loss: 0.3860, Accuracy: 80.91%, Test Loss: 0.3970, Test Accuracy: 80.31%, LR: 0.000040
#   ✓ Validation loss improved from 0.3971 to 0.3970
#
# Epoch 70/100
# Epoch 70, Loss: 0.3859, Accuracy: 80.91%, Test Loss: 0.3968, Test Accuracy: 80.33%, LR: 0.000040
#   ✓ Validation loss improved from 0.3970 to 0.3968
#
# Epoch 71/100
# Epoch 71, Loss: 0.3858, Accuracy: 80.91%, Test Loss: 0.3967, Test Accuracy: 80.34%, LR: 0.000040
#   ✓ Validation loss improved from 0.3968 to 0.3967
#
# Epoch 72/100
# Epoch 72, Loss: 0.3857, Accuracy: 80.92%, Test Loss: 0.3966, Test Accuracy: 80.34%, LR: 0.000040
#   ✓ Validation loss improved from 0.3967 to 0.3966
#
# Epoch 73/100
# Epoch 73, Loss: 0.3856, Accuracy: 80.92%, Test Loss: 0.3968, Test Accuracy: 80.32%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3966)
#
# Epoch 74/100
# Epoch 74, Loss: 0.3855, Accuracy: 80.93%, Test Loss: 0.3966, Test Accuracy: 80.33%, LR: 0.000040
#   ✓ Validation loss improved from 0.3966 to 0.3966
#
# Epoch 75/100
# Epoch 75, Loss: 0.3854, Accuracy: 80.93%, Test Loss: 0.3965, Test Accuracy: 80.32%, LR: 0.000040
#   ✓ Validation loss improved from 0.3966 to 0.3965
#
# Epoch 76/100
# Epoch 76, Loss: 0.3853, Accuracy: 80.93%, Test Loss: 0.3964, Test Accuracy: 80.35%, LR: 0.000040
#   ✓ Validation loss improved from 0.3965 to 0.3964
#
# Epoch 77/100
# Epoch 77, Loss: 0.3853, Accuracy: 80.94%, Test Loss: 0.3966, Test Accuracy: 80.33%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3964)
#
# Epoch 78/100
# Epoch 78, Loss: 0.3852, Accuracy: 80.94%, Test Loss: 0.3965, Test Accuracy: 80.33%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3964)
#
# Epoch 79/100
# Epoch 79, Loss: 0.3851, Accuracy: 80.95%, Test Loss: 0.3963, Test Accuracy: 80.34%, LR: 0.000040
#   ✓ Validation loss improved from 0.3964 to 0.3963
#
# Epoch 80/100
# Epoch 80, Loss: 0.3850, Accuracy: 80.94%, Test Loss: 0.3964, Test Accuracy: 80.34%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3963)
#
# Epoch 81/100
# Epoch 81, Loss: 0.3849, Accuracy: 80.95%, Test Loss: 0.3961, Test Accuracy: 80.34%, LR: 0.000040
#   ✓ Validation loss improved from 0.3963 to 0.3961
#
# Epoch 82/100
# Epoch 82, Loss: 0.3848, Accuracy: 80.94%, Test Loss: 0.3963, Test Accuracy: 80.33%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3961)
#
# Epoch 83/100
# Epoch 83, Loss: 0.3847, Accuracy: 80.96%, Test Loss: 0.3960, Test Accuracy: 80.35%, LR: 0.000040
#   ✓ Validation loss improved from 0.3961 to 0.3960
#
# Epoch 84/100
# Epoch 84, Loss: 0.3846, Accuracy: 80.97%, Test Loss: 0.3961, Test Accuracy: 80.35%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3960)
#
# Epoch 85/100
# Epoch 85, Loss: 0.3845, Accuracy: 80.96%, Test Loss: 0.3959, Test Accuracy: 80.33%, LR: 0.000040
#   ✓ Validation loss improved from 0.3960 to 0.3959
#
# Epoch 86/100
# Epoch 86, Loss: 0.3845, Accuracy: 80.97%, Test Loss: 0.3960, Test Accuracy: 80.35%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3959)
#
# Epoch 87/100
# Epoch 87, Loss: 0.3844, Accuracy: 80.98%, Test Loss: 0.3960, Test Accuracy: 80.34%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3959)
#
# Epoch 88/100
# Epoch 88, Loss: 0.3843, Accuracy: 80.97%, Test Loss: 0.3957, Test Accuracy: 80.36%, LR: 0.000040
#   ✓ Validation loss improved from 0.3959 to 0.3957
#
# Epoch 89/100
# Epoch 89, Loss: 0.3842, Accuracy: 80.97%, Test Loss: 0.3957, Test Accuracy: 80.37%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3957)
#
# Epoch 90/100
# Epoch 90, Loss: 0.3841, Accuracy: 80.99%, Test Loss: 0.3956, Test Accuracy: 80.36%, LR: 0.000040
#   ✓ Validation loss improved from 0.3957 to 0.3956
#
# Epoch 91/100
# Epoch 91, Loss: 0.3840, Accuracy: 80.99%, Test Loss: 0.3956, Test Accuracy: 80.37%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3956)
#
# Epoch 92/100
# Epoch 92, Loss: 0.3840, Accuracy: 80.99%, Test Loss: 0.3955, Test Accuracy: 80.36%, LR: 0.000040
#   ✓ Validation loss improved from 0.3956 to 0.3955
#
# Epoch 93/100
# Epoch 93, Loss: 0.3839, Accuracy: 80.98%, Test Loss: 0.3956, Test Accuracy: 80.35%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3955)
#
# Epoch 94/100
# Epoch 94, Loss: 0.3838, Accuracy: 80.99%, Test Loss: 0.3954, Test Accuracy: 80.37%, LR: 0.000040
#   ✓ Validation loss improved from 0.3955 to 0.3954
#
# Epoch 95/100
# Epoch 95, Loss: 0.3837, Accuracy: 80.99%, Test Loss: 0.3953, Test Accuracy: 80.39%, LR: 0.000040
#   ✓ Validation loss improved from 0.3954 to 0.3953
#
# Epoch 96/100
# Epoch 96, Loss: 0.3837, Accuracy: 80.99%, Test Loss: 0.3954, Test Accuracy: 80.36%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3953)
#
# Epoch 97/100
# Epoch 97, Loss: 0.3836, Accuracy: 81.01%, Test Loss: 0.3955, Test Accuracy: 80.38%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3953)
#
# Epoch 98/100
# Epoch 98, Loss: 0.3835, Accuracy: 81.00%, Test Loss: 0.3952, Test Accuracy: 80.38%, LR: 0.000040
#   ✓ Validation loss improved from 0.3953 to 0.3952
#
# Epoch 99/100
# Epoch 99, Loss: 0.3834, Accuracy: 81.01%, Test Loss: 0.3953, Test Accuracy: 80.39%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.3952)
#
# Epoch 100/100
# Epoch 100, Loss: 0.3833, Accuracy: 81.02%, Test Loss: 0.3951, Test Accuracy: 80.37%, LR: 0.000040
#   ✓ Validation loss improved from 0.3952 to 0.3951
#
# Training completed!
# Best validation loss: 0.3951

# %% [markdown]
# ## 4.1. Persistencia del modelo entrenado
#
# Se guarda el modelo en formato Keras (.keras) junto con los objetos de preprocesamiento necesarios para realizar predicciones futuras.

# %%
# Guardar el modelo entrenado en formato Keras nativo
model.save("models/frijol_model.keras")
print("Model saved successfully as 'frijol_model.keras'")

# Guardar objetos de preprocesamiento (scaler, encoder) para uso en producción
with open('preprocessing_objects_frijol.pkl', 'wb') as f:
    pickle.dump({
        'scaler': scaler,                    # Estandarizador ajustado
        'label_encoder': label_encoder,      # Codificador de etiquetas
        'feature_columns': feature_columns   # Lista de características esperadas
    }, f)

print("Preprocessing objects saved as 'preprocessing_objects_frijol.pkl'")
# Out:
# Model saved successfully as 'frijol_model.keras'
# Preprocessing objects saved as 'preprocessing_objects.pkl'

# %% [markdown]
# # 5. Evaluación del Modelo
#
# Esta sección carga el modelo entrenado y evalúa su rendimiento mediante:
# - **Generación de predicciones**: En conjuntos de entrenamiento y prueba
# - **Métricas de clasificación**: Accuracy, Precision, F1-Score, Kappa
# - **Matrices de confusión**: Visualización de aciertos y errores por clase
# - **Análisis de curvas de aprendizaje**: Evolución de pérdida y exactitud durante entrenamiento

# %%
# Carga del modelo entrenado desde archivo
trained_model = tf.keras.models.load_model('models/frijol/frijol_model_dnn.keras', custom_objects={'InitialModel': InitialModel})

# %%
# Generación de predicciones en el conjunto de prueba
print("Realizando predicciones en Test...")
y_pred_probs = trained_model.predict(X_test_scaled)  # Probabilidades para cada clase
y_pred = np.argmax(y_pred_probs, axis=1)             

# Generación de predicciones en el conjunto de entrenamiento
print("Realizando predicciones en Train...")
y_train_pred_probs = trained_model.predict(X_train_scaled)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)
# Out:
# Realizando predicciones en Test...
# 20716/20716 ━━━━━━━━━━━━━━━━━━━━ 15s 736us/step
# Realizando predicciones en Train...
# 82862/82862 ━━━━━━━━━━━━━━━━━━━━ 65s 780us/step

# %% [markdown]
# ## 5.1. Guardar predicciones

# %%
# Guardar predicciones del conjunto de prueba
joblib.dump(y_pred, "results/predictions/frijol/test/predicciones_dnn_test.pkl")
print("✓ Predicciones de prueba guardadas en: results/predictions/frijol/test/predicciones_dnn_test.pkl")

# Guardar predicciones del conjunto de entrenamiento
joblib.dump(y_train_pred, "results/predictions/frijol/train/predicciones_dnn_train.pkl")
print("✓ Predicciones de entrenamiento guardadas en: results/predictions/frijol/train/predicciones_dnn_train.pkl")

# Guardar probabilidades predichas
joblib.dump(y_pred_probs, "results/predictions/frijol/test/predicciones_dnn_test_probs.pkl")
joblib.dump(y_train_pred_probs, "results/predictions/frijol/train/predicciones_dnn_train_probs.pkl")
print("✓ Probabilidades de predicción guardadas exitosamente")

# %% [markdown]
# # 6. Resultados

# %%
# Cálculo de métricas para el conjunto de prueba (Test)
accuracy = accuracy_score(y_test, y_pred)                        # Exactitud: proporción de predicciones correctas
precision = precision_score(y_test, y_pred, average='weighted')  # Precisión ponderada por clase
f1 = f1_score(y_test, y_pred, average='weighted')                # F1-Score: media armónica de precisión y recall
kappa = cohen_kappa_score(y_test, y_pred)                        # Kappa de Cohen: acuerdo ajustado por azar

# Cálculo de métricas para el conjunto de entrenamiento (Train)
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, average='weighted')
train_f1 = f1_score(y_train, y_train_pred, average='weighted')
train_kappa = cohen_kappa_score(y_train, y_train_pred)

# Presentación comparativa de métricas
print("-" * 65)
print(f"{'Métrica':<20} | {'Train':<20} | {'Test':<20}")
print("-" * 65)
print(f"{'Accuracy':<20} | {train_accuracy:<20.4f} | {accuracy:<20.4f}")
print(f"{'Precision':<20} | {train_precision:<20.4f} | {precision:<20.4f}")
print(f"{'F1-Score':<20} | {train_f1:<20.4f} | {f1:<20.4f}")
print(f"{'Kappa Score':<20} | {train_kappa:<20.4f} | {kappa:<20.4f}")
print("-" * 65)
# Out:
# -----------------------------------------------------------------
# Métrica              | Train                | Test
# -----------------------------------------------------------------
# Accuracy             | 0.8107               | 0.8037
# Precision            | 0.8110               | 0.8040
# F1-Score             | 0.8108               | 0.8038
# Kappa Score          | 0.7462               | 0.7369
# -----------------------------------------------------------------

# %%
# Obtención de nombres de clases para los reportes
target_names = label_encoder.classes_.astype(str)

# Reporte de clasificación para conjunto de prueba
print("\nReporte de Clasificación (Test):")
print(classification_report(y_test, y_pred, target_names=target_names))

# Reporte de clasificación para conjunto de entrenamiento
print("\nReporte de Clasificación (Train):")
print(classification_report(y_train, y_train_pred, target_names=target_names))
# Out:
# Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#            1       0.80      0.81      0.81    194144
#            2       0.82      0.82      0.82    170758
#            3       0.76      0.78      0.77    133896
#            4       0.83      0.81      0.82    164092
#
#     accuracy                           0.80    662890
#    macro avg       0.80      0.80      0.80    662890
# weighted avg       0.80      0.80      0.80    662890
#
#
# Reporte de Clasificación (Train):
#               precision    recall  f1-score   support
#
#            1       0.81      0.82      0.81    776576
#            2       0.82      0.82      0.82    683032
#            3       0.77      0.79      0.78    535584
#            4       0.83      0.81      0.82    656368
#
#     accuracy                           0.81   2651560
#    macro avg       0.81      0.81      0.81   2651560
# weighted avg       0.81      0.81      0.81   2651560

# %%
# Visualización comparativa de matrices de confusión
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']

# Matriz de confusión para conjunto de entrenamiento
cm_train = confusion_matrix(y_train, y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=tratamiento_labels)
disp_train.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Matriz de Confusión DNN - Entrenamiento', fontsize=14)
axes[0].set_xlabel('Etiqueta predicha', fontsize=12)
axes[0].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[0].grid(False)

# Matriz de confusión para conjunto de prueba
cm_test = confusion_matrix(y_test, y_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=tratamiento_labels)
disp_test.plot(ax=axes[1], cmap='Blues', colorbar=False)
axes[1].set_title('Matriz de Confusión DNN - Testing', fontsize=14)
axes[1].set_xlabel('Etiqueta predicha', fontsize=12)
axes[1].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
# Carga del historial de entrenamiento desde archivo CSV
history_data = pd.read_csv("results/training_history_frijol.csv")

# Extracción de épocas para el eje X
epochs = history_data['epoch']

# Creación de visualización de métricas de entrenamiento
plt.figure(figsize=(15, 6))

# Gráfico de evolución de la pérdida (Loss)
plt.subplot(1, 2, 1)
plt.plot(epochs, history_data['loss'], label='Pérdida entrenamiento', linewidth=2, color='#1f77b4')
plt.plot(epochs, history_data['val_loss'], label='Pérdida validación', linewidth=2, color='#ff7f0e')
plt.title('Pérdidas en entrenamiento y validación', fontsize=14, pad=15)
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True, alpha=0.3)

# Gráfico de evolución de la exactitud (Accuracy)
plt.subplot(1, 2, 2)
plt.plot(epochs, history_data['accuracy'], label='Accuracy entrenamiento', linewidth=2, color='#1f77b4')
plt.plot(epochs, history_data['val_accuracy'], label='Accuracy validación', linewidth=2, color='#ff7f0e')
plt.title('Accuracy de entrenamiento y validación', fontsize=14, pad=15)
plt.xlabel('Épocas')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
