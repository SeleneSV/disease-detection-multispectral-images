# %% [markdown]
# <div style="font-family:'Georgia','Times New Roman',Times,serif; width:80%; margin:20px auto; padding:10px 20px 20px 20px; background:#ffffff; border-left:20px solid #003366; box-shadow:0 5px 20px rgba(0,0,0,0.1); text-align:center; border-radius:8px;">
#
#   <div style="display:flex; align-items:center; justify-content:center; gap:20px; margin-bottom:15px; padding-bottom:1px; border-bottom:2px solid #eeeeee;">
#     <img src="assets/Logotipo_de_la_Universidad_Nacional_de_Colombia.svg.png" alt="Logo Universidad" style="max-width:80px; height:auto;">
#     <div style="font-size:1.1em; color:#003366; font-weight:bold; text-align:left;">Universidad Nacional de Colombia</div>
#   </div>
#
#   <h1 style="color:#003366; font-size:2.2em; margin:0.6em 0; font-weight:bold; line-height:1.2;">Detección de enfermedades en plantas de maíz y fríjol común con Inteligencia Artificial e imágenes multiespectrales</h1>
#   <h2 style="color:#444444; font-size:1.4em; margin-bottom:0.8em; font-weight:normal; font-style:italic;">Entrenamiento de red neuronal densa con datos de fríjol</h2>
#
#   <div style="margin-bottom:0em; font-size:1.1em; color:#222222;">
#     <p style="text-align:center; margin:0;"><strong>Autor:</strong> Selene Solano Vera</p>
#   </div>
#
#   <div style="margin:1.0em 0 1.0em 0; padding:0.8em 0; color:#666666; font-size:1em;">Medellín, Febrero de 2026</div>
#
#   <div style="height:0.1rem;"></div>
#
# </div>

# %% [markdown]
# # Utilidades y Configuración Inicial
#
# Esta sección incluye la importación de bibliotecas necesarias para el entrenamiento de una red neuronal profunda (DNN) con TensorFlow/Keras para la clasificación de deficiencia de fósforo en plantas de frijol.

# %%
# TensorFlow y Keras para construcción y entrenamiento de redes neuronales
import tensorflow as tf                     
from tensorflow.keras import Model          

# Manipulación de datos
import pandas as pd                         
import numpy as np                          
import pickle                               
import warnings
import joblib                             

# Visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn para preprocesamiento y evaluación
from sklearn.preprocessing import StandardScaler        
from sklearn.preprocessing import LabelEncoder          
from sklearn.metrics import accuracy_score              
from sklearn.metrics import precision_score             
from sklearn.metrics import f1_score                    
from sklearn.metrics import cohen_kappa_score           
from sklearn.metrics import confusion_matrix            
from sklearn.metrics import classification_report       
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Configuración del tema visual de seaborn
sns.set_theme(style="whitegrid", palette="viridis")

# Configuración de parámetros globales de matplotlib
plt.rcParams['figure.figsize'] = (12, 7)    # Tamaño de figura predeterminado en pulgadas
plt.rcParams['axes.titlesize'] = 18         # Tamaño de fuente para títulos
plt.rcParams['axes.labelsize'] = 14         # Tamaño de fuente para etiquetas de ejes

# Suprimir advertencias para mantener limpia la salida del notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Carga del Dataset
#
# Se cargan los conjuntos de entrenamiento y prueba de plantas de fríjol generados en `build_dataset_v5.ipynb`. El dataset v5 maneja las **10 bandas espectrales como columnas independientes** y provee la separación train/test por objeto con estratificación por tratamiento.

# %%
# Carga de los conjuntos de entrenamiento y prueba desde archivos CSV (v5)
data_train = pd.read_csv("datasets/dataset_frijol_fix_obj_train_v5.csv")
data_test  = pd.read_csv("datasets/dataset_frijol_fix_obj_test_v5.csv")

# Verificación de la estructura y dimensiones
print(f"Train shape: {data_train.shape}")
print(f"Test shape:  {data_test.shape}")
print(f"\nColumnas: {data_train.columns.tolist()}")
print(f"\nDistribución de la clase objetivo (train):")
print(data_train['tratamiento'].value_counts().sort_index())
print(f"\nDistribución de la clase objetivo (test):")
print(data_test['tratamiento'].value_counts().sort_index())
# Out:
# Train shape: (231400, 36)
# Test shape:  (98308, 36)
#
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'genotipo', 'tratamiento', 'object_id', 'split', 'int_444', 'mean_444', 'std_444', 'int_475', 'mean_475', 'std_475', 'int_531', 'mean_531', 'std_531', 'int_560', 'mean_560', 'std_560', 'int_650', 'mean_650', 'std_650', 'int_668', 'mean_668', 'std_668', 'int_705', 'mean_705', 'std_705', 'int_717', 'mean_717', 'std_717', 'int_740', 'mean_740', 'std_740', 'int_848', 'mean_848', 'std_848']
#
# Distribución de la clase objetivo (train):
# tratamiento
# 1    68623
# 2    59593
# 3    45736
# 4    57448
# Name: count, dtype: int64
#
# Distribución de la clase objetivo (test):
# tratamiento
# 1    28070
# 2    25360
# 3    20754
# 4    24124
# Name: count, dtype: int64

# %% [markdown]
# # 2. Preparación de los Datos
#
# Esta fase comprende la transformación de los datos crudos al formato requerido por la red neuronal.

# %% [markdown]
# ## 2.1. Codificación de la clase objetivo
#
# Las redes neuronales requieren que las etiquetas de clase sean enteros consecutivos comenzando desde 0. Se utiliza `LabelEncoder` para transformar los tratamientos [1, 2, 3, 4] a [0, 1, 2, 3]. Las **10 bandas espectrales** (`int_444` … `int_848`) se usan como características de entrada.

# %%
# Definición de características predictoras: 10 bandas espectrales (intensidad + desviación estándar vecinal)
# Se excluyen las columnas mean_* por su alta correlación con int_* (r ≈ 0.90)
feature_columns = [
    'int_444', 'int_475', 'int_531', 'int_560', 'int_650',
    'int_668', 'int_705', 'int_717', 'int_740', 'int_848',
    'std_444', 'std_475', 'std_531', 'std_560', 'std_650',
    'std_668', 'std_705', 'std_717', 'std_740', 'std_848'
]

X_train = data_train[feature_columns].values   # Matriz de características (entrenamiento)
X_test  = data_test[feature_columns].values    # Matriz de características (prueba)

y_train_raw = data_train['tratamiento'].values  # Etiquetas de entrenamiento
y_test_raw  = data_test['tratamiento'].values   # Etiquetas de prueba

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape:  {X_test.shape}")
print(f"Número de features: {len(feature_columns)}")

# Codificación de etiquetas: convierte tratamientos [1,2,3,4] a [0,1,2,3]
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train_raw)
y_test  = label_encoder.transform(y_test_raw)

print(f"Original labels: {np.unique(y_train_raw)}")
print(f"Encoded labels: {np.unique(y_train)}")
print(f"Label mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")
# Out:
# X_train shape: (231400, 20)
# X_test shape:  (98308, 20)
# Número de features: 20
# Original labels: [1 2 3 4]
# Encoded labels: [0 1 2 3]
# Label mapping: {np.int64(1): 0, np.int64(2): 1, np.int64(3): 2, np.int64(4): 3}

# %% [markdown]
# ## 2.2 División del dataset en entrenamiento y prueba
#
# El dataset v5 ya provee la separación train/test por objeto con estratificación por tratamiento, generada en `build_dataset_v5.ipynb`. No se requiere `train_test_split`.

# %%
# El dataset v5 ya incluye la división train/test por objeto (generada en build_dataset_v5.ipynb)
print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Test set     - Features: {X_test.shape}, Labels: {y_test.shape}")

# Verificación de distribución de clases en los conjuntos
print(f"\nTraining set class distribution:")
train_unique, train_counts = np.unique(y_train, return_counts=True)
for class_label, count in zip(train_unique, train_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_train)*100:.1f}%)")

print(f"\nTest set class distribution:")
test_unique, test_counts = np.unique(y_test, return_counts=True)
for class_label, count in zip(test_unique, test_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_test)*100:.1f}%)")
# Out:
# Training set - Features: (231400, 20), Labels: (231400,)
# Test set     - Features: (98308, 20), Labels: (98308,)
#
# Training set class distribution:
#   Class 0: 68623 (29.7%)
#   Class 1: 59593 (25.8%)
#   Class 2: 45736 (19.8%)
#   Class 3: 57448 (24.8%)
#
# Test set class distribution:
#   Class 0: 28070 (28.6%)
#   Class 1: 25360 (25.8%)
#   Class 2: 20754 (21.1%)
#   Class 3: 24124 (24.5%)

# %% [markdown]
# ## 2.3. Estandarización de características

# %%
# Inicialización y aplicación del estandarizador
scaler = StandardScaler()

# Ajuste con datos de entrenamiento y transformación
X_train_scaled = scaler.fit_transform(X_train)
# Transformación del conjunto de prueba usando los mismos parámetros
X_test_scaled = scaler.transform(X_test)

# Conversión a tipos de datos compatibles con TensorFlow
X_train_scaled = X_train_scaled.astype(np.float32)
X_test_scaled = X_test_scaled.astype(np.float32)
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

print(f"\nData types after conversion:")
print(f"X_train: {X_train_scaled.dtype}, y_train: {y_train.dtype}")
print(f"X_test: {X_test_scaled.dtype}, y_test: {y_test.dtype}")
# Out:
# Data types after conversion:
# X_train: float32, y_train: int32
# X_test: float32, y_test: int32

# %% [markdown]
# ## 2.3 Convertir a formato dataset de TensorFlow

# %%
# Definición del tamaño de batch para el entrenamiento
BATCH_SIZE = 1000  # Número de muestras procesadas simultáneamente

# Creación del dataset de entrenamiento con optimizaciones
train_ds = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
train_ds = train_ds.shuffle(buffer_size=10000, seed=42)  # Mezcla con buffer para aleatoriedad
train_ds = train_ds.batch(BATCH_SIZE)                    # Agrupa en batches
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)           # Carga anticipada automática

# Creación del dataset de prueba (sin shuffling)
test_ds = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print(f"Training dataset created with batch size: {BATCH_SIZE}")
print(f"Test dataset created with batch size: {BATCH_SIZE}")

# Verificación de la estructura del dataset
for batch_features, batch_labels in train_ds.take(1):
    print(f"\nBatch verification:")
    print(f"Features batch shape: {batch_features.shape}")
    print(f"Labels batch shape: {batch_labels.shape}")
    print(f"Features dtype: {batch_features.dtype}")
    print(f"Labels dtype: {batch_labels.dtype}")
    break
# Out:
# Training dataset created with batch size: 1000
# Test dataset created with batch size: 1000
#
# Batch verification:
# Features batch shape: (1000, 20)
# Labels batch shape: (1000,)
# Features dtype: <dtype: 'float32'>
# Labels dtype: <dtype: 'int32'>

# %% [markdown]
# # 3. Construcción de la Arquitectura de Red Neuronal
#
# Se implementa una Red Neuronal Profunda (Deep Neural Network - DNN) utilizando la API funcional de Keras.

# %%
class InitialModel(Model):
  def __init__(self, input_shape=(20,), num_classes=4, **kwargs):
    super(InitialModel, self).__init__(**kwargs)
    self.input_shape_val = input_shape
    self.num_classes = num_classes
    
    # Capa de entrada
    self.input_layer = tf.keras.layers.InputLayer(input_shape=input_shape)
    
    # Primera capa oculta
    self.dense1 = tf.keras.layers.Dense(512, activation='relu')

    # Segunda capa oculta
    self.dense2 = tf.keras.layers.Dense(256, activation='relu')

    # Tecera capa oculta
    self.dense3 = tf.keras.layers.Dense(128, activation='relu')

     # Cuarta capa oculta
    self.dense4 = tf.keras.layers.Dense(128, activation='relu')

    # Quinta capa oculta
    self.dense5 = tf.keras.layers.Dense(64, activation='relu')
    
    # Capa de salida
    self.out = tf.keras.layers.Dense(num_classes, activation='softmax')

  def call(self, inputs, training=None):
    
    x = self.dense1(inputs)
    x = self.dense2(x)
    x = self.dense3(x)
    x = self.dense4(x)
    x = self.dense5(x)
    return self.out(x)

  def get_config(self):
    config = super(InitialModel, self).get_config()
    config.update({
        "input_shape": self.input_shape_val,
        "num_classes": self.num_classes,
    })
    return config

# Instanciar el modelo con 20 características de entrada (10 int_* + 10 std_*)
model = InitialModel(input_shape=(20,), num_classes=4)

# %%
# Definición de la función de pérdida y optimizador
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()   # Para clasificación multiclase con etiquetas enteras
optimizer = tf.keras.optimizers.Adam()                          # Optimizador Adam con learning rate adaptativo

# %%
# Definición de métricas para monitorear el entrenamiento
train_loss = tf.keras.metrics.Mean(name='train_loss')                              # Pérdida promedio de entrenamiento
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy') # Exactitud de entrenamiento

test_loss = tf.keras.metrics.Mean(name='test_loss')                                # Pérdida promedio de validación
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')   # Exactitud de validación

# %%
# Implementación manual de callbacks para control del entrenamiento

best_val_loss = float('inf')  # Mejor pérdida de validación observada
best_weights = None           # Pesos del modelo con mejor rendimiento
patience_lr = 3               # Épocas sin mejora antes de reducir LR
patience_es = 4               # Épocas sin mejora antes de detener entrenamiento
lr_counter = 0                # Contador para reducción de LR
es_counter = 0                # Contador para early stopping
lr_factor = 0.2               # Factor de reducción del learning rate (nuevo_lr = lr × 0.2)
min_lr = 0.00001              # Learning rate mínimo permitido

print("Manual callbacks initialized:")
print(f"  LR reduction: patience={patience_lr}, factor={lr_factor}, min_lr={min_lr}")
print(f"  Early stopping: patience={patience_es}, restore_best_weights=True")
# Out:
# Manual callbacks initialized:
#   LR reduction: patience=3, factor=0.2, min_lr=1e-05
#   Early stopping: patience=4, restore_best_weights=True

# %% [markdown]
# # 4. Entrenamiento del Modelo
#
# Esta sección implementa el loop de entrenamiento personalizado con TensorFlow.

# %%
@tf.function  # Compilación a grafo estático para mayor eficiencia
def train_step(data, labels):
  """
  Ejecuta un paso de entrenamiento: forward pass, cálculo de pérdida y backpropagation.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  with tf.GradientTape() as tape:
    predictions = model(data, training=True)  # Forward pass con modo entrenamiento
    loss = loss_object(labels, predictions)   # Cálculo de pérdida
  gradients = tape.gradient(loss, model.trainable_variables)  # Backpropagation
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))  # Actualización de pesos

  train_loss(loss)                     # Actualización de métrica de pérdida
  train_accuracy(labels, predictions)  # Actualización de métrica de exactitud

# %%
@tf.function  # Compilación para optimización
def test_step(data, labels):
  """
  Ejecuta evaluación en conjunto de validación/prueba sin actualización de pesos.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  predictions = model(data, training=False)   # Forward pass sin dropout/regularización
  t_loss = loss_object(labels, predictions)   # Cálculo de pérdida

  test_loss(t_loss)                    # Actualización de métrica de pérdida
  test_accuracy(labels, predictions)   # Actualización de métrica de exactitud

# %%
EPOCHS = 100

train_batches = len(X_train_scaled) // BATCH_SIZE + (1 if len(X_train_scaled) % BATCH_SIZE != 0 else 0)
test_batches = len(X_test_scaled) // BATCH_SIZE + (1 if len(X_test_scaled) % BATCH_SIZE != 0 else 0)

print(f"Training for up to {EPOCHS} epochs (with early stopping)")
print(f"Training batches per epoch: {train_batches}")
print(f"Test batches per epoch: {test_batches}")

# Resetear métricasa antes del entrenamiento
train_loss.reset_state()
train_accuracy.reset_state()
test_loss.reset_state()
test_accuracy.reset_state()

for epoch in range(EPOCHS):
  print(f"\nEpoch {epoch+1}/{EPOCHS}")
  
  # Entrenamiento
  for batch_idx, (data, labels) in enumerate(train_ds):
    train_step(data, labels)

  # Prueba
  for test_data, test_labels in test_ds:
    test_step(test_data, test_labels)

  # Obtener métricas actuales
  current_train_loss = train_loss.result().numpy()
  current_train_acc = train_accuracy.result().numpy() * 100
  current_test_loss = test_loss.result().numpy()
  current_test_acc = test_accuracy.result().numpy() * 100
  current_lr = optimizer.learning_rate.numpy()

  # Resultados épocas
  template = 'Epoch {}, Loss: {:.4f}, Accuracy: {:.2f}%, Test Loss: {:.4f}, Test Accuracy: {:.2f}%, LR: {:.6f}'
  print(template.format(epoch+1,
                        current_train_loss,
                        current_train_acc,
                        current_test_loss,
                        current_test_acc,
                        current_lr))

  # Verificar si la pérdida en validación mejora
  if current_test_loss < best_val_loss:
    print(f"  ✓ Validation loss improved from {best_val_loss:.4f} to {current_test_loss:.4f}")
    best_val_loss = current_test_loss
    best_weights = model.get_weights()  # Salvar mejores pesos
    lr_counter = 0  # Resetear contador LR
    es_counter = 0  # Resetear contador early stopping
  else:
    lr_counter += 1
    es_counter += 1
    print(f"  ✗ Validation loss did not improve (best: {best_val_loss:.4f})")
    
    # Reducción del Learning rate
    if lr_counter >= patience_lr:
      old_lr = optimizer.learning_rate.numpy()
      new_lr = max(old_lr * lr_factor, min_lr)
      if new_lr != old_lr:
        optimizer.learning_rate.assign(new_lr)
        print(f"  → Reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
        lr_counter = 0  # Resetear contador LR
      else:
        print(f"  → Learning rate already at minimum ({min_lr:.6f})")
    
    # Lógica de Early stopping
    if es_counter >= patience_es:
      print(f"\n Early stopping triggered! No improvement for {patience_es} epochs.")
      print(f"  Restoring best weights from epoch {epoch+1-patience_es}")
      model.set_weights(best_weights)  # Restaurar lo pesos
      break

  # Resetear las métricas para la siguiente época
  train_loss.reset_state()
  train_accuracy.reset_state()
  test_loss.reset_state()
  test_accuracy.reset_state()

print("\nTraining completed!")
print(f"Best validation loss: {best_val_loss:.4f}")
# Out:
# Training for up to 100 epochs (with early stopping)
# Training batches per epoch: 232
# Test batches per epoch: 99
#
# Epoch 1/100
# Epoch 1, Loss: 0.9835, Accuracy: 61.47%, Test Loss: 14.8823, Test Accuracy: 24.54%, LR: 0.001000
#   ✓ Validation loss improved from inf to 14.8823
#
# Epoch 2/100
# Epoch 2, Loss: 1.1878, Accuracy: 58.02%, Test Loss: 9.4447, Test Accuracy: 24.54%, LR: 0.001000
#   ✓ Validation loss improved from 14.8823 to 9.4447
#
# Epoch 3/100
# Epoch 3, Loss: 1.0237, Accuracy: 60.95%, Test Loss: 10.4546, Test Accuracy: 24.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.4447)
#
# Epoch 4/100
# Epoch 4, Loss: 1.0248, Accuracy: 55.59%, Test Loss: 10.1178, Test Accuracy: 24.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.4447)
#
# Epoch 5/100
# Epoch 5, Loss: 1.0056, Accuracy: 60.63%, Test Loss: 9.0678, Test Accuracy: 24.54%, LR: 0.001000
#   ✓ Validation loss improved from 9.4447 to 9.0678
#
# Epoch 6/100
# Epoch 6, Loss: 1.0900, Accuracy: 54.04%, Test Loss: 13.4942, Test Accuracy: 24.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.0678)
#
# Epoch 7/100
# Epoch 7, Loss: 1.0582, Accuracy: 61.48%, Test Loss: 10.6486, Test Accuracy: 24.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.0678)
#
# Epoch 8/100
# Epoch 8, Loss: 1.0266, Accuracy: 55.68%, Test Loss: 10.4318, Test Accuracy: 24.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.0678)
#   → Reducing learning rate from 0.001000 to 0.000200
#
# Epoch 9/100
# Epoch 9, Loss: 2.0291, Accuracy: 23.03%, Test Loss: 1.5138, Test Accuracy: 24.54%, LR: 0.000200
#   ✓ Validation loss improved from 9.0678 to 1.5138
#
# Epoch 10/100
# Epoch 10, Loss: 1.4304, Accuracy: 26.81%, Test Loss: 1.3932, Test Accuracy: 24.54%, LR: 0.000200
#   ✓ Validation loss improved from 1.5138 to 1.3932
#
# Epoch 11/100
# Epoch 11, Loss: 1.4058, Accuracy: 24.83%, Test Loss: 1.3977, Test Accuracy: 28.87%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3932)
#
# Epoch 12/100
# Epoch 12, Loss: 1.3525, Accuracy: 33.21%, Test Loss: 1.3698, Test Accuracy: 28.65%, LR: 0.000200
#   ✓ Validation loss improved from 1.3932 to 1.3698
#
# Epoch 13/100
# Epoch 13, Loss: 1.3362, Accuracy: 33.58%, Test Loss: 1.4609, Test Accuracy: 28.46%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3698)
#
# Epoch 14/100
# Epoch 14, Loss: 1.3514, Accuracy: 33.70%, Test Loss: 1.3694, Test Accuracy: 28.93%, LR: 0.000200
#   ✓ Validation loss improved from 1.3698 to 1.3694
#
# Epoch 15/100
# Epoch 15, Loss: 1.2886, Accuracy: 39.77%, Test Loss: 1.5455, Test Accuracy: 27.97%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3694)
#
# Epoch 16/100
# Epoch 16, Loss: 1.2825, Accuracy: 42.76%, Test Loss: 1.5340, Test Accuracy: 27.28%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3694)
#
# Epoch 17/100
# Epoch 17, Loss: 1.3087, Accuracy: 36.62%, Test Loss: 1.5414, Test Accuracy: 27.19%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3694)
#   → Reducing learning rate from 0.000200 to 0.000040
#
# Epoch 18/100
# Epoch 18, Loss: 1.4155, Accuracy: 29.62%, Test Loss: 1.2961, Test Accuracy: 33.00%, LR: 0.000040
#   ✓ Validation loss improved from 1.3694 to 1.2961
#
# Epoch 19/100
# Epoch 19, Loss: 1.3047, Accuracy: 35.35%, Test Loss: 1.2502, Test Accuracy: 39.38%, LR: 0.000040
#   ✓ Validation loss improved from 1.2961 to 1.2502
#
# Epoch 20/100
# Epoch 20, Loss: 1.2607, Accuracy: 40.74%, Test Loss: 1.2260, Test Accuracy: 42.13%, LR: 0.000040
#   ✓ Validation loss improved from 1.2502 to 1.2260
#
# Epoch 21/100
# Epoch 21, Loss: 1.2348, Accuracy: 44.30%, Test Loss: 1.2100, Test Accuracy: 43.70%, LR: 0.000040
#   ✓ Validation loss improved from 1.2260 to 1.2100
#
# Epoch 22/100
# Epoch 22, Loss: 1.2159, Accuracy: 46.14%, Test Loss: 1.1965, Test Accuracy: 45.01%, LR: 0.000040
#   ✓ Validation loss improved from 1.2100 to 1.1965
#
# Epoch 23/100
# Epoch 23, Loss: 1.2002, Accuracy: 47.22%, Test Loss: 1.1847, Test Accuracy: 45.88%, LR: 0.000040
#   ✓ Validation loss improved from 1.1965 to 1.1847
#
# Epoch 24/100
# Epoch 24, Loss: 1.1862, Accuracy: 47.99%, Test Loss: 1.1747, Test Accuracy: 46.56%, LR: 0.000040
#   ✓ Validation loss improved from 1.1847 to 1.1747
#
# Epoch 25/100
# Epoch 25, Loss: 1.1741, Accuracy: 48.56%, Test Loss: 1.1668, Test Accuracy: 46.97%, LR: 0.000040
#   ✓ Validation loss improved from 1.1747 to 1.1668
#
# Epoch 26/100
# Epoch 26, Loss: 1.1636, Accuracy: 48.98%, Test Loss: 1.1605, Test Accuracy: 47.36%, LR: 0.000040
#   ✓ Validation loss improved from 1.1668 to 1.1605
#
# Epoch 27/100
# Epoch 27, Loss: 1.1548, Accuracy: 49.39%, Test Loss: 1.1554, Test Accuracy: 47.69%, LR: 0.000040
#   ✓ Validation loss improved from 1.1605 to 1.1554
#
# Epoch 28/100
# Epoch 28, Loss: 1.1474, Accuracy: 49.69%, Test Loss: 1.1506, Test Accuracy: 48.05%, LR: 0.000040
#   ✓ Validation loss improved from 1.1554 to 1.1506
#
# Epoch 29/100
# Epoch 29, Loss: 1.1403, Accuracy: 50.06%, Test Loss: 1.1462, Test Accuracy: 48.28%, LR: 0.000040
#   ✓ Validation loss improved from 1.1506 to 1.1462
#
# Epoch 30/100
# Epoch 30, Loss: 1.1339, Accuracy: 50.44%, Test Loss: 1.1419, Test Accuracy: 48.56%, LR: 0.000040
#   ✓ Validation loss improved from 1.1462 to 1.1419
#
# Epoch 31/100
# Epoch 31, Loss: 1.1276, Accuracy: 50.74%, Test Loss: 1.1378, Test Accuracy: 48.85%, LR: 0.000040
#   ✓ Validation loss improved from 1.1419 to 1.1378
#
# Epoch 32/100
# Epoch 32, Loss: 1.1221, Accuracy: 51.07%, Test Loss: 1.1340, Test Accuracy: 49.19%, LR: 0.000040
#   ✓ Validation loss improved from 1.1378 to 1.1340
#
# Epoch 33/100
# Epoch 33, Loss: 1.1166, Accuracy: 51.42%, Test Loss: 1.1304, Test Accuracy: 49.50%, LR: 0.000040
#   ✓ Validation loss improved from 1.1340 to 1.1304
#
# Epoch 34/100
# Epoch 34, Loss: 1.1110, Accuracy: 51.86%, Test Loss: 1.1273, Test Accuracy: 49.81%, LR: 0.000040
#   ✓ Validation loss improved from 1.1304 to 1.1273
#
# Epoch 35/100
# Epoch 35, Loss: 1.1061, Accuracy: 52.22%, Test Loss: 1.1244, Test Accuracy: 50.12%, LR: 0.000040
#   ✓ Validation loss improved from 1.1273 to 1.1244
#
# Epoch 36/100
# Epoch 36, Loss: 1.1014, Accuracy: 52.52%, Test Loss: 1.1216, Test Accuracy: 50.37%, LR: 0.000040
#   ✓ Validation loss improved from 1.1244 to 1.1216
#
# Epoch 37/100
# Epoch 37, Loss: 1.0962, Accuracy: 52.88%, Test Loss: 1.1192, Test Accuracy: 50.63%, LR: 0.000040
#   ✓ Validation loss improved from 1.1216 to 1.1192
#
# Epoch 38/100
# Epoch 38, Loss: 1.0917, Accuracy: 53.22%, Test Loss: 1.1171, Test Accuracy: 50.86%, LR: 0.000040
#   ✓ Validation loss improved from 1.1192 to 1.1171
#
# Epoch 39/100
# Epoch 39, Loss: 1.0875, Accuracy: 53.44%, Test Loss: 1.1147, Test Accuracy: 51.04%, LR: 0.000040
#   ✓ Validation loss improved from 1.1171 to 1.1147
#
# Epoch 40/100
# Epoch 40, Loss: 1.0829, Accuracy: 53.73%, Test Loss: 1.1126, Test Accuracy: 51.19%, LR: 0.000040
#   ✓ Validation loss improved from 1.1147 to 1.1126
#
# Epoch 41/100
# Epoch 41, Loss: 1.0785, Accuracy: 53.95%, Test Loss: 1.1107, Test Accuracy: 51.27%, LR: 0.000040
#   ✓ Validation loss improved from 1.1126 to 1.1107
#
# Epoch 42/100
# Epoch 42, Loss: 1.0741, Accuracy: 54.17%, Test Loss: 1.1087, Test Accuracy: 51.36%, LR: 0.000040
#   ✓ Validation loss improved from 1.1107 to 1.1087
#
# Epoch 43/100
# Epoch 43, Loss: 1.0699, Accuracy: 54.42%, Test Loss: 1.1070, Test Accuracy: 51.47%, LR: 0.000040
#   ✓ Validation loss improved from 1.1087 to 1.1070
#
# Epoch 44/100
# Epoch 44, Loss: 1.0661, Accuracy: 54.62%, Test Loss: 1.1052, Test Accuracy: 51.54%, LR: 0.000040
#   ✓ Validation loss improved from 1.1070 to 1.1052
#
# Epoch 45/100
# Epoch 45, Loss: 1.0623, Accuracy: 54.78%, Test Loss: 1.1035, Test Accuracy: 51.69%, LR: 0.000040
#   ✓ Validation loss improved from 1.1052 to 1.1035
#
# Epoch 46/100
# Epoch 46, Loss: 1.0583, Accuracy: 54.95%, Test Loss: 1.1019, Test Accuracy: 51.84%, LR: 0.000040
#   ✓ Validation loss improved from 1.1035 to 1.1019
#
# Epoch 47/100
# Epoch 47, Loss: 1.0547, Accuracy: 55.13%, Test Loss: 1.1002, Test Accuracy: 51.96%, LR: 0.000040
#   ✓ Validation loss improved from 1.1019 to 1.1002
#
# Epoch 48/100
# Epoch 48, Loss: 1.0509, Accuracy: 55.32%, Test Loss: 1.0987, Test Accuracy: 52.09%, LR: 0.000040
#   ✓ Validation loss improved from 1.1002 to 1.0987
#
# Epoch 49/100
# Epoch 49, Loss: 1.0475, Accuracy: 55.46%, Test Loss: 1.0971, Test Accuracy: 52.19%, LR: 0.000040
#   ✓ Validation loss improved from 1.0987 to 1.0971
#
# Epoch 50/100
# Epoch 50, Loss: 1.0440, Accuracy: 55.61%, Test Loss: 1.0953, Test Accuracy: 52.28%, LR: 0.000040
#   ✓ Validation loss improved from 1.0971 to 1.0953
#
# Epoch 51/100
# Epoch 51, Loss: 1.0407, Accuracy: 55.80%, Test Loss: 1.0934, Test Accuracy: 52.40%, LR: 0.000040
#   ✓ Validation loss improved from 1.0953 to 1.0934
#
# Epoch 52/100
# Epoch 52, Loss: 1.0372, Accuracy: 55.93%, Test Loss: 1.0922, Test Accuracy: 52.47%, LR: 0.000040
#   ✓ Validation loss improved from 1.0934 to 1.0922
#
# Epoch 53/100
# Epoch 53, Loss: 1.0340, Accuracy: 56.03%, Test Loss: 1.0906, Test Accuracy: 52.55%, LR: 0.000040
#   ✓ Validation loss improved from 1.0922 to 1.0906
#
# Epoch 54/100
# Epoch 54, Loss: 1.0312, Accuracy: 56.19%, Test Loss: 1.0892, Test Accuracy: 52.66%, LR: 0.000040
#   ✓ Validation loss improved from 1.0906 to 1.0892
#
# Epoch 55/100
# Epoch 55, Loss: 1.0279, Accuracy: 56.28%, Test Loss: 1.0880, Test Accuracy: 52.77%, LR: 0.000040
#   ✓ Validation loss improved from 1.0892 to 1.0880
#
# Epoch 56/100
# Epoch 56, Loss: 1.0251, Accuracy: 56.45%, Test Loss: 1.0870, Test Accuracy: 52.85%, LR: 0.000040
#   ✓ Validation loss improved from 1.0880 to 1.0870
#
# Epoch 57/100
# Epoch 57, Loss: 1.0227, Accuracy: 56.53%, Test Loss: 1.0859, Test Accuracy: 52.92%, LR: 0.000040
#   ✓ Validation loss improved from 1.0870 to 1.0859
#
# Epoch 58/100
# Epoch 58, Loss: 1.0199, Accuracy: 56.68%, Test Loss: 1.0849, Test Accuracy: 52.98%, LR: 0.000040
#   ✓ Validation loss improved from 1.0859 to 1.0849
#
# Epoch 59/100
# Epoch 59, Loss: 1.0177, Accuracy: 56.77%, Test Loss: 1.0837, Test Accuracy: 53.06%, LR: 0.000040
#   ✓ Validation loss improved from 1.0849 to 1.0837
#
# Epoch 60/100
# Epoch 60, Loss: 1.0148, Accuracy: 56.85%, Test Loss: 1.0830, Test Accuracy: 53.07%, LR: 0.000040
#   ✓ Validation loss improved from 1.0837 to 1.0830
#
# Epoch 61/100
# Epoch 61, Loss: 1.0126, Accuracy: 56.95%, Test Loss: 1.0821, Test Accuracy: 53.17%, LR: 0.000040
#   ✓ Validation loss improved from 1.0830 to 1.0821
#
# Epoch 62/100
# Epoch 62, Loss: 1.0104, Accuracy: 57.06%, Test Loss: 1.0814, Test Accuracy: 53.23%, LR: 0.000040
#   ✓ Validation loss improved from 1.0821 to 1.0814
#
# Epoch 63/100
# Epoch 63, Loss: 1.0082, Accuracy: 57.18%, Test Loss: 1.0807, Test Accuracy: 53.31%, LR: 0.000040
#   ✓ Validation loss improved from 1.0814 to 1.0807
#
# Epoch 64/100
# Epoch 64, Loss: 1.0062, Accuracy: 57.25%, Test Loss: 1.0802, Test Accuracy: 53.37%, LR: 0.000040
#   ✓ Validation loss improved from 1.0807 to 1.0802
#
# Epoch 65/100
# Epoch 65, Loss: 1.0039, Accuracy: 57.29%, Test Loss: 1.0797, Test Accuracy: 53.45%, LR: 0.000040
#   ✓ Validation loss improved from 1.0802 to 1.0797
#
# Epoch 66/100
# Epoch 66, Loss: 1.0016, Accuracy: 57.49%, Test Loss: 1.0794, Test Accuracy: 53.48%, LR: 0.000040
#   ✓ Validation loss improved from 1.0797 to 1.0794
#
# Epoch 67/100
# Epoch 67, Loss: 0.9998, Accuracy: 57.52%, Test Loss: 1.0788, Test Accuracy: 53.55%, LR: 0.000040
#   ✓ Validation loss improved from 1.0794 to 1.0788
#
# Epoch 68/100
# Epoch 68, Loss: 0.9980, Accuracy: 57.61%, Test Loss: 1.0784, Test Accuracy: 53.59%, LR: 0.000040
#   ✓ Validation loss improved from 1.0788 to 1.0784
#
# Epoch 69/100
# Epoch 69, Loss: 0.9961, Accuracy: 57.69%, Test Loss: 1.0785, Test Accuracy: 53.65%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.0784)
#
# Epoch 70/100
# Epoch 70, Loss: 0.9947, Accuracy: 57.74%, Test Loss: 1.0780, Test Accuracy: 53.72%, LR: 0.000040
#   ✓ Validation loss improved from 1.0784 to 1.0780
#
# Epoch 71/100
# Epoch 71, Loss: 0.9930, Accuracy: 57.87%, Test Loss: 1.0777, Test Accuracy: 53.78%, LR: 0.000040
#   ✓ Validation loss improved from 1.0780 to 1.0777
#
# Epoch 72/100
# Epoch 72, Loss: 0.9912, Accuracy: 57.93%, Test Loss: 1.0774, Test Accuracy: 53.84%, LR: 0.000040
#   ✓ Validation loss improved from 1.0777 to 1.0774
#
# Epoch 73/100
# Epoch 73, Loss: 0.9896, Accuracy: 57.99%, Test Loss: 1.0770, Test Accuracy: 53.84%, LR: 0.000040
#   ✓ Validation loss improved from 1.0774 to 1.0770
#
# Epoch 74/100
# Epoch 74, Loss: 0.9880, Accuracy: 58.05%, Test Loss: 1.0766, Test Accuracy: 53.85%, LR: 0.000040
#   ✓ Validation loss improved from 1.0770 to 1.0766
#
# Epoch 75/100
# Epoch 75, Loss: 0.9865, Accuracy: 58.16%, Test Loss: 1.0765, Test Accuracy: 53.84%, LR: 0.000040
#   ✓ Validation loss improved from 1.0766 to 1.0765
#
# Epoch 76/100
# Epoch 76, Loss: 0.9849, Accuracy: 58.17%, Test Loss: 1.0763, Test Accuracy: 53.84%, LR: 0.000040
#   ✓ Validation loss improved from 1.0765 to 1.0763
#
# Epoch 77/100
# Epoch 77, Loss: 0.9834, Accuracy: 58.24%, Test Loss: 1.0768, Test Accuracy: 53.82%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.0763)
#
# Epoch 78/100
# Epoch 78, Loss: 0.9821, Accuracy: 58.26%, Test Loss: 1.0769, Test Accuracy: 53.81%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.0763)
#
# Epoch 79/100
# Epoch 79, Loss: 0.9809, Accuracy: 58.34%, Test Loss: 1.0771, Test Accuracy: 53.81%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.0763)
#   → Reducing learning rate from 0.000040 to 0.000010
#
# Epoch 80/100
# Epoch 80, Loss: 0.9794, Accuracy: 58.55%, Test Loss: 1.0492, Test Accuracy: 54.92%, LR: 0.000010
#   ✓ Validation loss improved from 1.0763 to 1.0492
#
# Epoch 81/100
# Epoch 81, Loss: 0.9560, Accuracy: 59.73%, Test Loss: 1.0400, Test Accuracy: 55.29%, LR: 0.000010
#   ✓ Validation loss improved from 1.0492 to 1.0400
#
# Epoch 82/100
# Epoch 82, Loss: 0.9469, Accuracy: 60.14%, Test Loss: 1.0355, Test Accuracy: 55.45%, LR: 0.000010
#   ✓ Validation loss improved from 1.0400 to 1.0355
#
# Epoch 83/100
# Epoch 83, Loss: 0.9418, Accuracy: 60.28%, Test Loss: 1.0331, Test Accuracy: 55.49%, LR: 0.000010
#   ✓ Validation loss improved from 1.0355 to 1.0331
#
# Epoch 84/100
# Epoch 84, Loss: 0.9385, Accuracy: 60.44%, Test Loss: 1.0318, Test Accuracy: 55.56%, LR: 0.000010
#   ✓ Validation loss improved from 1.0331 to 1.0318
#
# Epoch 85/100
# Epoch 85, Loss: 0.9363, Accuracy: 60.51%, Test Loss: 1.0310, Test Accuracy: 55.58%, LR: 0.000010
#   ✓ Validation loss improved from 1.0318 to 1.0310
#
# Epoch 86/100
# Epoch 86, Loss: 0.9344, Accuracy: 60.63%, Test Loss: 1.0307, Test Accuracy: 55.60%, LR: 0.000010
#   ✓ Validation loss improved from 1.0310 to 1.0307
#
# Epoch 87/100
# Epoch 87, Loss: 0.9332, Accuracy: 60.67%, Test Loss: 1.0304, Test Accuracy: 55.59%, LR: 0.000010
#   ✓ Validation loss improved from 1.0307 to 1.0304
#
# Epoch 88/100
# Epoch 88, Loss: 0.9317, Accuracy: 60.75%, Test Loss: 1.0303, Test Accuracy: 55.59%, LR: 0.000010
#   ✓ Validation loss improved from 1.0304 to 1.0303
#
# Epoch 89/100
# Epoch 89, Loss: 0.9304, Accuracy: 60.77%, Test Loss: 1.0302, Test Accuracy: 55.59%, LR: 0.000010
#   ✓ Validation loss improved from 1.0303 to 1.0302
#
# Epoch 90/100
# Epoch 90, Loss: 0.9295, Accuracy: 60.84%, Test Loss: 1.0302, Test Accuracy: 55.62%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0302)
#
# Epoch 91/100
# Epoch 91, Loss: 0.9284, Accuracy: 60.85%, Test Loss: 1.0302, Test Accuracy: 55.62%, LR: 0.000010
#   ✓ Validation loss improved from 1.0302 to 1.0302
#
# Epoch 92/100
# Epoch 92, Loss: 0.9275, Accuracy: 60.90%, Test Loss: 1.0301, Test Accuracy: 55.63%, LR: 0.000010
#   ✓ Validation loss improved from 1.0302 to 1.0301
#
# Epoch 93/100
# Epoch 93, Loss: 0.9264, Accuracy: 60.94%, Test Loss: 1.0301, Test Accuracy: 55.63%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0301)
#
# Epoch 94/100
# Epoch 94, Loss: 0.9257, Accuracy: 61.00%, Test Loss: 1.0301, Test Accuracy: 55.64%, LR: 0.000010
#   ✓ Validation loss improved from 1.0301 to 1.0301
#
# Epoch 95/100
# Epoch 95, Loss: 0.9250, Accuracy: 61.03%, Test Loss: 1.0301, Test Accuracy: 55.63%, LR: 0.000010
#   ✓ Validation loss improved from 1.0301 to 1.0301
#
# Epoch 96/100
# Epoch 96, Loss: 0.9239, Accuracy: 61.09%, Test Loss: 1.0301, Test Accuracy: 55.65%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0301)
#
# Epoch 97/100
# Epoch 97, Loss: 0.9232, Accuracy: 61.12%, Test Loss: 1.0301, Test Accuracy: 55.65%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0301)
#
# Epoch 98/100
# Epoch 98, Loss: 0.9224, Accuracy: 61.14%, Test Loss: 1.0301, Test Accuracy: 55.65%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0301)
#   → Learning rate already at minimum (0.000010)
#
# Epoch 99/100
# Epoch 99, Loss: 0.9217, Accuracy: 61.18%, Test Loss: 1.0301, Test Accuracy: 55.67%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.0301)
#   → Learning rate already at minimum (0.000010)
#
#  Early stopping triggered! No improvement for 4 epochs.
#   Restoring best weights from epoch 95
#
# Training completed!
# Best validation loss: 1.0301

# %% [markdown]
# ## 4.1. Persistencia del modelo entrenado
#
# Se guarda el modelo en formato Keras (.keras) junto con los objetos de preprocesamiento necesarios para realizar predicciones futuras.

# %%
# Guardar el modelo entrenado en formato Keras nativo
model.save("models/frijol/frijol_model_dnn_v5.keras")
print("Model saved successfully as 'models/frijol/frijol_model_dnn_v5.keras'")

# Guardar objetos de preprocesamiento (scaler, encoder) para uso en producción
with open('preprocessing_objects_frijol_v5.pkl', 'wb') as f:
    pickle.dump({
        'scaler': scaler,                    # Estandarizador ajustado
        'label_encoder': label_encoder,      # Codificador de etiquetas
        'feature_columns': feature_columns   # Lista de características esperadas
    }, f)

print("Preprocessing objects saved as 'preprocessing_objects_frijol.pkl'")
# Out:
# Model saved successfully as 'models/frijol/frijol_model_dnn_v5.keras'
# Preprocessing objects saved as 'preprocessing_objects_frijol.pkl'

# %% [markdown]
# # 5. Evaluación del Modelo
#
# Esta sección carga el modelo entrenado y evalúa su rendimiento mediante:
# - **Generación de predicciones**: En conjuntos de entrenamiento y prueba
# - **Métricas de clasificación**: Accuracy, Precision, F1-Score, Kappa
# - **Matrices de confusión**: Visualización de aciertos y errores por clase
# - **Análisis de curvas de aprendizaje**: Evolución de pérdida y exactitud durante entrenamiento

# %%
# Carga del modelo entrenado desde archivo
trained_model = tf.keras.models.load_model('models/frijol/frijol_model_dnn_v5.keras', custom_objects={'InitialModel': InitialModel})

# %%
# Generación de predicciones en el conjunto de prueba
print("Realizando predicciones en Test...")
y_pred_probs = trained_model.predict(X_test_scaled)  # Probabilidades para cada clase
y_pred = np.argmax(y_pred_probs, axis=1)             

# Generación de predicciones en el conjunto de entrenamiento
print("Realizando predicciones en Train...")
y_train_pred_probs = trained_model.predict(X_train_scaled)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)
# Out:
# Realizando predicciones en Test...
# 3073/3073 ━━━━━━━━━━━━━━━━━━━━ 2s 732us/step
# Realizando predicciones en Train...
# 7232/7232 ━━━━━━━━━━━━━━━━━━━━ 5s 712us/step

# %% [markdown]
# ## 5.1. Guardar predicciones

# %%
# Guardar predicciones del conjunto de prueba
joblib.dump(y_pred, "results/predictions/frijol/test/predicciones_dnn_test_v5.pkl")
print("✓ Predicciones de prueba guardadas en: results/predictions/frijol/test/predicciones_dnn_test_v5.pkl")

# Guardar predicciones del conjunto de entrenamiento
joblib.dump(y_train_pred, "results/predictions/frijol/train/predicciones_dnn_train_v5.pkl")
print("✓ Predicciones de entrenamiento guardadas en: results/predictions/frijol/train/predicciones_dnn_train.pkl")

# Guardar probabilidades predichas
joblib.dump(y_pred_probs, "results/predictions/frijol/test/predicciones_dnn_test_probs_v5.pkl")
joblib.dump(y_train_pred_probs, "results/predictions/frijol/train/predicciones_dnn_train_probs.pkl")
print("✓ Probabilidades de predicción guardadas exitosamente")
# Out:
# ✓ Predicciones de prueba guardadas en: results/predictions/frijol/test/predicciones_dnn_test_v5.pkl
# ✓ Predicciones de entrenamiento guardadas en: results/predictions/frijol/train/predicciones_dnn_train.pkl
# ✓ Probabilidades de predicción guardadas exitosamente

# %% [markdown]
# # 6. Resultados

# %%
# Cálculo de métricas para el conjunto de prueba (Test)
accuracy = accuracy_score(y_test, y_pred)                        # Exactitud: proporción de predicciones correctas
precision = precision_score(y_test, y_pred, average='weighted')  # Precisión ponderada por clase
f1 = f1_score(y_test, y_pred, average='weighted')                # F1-Score: media armónica de precisión y recall
kappa = cohen_kappa_score(y_test, y_pred)                        # Kappa de Cohen: acuerdo ajustado por azar

# Cálculo de métricas para el conjunto de entrenamiento (Train)
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, average='weighted')
train_f1 = f1_score(y_train, y_train_pred, average='weighted')
train_kappa = cohen_kappa_score(y_train, y_train_pred)

# Presentación comparativa de métricas
print("-" * 65)
print(f"{'Métrica':<20} | {'Train':<20} | {'Test':<20}")
print("-" * 65)
print(f"{'Accuracy':<20} | {train_accuracy:<20.4f} | {accuracy:<20.4f}")
print(f"{'Precision':<20} | {train_precision:<20.4f} | {precision:<20.4f}")
print(f"{'F1-Score':<20} | {train_f1:<20.4f} | {f1:<20.4f}")
print(f"{'Kappa Score':<20} | {train_kappa:<20.4f} | {kappa:<20.4f}")
print("-" * 65)
# Out:
# -----------------------------------------------------------------
# Métrica              | Train                | Test
# -----------------------------------------------------------------
# Accuracy             | 0.6191               | 0.5563
# Precision            | 0.6119               | 0.5441
# F1-Score             | 0.6078               | 0.5399
# Kappa Score          | 0.4841               | 0.4018
# -----------------------------------------------------------------

# %%
# Obtención de nombres de clases para los reportes
target_names = label_encoder.classes_.astype(str)

# Reporte de clasificación para conjunto de prueba
print("\nReporte de Clasificación (Test):")
print(classification_report(y_test, y_pred, target_names=target_names))

# Reporte de clasificación para conjunto de entrenamiento
print("\nReporte de Clasificación (Train):")
print(classification_report(y_train, y_train_pred, target_names=target_names))
# Out:
# Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#            1       0.59      0.74      0.66     28070
#            2       0.61      0.51      0.55     25360
#            3       0.40      0.23      0.30     20754
#            4       0.54      0.67      0.60     24124
#
#     accuracy                           0.56     98308
#    macro avg       0.54      0.54      0.53     98308
# weighted avg       0.54      0.56      0.54     98308
#
#
# Reporte de Clasificación (Train):
#               precision    recall  f1-score   support
#
#            1       0.66      0.79      0.72     68623
#            2       0.66      0.63      0.64     59593
#            3       0.53      0.32      0.40     45736
#            4       0.57      0.65      0.60     57448
#
#     accuracy                           0.62    231400
#    macro avg       0.61      0.60      0.59    231400
# weighted avg       0.61      0.62      0.61    231400

# %%
# Visualización comparativa de matrices de confusión
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']

# Matriz de confusión para conjunto de entrenamiento
cm_train = confusion_matrix(y_train, y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=tratamiento_labels)
disp_train.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Matriz de Confusión DNN - Entrenamiento', fontsize=14)
axes[0].set_xlabel('Etiqueta predicha', fontsize=12)
axes[0].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[0].grid(False)

# Matriz de confusión para conjunto de prueba
cm_test = confusion_matrix(y_test, y_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=tratamiento_labels)
disp_test.plot(ax=axes[1], cmap='Blues', colorbar=False)
axes[1].set_title('Matriz de Confusión DNN - Testing', fontsize=14)
axes[1].set_xlabel('Etiqueta predicha', fontsize=12)
axes[1].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[1].grid(False)

plt.tight_layout()
plt.show()
