# %% [markdown]
# <div style="font-family:'Georgia','Times New Roman',Times,serif; width:80%; margin:20px auto; padding:10px 20px 20px 20px; background:#ffffff; border-left:20px solid #003366; box-shadow:0 5px 20px rgba(0,0,0,0.1); text-align:center; border-radius:8px;">
#
#   <div style="display:flex; align-items:center; justify-content:center; gap:20px; margin-bottom:15px; padding-bottom:1px; border-bottom:2px solid #eeeeee;">
#     <img src="assets/Logotipo_de_la_Universidad_Nacional_de_Colombia.svg.png" alt="Logo Universidad" style="max-width:80px; height:auto;">
#     <div style="font-size:1.1em; color:#003366; font-weight:bold; text-align:left;">Universidad Nacional de Colombia</div>
#   </div>
#
#   <h1 style="color:#003366; font-size:2.2em; margin:0.6em 0; font-weight:bold; line-height:1.2;">Detección de enfermedades en plantas de maíz y fríjol común con Inteligencia Artificial e imágenes multiespectrales</h1>
#   <h2 style="color:#444444; font-size:1.4em; margin-bottom:0.8em; font-weight:normal; font-style:italic;">Entrenamiento de red neuronal densa con datos de fríjol</h2>
#
#   <div style="margin-bottom:0em; font-size:1.1em; color:#222222;">
#     <p style="text-align:center; margin:0;"><strong>Autor:</strong> Selene Solano Vera</p>
#   </div>
#
#   <div style="margin:1.0em 0 1.0em 0; padding:0.8em 0; color:#666666; font-size:1em;">Medellín, Febrero de 2026</div>
#
#   <div style="height:0.1rem;"></div>
#
# </div>

# %% [markdown]
# # Utilidades y Configuración Inicial
#
# Esta sección incluye la importación de bibliotecas necesarias para el entrenamiento de una red neuronal profunda (DNN) con TensorFlow/Keras para la clasificación de deficiencia de fósforo en plantas de frijol.

# %%
# TensorFlow y Keras para construcción y entrenamiento de redes neuronales
import tensorflow as tf                     
from tensorflow.keras import Model          

# Manipulación de datos
import pandas as pd                         
import numpy as np                          
import pickle                               
import warnings
import joblib                             

# Visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn para preprocesamiento y evaluación
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import StandardScaler        
from sklearn.preprocessing import LabelEncoder          
from sklearn.metrics import accuracy_score              
from sklearn.metrics import precision_score             
from sklearn.metrics import f1_score                    
from sklearn.metrics import cohen_kappa_score           
from sklearn.metrics import confusion_matrix            
from sklearn.metrics import classification_report       
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Configuración del tema visual de seaborn
sns.set_theme(style="whitegrid", palette="viridis")

# Configuración de parámetros globales de matplotlib
plt.rcParams['figure.figsize'] = (12, 7)    # Tamaño de figura predeterminado en pulgadas
plt.rcParams['axes.titlesize'] = 18         # Tamaño de fuente para títulos
plt.rcParams['axes.labelsize'] = 14         # Tamaño de fuente para etiquetas de ejes

# Suprimir advertencias para mantener limpia la salida del notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Carga del Dataset
#
# Se carga el conjunto de datos de plantas de frijol con información multiespectral para el entrenamiento de la red neuronal profunda.

# %%
# Carga del dataset desde archivos CSV (train y test ya separados por build_dataset.ipynb)
df_train = pd.read_csv("datasets/dataset_frijol_fix_obj_train_v4.csv")
df_test = pd.read_csv("datasets/dataset_frijol_fix_obj_test_v4.csv")

print(f"Train shape: {df_train.shape}")
print(f"Test shape: {df_test.shape}")
print(f"Columnas: {df_train.columns.tolist()}")
print(f"\nDistribución de la clase objetivo (Train):")
print(df_train['tratamiento'].value_counts().sort_index())
print(f"\nDistribución de la clase objetivo (Test):")
print(df_test['tratamiento'].value_counts().sort_index())
# Out:
# Train shape: (234257, 16)
# Test shape: (95588, 16)
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'genotipo', 'tratamiento', 'object_id', 'split', 'int_444', 'int_475', 'int_531', 'int_560', 'int_650', 'int_668', 'int_705', 'int_717', 'int_740', 'int_848']
#
# Distribución de la clase objetivo (Train):
# tratamiento
# 1    68623
# 2    59593
# 3    46203
# 4    59838
# Name: count, dtype: int64
#
# Distribución de la clase objetivo (Test):
# tratamiento
# 1    28070
# 2    25360
# 3    20287
# 4    21871
# Name: count, dtype: int64

# %% [markdown]
# # 2. Preparación de los Datos
#
# Esta fase comprende la transformación de los datos crudos al formato requerido por la red neuronal.

# %% [markdown]
# ## 2.1. Codificación de la clase objetivo
#
# Las redes neuronales requieren que las etiquetas de clase sean enteros consecutivos comenzando desde 0. Se utiliza LabelEncoder para transformar los tratamientos [1, 2, 3, 4] a [0, 1, 2, 3].

# %%
# Definición de características predictoras (posición, genotipo y 10 bandas espectrales)
band_cols = ['int_444', 'int_475', 'int_531', 'int_560', 'int_650',
             'int_668', 'int_705', 'int_717', 'int_740', 'int_848']
feature_columns = ['pixel_relativo_x', 'pixel_relativo_y', 'genotipo'] + band_cols

X_train = df_train[feature_columns].values
X_test = df_test[feature_columns].values

y_train_raw = df_train['tratamiento'].values
y_test_raw = df_test['tratamiento'].values

print(f"Train features shape: {X_train.shape}")
print(f"Test features shape: {X_test.shape}")

# Codificación de etiquetas: convierte tratamientos [1,2,3,4] a [0,1,2,3]
label_encoder = LabelEncoder()
label_encoder.fit(y_train_raw)
y_train = label_encoder.transform(y_train_raw)
y_test = label_encoder.transform(y_test_raw)

print(f"Original labels: {np.unique(y_train_raw)}")
print(f"Encoded labels: {np.unique(y_train)}")
print(f"Label mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")
# Out:
# Train features shape: (234257, 13)
# Test features shape: (95588, 13)
# Original labels: [1 2 3 4]
# Encoded labels: [0 1 2 3]
# Label mapping: {np.int64(1): 0, np.int64(2): 1, np.int64(3): 2, np.int64(4): 3}

# %% [markdown]
# ## 2.2 División del dataset en entrenamiento y prueba
#
# El split ya fue realizado en `build_dataset.ipynb` de forma estratificada por objeto (70% train, 30% test). Los archivos `dataset_frijol_fix_obj_train.csv` y `dataset_frijol_fix_obj_test.csv` contienen los conjuntos ya separados, garantizando que ningún objeto aparezca en ambos conjuntos.

# %%
# División provista por build_dataset.ipynb (split estratificado por objeto)
# Los conjuntos ya están separados en los archivos CSV de entrada
print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Test set - Features: {X_test.shape}, Labels: {y_test.shape}")

print(f"\nTraining set class distribution:")
train_unique, train_counts = np.unique(y_train, return_counts=True)
for class_label, count in zip(train_unique, train_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_train)*100:.1f}%)")

print(f"\nTest set class distribution:")
test_unique, test_counts = np.unique(y_test, return_counts=True)
for class_label, count in zip(test_unique, test_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_test)*100:.1f}%)")
# Out:
# Training set - Features: (234257, 13), Labels: (234257,)
# Test set - Features: (95588, 13), Labels: (95588,)
#
# Training set class distribution:
#   Class 0: 68623 (29.3%)
#   Class 1: 59593 (25.4%)
#   Class 2: 46203 (19.7%)
#   Class 3: 59838 (25.5%)
#
# Test set class distribution:
#   Class 0: 28070 (29.4%)
#   Class 1: 25360 (26.5%)
#   Class 2: 20287 (21.2%)
#   Class 3: 21871 (22.9%)

# %% [markdown]
# ## 2.3. Estandarización de características

# %%
# Inicialización y aplicación del estandarizador
scaler = StandardScaler()

# Ajuste con datos de entrenamiento y transformación
X_train_scaled = scaler.fit_transform(X_train)
# Transformación del conjunto de prueba usando los mismos parámetros
X_test_scaled = scaler.transform(X_test)

# Conversión a tipos de datos compatibles con TensorFlow
X_train_scaled = X_train_scaled.astype(np.float32)
X_test_scaled = X_test_scaled.astype(np.float32)
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

print(f"\nData types after conversion:")
print(f"X_train: {X_train_scaled.dtype}, y_train: {y_train.dtype}")
print(f"X_test: {X_test_scaled.dtype}, y_test: {y_test.dtype}")
# Out:
# Data types after conversion:
# X_train: float32, y_train: int32
# X_test: float32, y_test: int32

# %% [markdown]
# ## 2.3 Convertir a formato dataset de TensorFlow

# %%
# Definición del tamaño de batch para el entrenamiento
BATCH_SIZE = 1000  # Número de muestras procesadas simultáneamente

# Creación del dataset de entrenamiento con optimizaciones
train_ds = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
train_ds = train_ds.shuffle(buffer_size=10000, seed=42)  # Mezcla con buffer para aleatoriedad
train_ds = train_ds.batch(BATCH_SIZE)                    # Agrupa en batches
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)           # Carga anticipada automática

# Creación del dataset de prueba (sin shuffling)
test_ds = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print(f"Training dataset created with batch size: {BATCH_SIZE}")
print(f"Test dataset created with batch size: {BATCH_SIZE}")

# Verificación de la estructura del dataset
for batch_features, batch_labels in train_ds.take(1):
    print(f"\nBatch verification:")
    print(f"Features batch shape: {batch_features.shape}")
    print(f"Labels batch shape: {batch_labels.shape}")
    print(f"Features dtype: {batch_features.dtype}")
    print(f"Labels dtype: {batch_labels.dtype}")
    break
# Out:
# Training dataset created with batch size: 1000
# Test dataset created with batch size: 1000
#
# Batch verification:
# Features batch shape: (1000, 13)
# Labels batch shape: (1000,)
# Features dtype: <dtype: 'float32'>
# Labels dtype: <dtype: 'int32'>

# %% [markdown]
# # 3. Construcción de la Arquitectura de Red Neuronal
#
# Se implementa una Red Neuronal Profunda (Deep Neural Network - DNN) utilizando la API funcional de Keras.

# %%
class InitialModel(Model):
  def __init__(self, input_shape=(13,), num_classes=4, **kwargs):
    super(InitialModel, self).__init__(**kwargs)
    self.input_shape_val = input_shape
    self.num_classes = num_classes
    
    # Capa de entrada
    self.input_layer = tf.keras.layers.InputLayer(input_shape=input_shape)
    
    # Primera capa oculta
    self.dense1 = tf.keras.layers.Dense(512, activation='relu')

    # Segunda capa oculta
    self.dense2 = tf.keras.layers.Dense(256, activation='relu')

    # Tecera capa oculta
    self.dense3 = tf.keras.layers.Dense(128, activation='relu')

     # Cuarta capa oculta
    self.dense4 = tf.keras.layers.Dense(128, activation='relu')

    # Quinta capa oculta
    self.dense5 = tf.keras.layers.Dense(64, activation='relu')
    
    # Capa de salida
    self.out = tf.keras.layers.Dense(num_classes, activation='softmax')

  def call(self, inputs, training=None):
    
    x = self.dense1(inputs)
    x = self.dense2(x)
    x = self.dense3(x)
    x = self.dense4(x)
    x = self.dense5(x)
    return self.out(x)

  def get_config(self):
    config = super(InitialModel, self).get_config()
    config.update({
        "input_shape": self.input_shape_val,
        "num_classes": self.num_classes,
    })
    return config

# Instanciar el modelo
model = InitialModel(input_shape=(13,), num_classes=4)

# %%
# Definición de la función de pérdida y optimizador
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()   # Para clasificación multiclase con etiquetas enteras
optimizer = tf.keras.optimizers.Adam()                          # Optimizador Adam con learning rate adaptativo

# %%
# Definición de métricas para monitorear el entrenamiento
train_loss = tf.keras.metrics.Mean(name='train_loss')                              # Pérdida promedio de entrenamiento
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy') # Exactitud de entrenamiento

test_loss = tf.keras.metrics.Mean(name='test_loss')                                # Pérdida promedio de validación
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')   # Exactitud de validación

# %%
# Implementación manual de callbacks para control del entrenamiento

best_val_loss = float('inf')  # Mejor pérdida de validación observada
best_weights = None           # Pesos del modelo con mejor rendimiento
patience_lr = 3               # Épocas sin mejora antes de reducir LR
patience_es = 4               # Épocas sin mejora antes de detener entrenamiento
lr_counter = 0                # Contador para reducción de LR
es_counter = 0                # Contador para early stopping
lr_factor = 0.2               # Factor de reducción del learning rate (nuevo_lr = lr × 0.2)
min_lr = 0.00001              # Learning rate mínimo permitido

print("Manual callbacks initialized:")
print(f"  LR reduction: patience={patience_lr}, factor={lr_factor}, min_lr={min_lr}")
print(f"  Early stopping: patience={patience_es}, restore_best_weights=True")
# Out:
# Manual callbacks initialized:
#   LR reduction: patience=3, factor=0.2, min_lr=1e-05
#   Early stopping: patience=4, restore_best_weights=True

# %% [markdown]
# # 4. Entrenamiento del Modelo
#
# Esta sección implementa el loop de entrenamiento personalizado con TensorFlow.

# %%
@tf.function  # Compilación a grafo estático para mayor eficiencia
def train_step(data, labels):
  """
  Ejecuta un paso de entrenamiento: forward pass, cálculo de pérdida y backpropagation.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  with tf.GradientTape() as tape:
    predictions = model(data, training=True)  # Forward pass con modo entrenamiento
    loss = loss_object(labels, predictions)   # Cálculo de pérdida
  gradients = tape.gradient(loss, model.trainable_variables)  # Backpropagation
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))  # Actualización de pesos

  train_loss(loss)                     # Actualización de métrica de pérdida
  train_accuracy(labels, predictions)  # Actualización de métrica de exactitud

# %%
@tf.function  # Compilación para optimización
def test_step(data, labels):
  """
  Ejecuta evaluación en conjunto de validación/prueba sin actualización de pesos.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  predictions = model(data, training=False)   # Forward pass sin dropout/regularización
  t_loss = loss_object(labels, predictions)   # Cálculo de pérdida

  test_loss(t_loss)                    # Actualización de métrica de pérdida
  test_accuracy(labels, predictions)   # Actualización de métrica de exactitud

# %%
EPOCHS = 100

train_batches = len(X_train_scaled) // BATCH_SIZE + (1 if len(X_train_scaled) % BATCH_SIZE != 0 else 0)
test_batches = len(X_test_scaled) // BATCH_SIZE + (1 if len(X_test_scaled) % BATCH_SIZE != 0 else 0)

print(f"Training for up to {EPOCHS} epochs (with early stopping)")
print(f"Training batches per epoch: {train_batches}")
print(f"Test batches per epoch: {test_batches}")

# Resetear métricasa antes del entrenamiento
train_loss.reset_state()
train_accuracy.reset_state()
test_loss.reset_state()
test_accuracy.reset_state()

for epoch in range(EPOCHS):
  print(f"\nEpoch {epoch+1}/{EPOCHS}")
  
  # Entrenamiento
  for batch_idx, (data, labels) in enumerate(train_ds):
    train_step(data, labels)

  # Prueba
  for test_data, test_labels in test_ds:
    test_step(test_data, test_labels)

  # Obtener métricas actuales
  current_train_loss = train_loss.result().numpy()
  current_train_acc = train_accuracy.result().numpy() * 100
  current_test_loss = test_loss.result().numpy()
  current_test_acc = test_accuracy.result().numpy() * 100
  current_lr = optimizer.learning_rate.numpy()

  # Resultados épocas
  template = 'Epoch {}, Loss: {:.4f}, Accuracy: {:.2f}%, Test Loss: {:.4f}, Test Accuracy: {:.2f}%, LR: {:.6f}'
  print(template.format(epoch+1,
                        current_train_loss,
                        current_train_acc,
                        current_test_loss,
                        current_test_acc,
                        current_lr))

  # Verificar si la pérdida en validación mejora
  if current_test_loss < best_val_loss:
    print(f"  ✓ Validation loss improved from {best_val_loss:.4f} to {current_test_loss:.4f}")
    best_val_loss = current_test_loss
    best_weights = model.get_weights()  # Salvar mejores pesos
    lr_counter = 0  # Resetear contador LR
    es_counter = 0  # Resetear contador early stopping
  else:
    lr_counter += 1
    es_counter += 1
    print(f"  ✗ Validation loss did not improve (best: {best_val_loss:.4f})")
    
    # Reducción del Learning rate
    if lr_counter >= patience_lr:
      old_lr = optimizer.learning_rate.numpy()
      new_lr = max(old_lr * lr_factor, min_lr)
      if new_lr != old_lr:
        optimizer.learning_rate.assign(new_lr)
        print(f"  → Reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
        lr_counter = 0  # Resetear contador LR
      else:
        print(f"  → Learning rate already at minimum ({min_lr:.6f})")
    
    # Lógica de Early stopping
    if es_counter >= patience_es:
      print(f"\n Early stopping triggered! No improvement for {patience_es} epochs.")
      print(f"  Restoring best weights from epoch {epoch+1-patience_es}")
      model.set_weights(best_weights)  # Restaurar lo pesos
      break

  # Resetear las métricas para la siguiente época
  train_loss.reset_state()
  train_accuracy.reset_state()
  test_loss.reset_state()
  test_accuracy.reset_state()

print("\nTraining completed!")
print(f"Best validation loss: {best_val_loss:.4f}")
# Out:
# Training for up to 100 epochs (with early stopping)
# Training batches per epoch: 235
# Test batches per epoch: 96
#
# Epoch 1/100
# Epoch 1, Loss: 1.0373, Accuracy: 63.87%, Test Loss: 12.3959, Test Accuracy: 22.88%, LR: 0.001000
#   ✓ Validation loss improved from inf to 12.3959
#
# Epoch 2/100
# Epoch 2, Loss: 1.1803, Accuracy: 58.65%, Test Loss: 10.7679, Test Accuracy: 22.88%, LR: 0.001000
#   ✓ Validation loss improved from 12.3959 to 10.7679
#
# Epoch 3/100
# Epoch 3, Loss: 1.0837, Accuracy: 60.60%, Test Loss: 12.6398, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 10.7679)
#
# Epoch 4/100
# Epoch 4, Loss: 1.1479, Accuracy: 50.82%, Test Loss: 14.8099, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 10.7679)
#
# Epoch 5/100
# Epoch 5, Loss: 1.1078, Accuracy: 55.71%, Test Loss: 9.3205, Test Accuracy: 22.88%, LR: 0.001000
#   ✓ Validation loss improved from 10.7679 to 9.3205
#
# Epoch 6/100
# Epoch 6, Loss: 1.0362, Accuracy: 59.12%, Test Loss: 12.7680, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.3205)
#
# Epoch 7/100
# Epoch 7, Loss: 1.0793, Accuracy: 53.47%, Test Loss: 15.0902, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 9.3205)
#
# Epoch 8/100
# Epoch 8, Loss: 1.0798, Accuracy: 60.89%, Test Loss: 8.1173, Test Accuracy: 22.88%, LR: 0.001000
#   ✓ Validation loss improved from 9.3205 to 8.1173
#
# Epoch 9/100
# Epoch 9, Loss: 1.0783, Accuracy: 53.55%, Test Loss: 9.0789, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 8.1173)
#
# Epoch 10/100
# Epoch 10, Loss: 1.0287, Accuracy: 61.08%, Test Loss: 10.5339, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 8.1173)
#
# Epoch 11/100
# Epoch 11, Loss: 1.1405, Accuracy: 51.58%, Test Loss: 16.1245, Test Accuracy: 22.88%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 8.1173)
#   → Reducing learning rate from 0.001000 to 0.000200
#
# Epoch 12/100
# Epoch 12, Loss: 2.3246, Accuracy: 32.64%, Test Loss: 1.6409, Test Accuracy: 22.84%, LR: 0.000200
#   ✓ Validation loss improved from 8.1173 to 1.6409
#
# Epoch 13/100
# Epoch 13, Loss: 1.4249, Accuracy: 32.47%, Test Loss: 1.4766, Test Accuracy: 23.92%, LR: 0.000200
#   ✓ Validation loss improved from 1.6409 to 1.4766
#
# Epoch 14/100
# Epoch 14, Loss: 1.3514, Accuracy: 38.55%, Test Loss: 1.5044, Test Accuracy: 22.86%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.4766)
#
# Epoch 15/100
# Epoch 15, Loss: 1.4260, Accuracy: 34.73%, Test Loss: 1.4683, Test Accuracy: 23.00%, LR: 0.000200
#   ✓ Validation loss improved from 1.4766 to 1.4683
#
# Epoch 16/100
# Epoch 16, Loss: 1.2965, Accuracy: 41.98%, Test Loss: 1.6218, Test Accuracy: 22.88%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.4683)
#
# Epoch 17/100
# Epoch 17, Loss: 1.3822, Accuracy: 33.36%, Test Loss: 1.4264, Test Accuracy: 22.96%, LR: 0.000200
#   ✓ Validation loss improved from 1.4683 to 1.4264
#
# Epoch 18/100
# Epoch 18, Loss: 1.3571, Accuracy: 33.04%, Test Loss: 1.4427, Test Accuracy: 22.89%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.4264)
#
# Epoch 19/100
# Epoch 19, Loss: 1.3968, Accuracy: 26.46%, Test Loss: 1.3864, Test Accuracy: 26.25%, LR: 0.000200
#   ✓ Validation loss improved from 1.4264 to 1.3864
#
# Epoch 20/100
# Epoch 20, Loss: 1.3513, Accuracy: 29.77%, Test Loss: 1.3890, Test Accuracy: 25.99%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3864)
#
# Epoch 21/100
# Epoch 21, Loss: 1.3345, Accuracy: 28.80%, Test Loss: 1.4075, Test Accuracy: 26.73%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3864)
#
# Epoch 22/100
# Epoch 22, Loss: 1.3606, Accuracy: 28.78%, Test Loss: 1.3944, Test Accuracy: 24.98%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 1.3864)
#   → Reducing learning rate from 0.000200 to 0.000040
#
# Epoch 23/100
# Epoch 23, Loss: 1.3630, Accuracy: 27.19%, Test Loss: 1.3617, Test Accuracy: 26.77%, LR: 0.000040
#   ✓ Validation loss improved from 1.3864 to 1.3617
#
# Epoch 24/100
# Epoch 24, Loss: 1.3214, Accuracy: 31.01%, Test Loss: 1.3453, Test Accuracy: 29.89%, LR: 0.000040
#   ✓ Validation loss improved from 1.3617 to 1.3453
#
# Epoch 25/100
# Epoch 25, Loss: 1.2942, Accuracy: 32.90%, Test Loss: 1.3380, Test Accuracy: 31.43%, LR: 0.000040
#   ✓ Validation loss improved from 1.3453 to 1.3380
#
# Epoch 26/100
# Epoch 26, Loss: 1.2789, Accuracy: 33.39%, Test Loss: 1.3349, Test Accuracy: 32.27%, LR: 0.000040
#   ✓ Validation loss improved from 1.3380 to 1.3349
#
# Epoch 27/100
# Epoch 27, Loss: 1.2701, Accuracy: 34.51%, Test Loss: 1.3326, Test Accuracy: 32.94%, LR: 0.000040
#   ✓ Validation loss improved from 1.3349 to 1.3326
#
# Epoch 28/100
# Epoch 28, Loss: 1.2631, Accuracy: 35.70%, Test Loss: 1.3304, Test Accuracy: 33.68%, LR: 0.000040
#   ✓ Validation loss improved from 1.3326 to 1.3304
#
# Epoch 29/100
# Epoch 29, Loss: 1.2568, Accuracy: 36.67%, Test Loss: 1.3278, Test Accuracy: 34.31%, LR: 0.000040
#   ✓ Validation loss improved from 1.3304 to 1.3278
#
# Epoch 30/100
# Epoch 30, Loss: 1.2502, Accuracy: 37.59%, Test Loss: 1.3253, Test Accuracy: 34.83%, LR: 0.000040
#   ✓ Validation loss improved from 1.3278 to 1.3253
#
# Epoch 31/100
# Epoch 31, Loss: 1.2446, Accuracy: 38.40%, Test Loss: 1.3224, Test Accuracy: 35.39%, LR: 0.000040
#   ✓ Validation loss improved from 1.3253 to 1.3224
#
# Epoch 32/100
# Epoch 32, Loss: 1.2389, Accuracy: 39.10%, Test Loss: 1.3196, Test Accuracy: 35.79%, LR: 0.000040
#   ✓ Validation loss improved from 1.3224 to 1.3196
#
# Epoch 33/100
# Epoch 33, Loss: 1.2333, Accuracy: 39.81%, Test Loss: 1.3165, Test Accuracy: 36.17%, LR: 0.000040
#   ✓ Validation loss improved from 1.3196 to 1.3165
#
# Epoch 34/100
# Epoch 34, Loss: 1.2274, Accuracy: 40.47%, Test Loss: 1.3130, Test Accuracy: 36.56%, LR: 0.000040
#   ✓ Validation loss improved from 1.3165 to 1.3130
#
# Epoch 35/100
# Epoch 35, Loss: 1.2218, Accuracy: 41.13%, Test Loss: 1.3096, Test Accuracy: 36.86%, LR: 0.000040
#   ✓ Validation loss improved from 1.3130 to 1.3096
#
# Epoch 36/100
# Epoch 36, Loss: 1.2161, Accuracy: 42.02%, Test Loss: 1.3062, Test Accuracy: 37.45%, LR: 0.000040
#   ✓ Validation loss improved from 1.3096 to 1.3062
#
# Epoch 37/100
# Epoch 37, Loss: 1.2103, Accuracy: 42.89%, Test Loss: 1.3029, Test Accuracy: 38.21%, LR: 0.000040
#   ✓ Validation loss improved from 1.3062 to 1.3029
#
# Epoch 38/100
# Epoch 38, Loss: 1.2047, Accuracy: 43.70%, Test Loss: 1.2998, Test Accuracy: 39.11%, LR: 0.000040
#   ✓ Validation loss improved from 1.3029 to 1.2998
#
# Epoch 39/100
# Epoch 39, Loss: 1.1992, Accuracy: 44.63%, Test Loss: 1.2975, Test Accuracy: 39.70%, LR: 0.000040
#   ✓ Validation loss improved from 1.2998 to 1.2975
#
# Epoch 40/100
# Epoch 40, Loss: 1.1937, Accuracy: 45.70%, Test Loss: 1.2952, Test Accuracy: 40.08%, LR: 0.000040
#   ✓ Validation loss improved from 1.2975 to 1.2952
#
# Epoch 41/100
# Epoch 41, Loss: 1.1882, Accuracy: 46.68%, Test Loss: 1.2931, Test Accuracy: 40.25%, LR: 0.000040
#   ✓ Validation loss improved from 1.2952 to 1.2931
#
# Epoch 42/100
# Epoch 42, Loss: 1.1825, Accuracy: 47.25%, Test Loss: 1.2915, Test Accuracy: 40.28%, LR: 0.000040
#   ✓ Validation loss improved from 1.2931 to 1.2915
#
# Epoch 43/100
# Epoch 43, Loss: 1.1771, Accuracy: 47.49%, Test Loss: 1.2896, Test Accuracy: 40.37%, LR: 0.000040
#   ✓ Validation loss improved from 1.2915 to 1.2896
#
# Epoch 44/100
# Epoch 44, Loss: 1.1712, Accuracy: 47.69%, Test Loss: 1.2882, Test Accuracy: 40.43%, LR: 0.000040
#   ✓ Validation loss improved from 1.2896 to 1.2882
#
# Epoch 45/100
# Epoch 45, Loss: 1.1658, Accuracy: 47.85%, Test Loss: 1.2866, Test Accuracy: 40.45%, LR: 0.000040
#   ✓ Validation loss improved from 1.2882 to 1.2866
#
# Epoch 46/100
# Epoch 46, Loss: 1.1604, Accuracy: 48.04%, Test Loss: 1.2850, Test Accuracy: 40.52%, LR: 0.000040
#   ✓ Validation loss improved from 1.2866 to 1.2850
#
# Epoch 47/100
# Epoch 47, Loss: 1.1548, Accuracy: 48.13%, Test Loss: 1.2836, Test Accuracy: 40.63%, LR: 0.000040
#   ✓ Validation loss improved from 1.2850 to 1.2836
#
# Epoch 48/100
# Epoch 48, Loss: 1.1498, Accuracy: 48.35%, Test Loss: 1.2823, Test Accuracy: 40.61%, LR: 0.000040
#   ✓ Validation loss improved from 1.2836 to 1.2823
#
# Epoch 49/100
# Epoch 49, Loss: 1.1442, Accuracy: 48.52%, Test Loss: 1.2809, Test Accuracy: 40.66%, LR: 0.000040
#   ✓ Validation loss improved from 1.2823 to 1.2809
#
# Epoch 50/100
# Epoch 50, Loss: 1.1393, Accuracy: 48.60%, Test Loss: 1.2794, Test Accuracy: 40.66%, LR: 0.000040
#   ✓ Validation loss improved from 1.2809 to 1.2794
#
# Epoch 51/100
# Epoch 51, Loss: 1.1338, Accuracy: 48.77%, Test Loss: 1.2781, Test Accuracy: 40.71%, LR: 0.000040
#   ✓ Validation loss improved from 1.2794 to 1.2781
#
# Epoch 52/100
# Epoch 52, Loss: 1.1287, Accuracy: 48.92%, Test Loss: 1.2771, Test Accuracy: 40.83%, LR: 0.000040
#   ✓ Validation loss improved from 1.2781 to 1.2771
#
# Epoch 53/100
# Epoch 53, Loss: 1.1241, Accuracy: 49.13%, Test Loss: 1.2762, Test Accuracy: 40.90%, LR: 0.000040
#   ✓ Validation loss improved from 1.2771 to 1.2762
#
# Epoch 54/100
# Epoch 54, Loss: 1.1194, Accuracy: 49.33%, Test Loss: 1.2754, Test Accuracy: 41.00%, LR: 0.000040
#   ✓ Validation loss improved from 1.2762 to 1.2754
#
# Epoch 55/100
# Epoch 55, Loss: 1.1149, Accuracy: 49.59%, Test Loss: 1.2746, Test Accuracy: 41.06%, LR: 0.000040
#   ✓ Validation loss improved from 1.2754 to 1.2746
#
# Epoch 56/100
# Epoch 56, Loss: 1.1105, Accuracy: 49.88%, Test Loss: 1.2744, Test Accuracy: 41.17%, LR: 0.000040
#   ✓ Validation loss improved from 1.2746 to 1.2744
#
# Epoch 57/100
# Epoch 57, Loss: 1.1062, Accuracy: 50.23%, Test Loss: 1.2736, Test Accuracy: 41.28%, LR: 0.000040
#   ✓ Validation loss improved from 1.2744 to 1.2736
#
# Epoch 58/100
# Epoch 58, Loss: 1.1017, Accuracy: 50.59%, Test Loss: 1.2734, Test Accuracy: 41.48%, LR: 0.000040
#   ✓ Validation loss improved from 1.2736 to 1.2734
#
# Epoch 59/100
# Epoch 59, Loss: 1.0977, Accuracy: 50.92%, Test Loss: 1.2734, Test Accuracy: 41.60%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.2734)
#
# Epoch 60/100
# Epoch 60, Loss: 1.0937, Accuracy: 51.20%, Test Loss: 1.2734, Test Accuracy: 41.67%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.2734)
#
# Epoch 61/100
# Epoch 61, Loss: 1.0899, Accuracy: 51.44%, Test Loss: 1.2741, Test Accuracy: 41.72%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 1.2734)
#   → Reducing learning rate from 0.000040 to 0.000010
#
# Epoch 62/100
# Epoch 62, Loss: 1.0894, Accuracy: 51.25%, Test Loss: 1.2545, Test Accuracy: 43.01%, LR: 0.000010
#   ✓ Validation loss improved from 1.2734 to 1.2545
#
# Epoch 63/100
# Epoch 63, Loss: 1.0697, Accuracy: 52.48%, Test Loss: 1.2448, Test Accuracy: 43.95%, LR: 0.000010
#   ✓ Validation loss improved from 1.2545 to 1.2448
#
# Epoch 64/100
# Epoch 64, Loss: 1.0592, Accuracy: 53.13%, Test Loss: 1.2396, Test Accuracy: 44.47%, LR: 0.000010
#   ✓ Validation loss improved from 1.2448 to 1.2396
#
# Epoch 65/100
# Epoch 65, Loss: 1.0530, Accuracy: 53.54%, Test Loss: 1.2365, Test Accuracy: 44.73%, LR: 0.000010
#   ✓ Validation loss improved from 1.2396 to 1.2365
#
# Epoch 66/100
# Epoch 66, Loss: 1.0490, Accuracy: 53.85%, Test Loss: 1.2347, Test Accuracy: 44.88%, LR: 0.000010
#   ✓ Validation loss improved from 1.2365 to 1.2347
#
# Epoch 67/100
# Epoch 67, Loss: 1.0459, Accuracy: 53.98%, Test Loss: 1.2336, Test Accuracy: 44.97%, LR: 0.000010
#   ✓ Validation loss improved from 1.2347 to 1.2336
#
# Epoch 68/100
# Epoch 68, Loss: 1.0431, Accuracy: 54.19%, Test Loss: 1.2329, Test Accuracy: 45.04%, LR: 0.000010
#   ✓ Validation loss improved from 1.2336 to 1.2329
#
# Epoch 69/100
# Epoch 69, Loss: 1.0410, Accuracy: 54.29%, Test Loss: 1.2324, Test Accuracy: 45.01%, LR: 0.000010
#   ✓ Validation loss improved from 1.2329 to 1.2324
#
# Epoch 70/100
# Epoch 70, Loss: 1.0390, Accuracy: 54.43%, Test Loss: 1.2320, Test Accuracy: 44.98%, LR: 0.000010
#   ✓ Validation loss improved from 1.2324 to 1.2320
#
# Epoch 71/100
# Epoch 71, Loss: 1.0374, Accuracy: 54.52%, Test Loss: 1.2317, Test Accuracy: 44.96%, LR: 0.000010
#   ✓ Validation loss improved from 1.2320 to 1.2317
#
# Epoch 72/100
# Epoch 72, Loss: 1.0352, Accuracy: 54.61%, Test Loss: 1.2315, Test Accuracy: 44.97%, LR: 0.000010
#   ✓ Validation loss improved from 1.2317 to 1.2315
#
# Epoch 73/100
# Epoch 73, Loss: 1.0337, Accuracy: 54.72%, Test Loss: 1.2313, Test Accuracy: 44.99%, LR: 0.000010
#   ✓ Validation loss improved from 1.2315 to 1.2313
#
# Epoch 74/100
# Epoch 74, Loss: 1.0319, Accuracy: 54.83%, Test Loss: 1.2311, Test Accuracy: 44.98%, LR: 0.000010
#   ✓ Validation loss improved from 1.2313 to 1.2311
#
# Epoch 75/100
# Epoch 75, Loss: 1.0305, Accuracy: 54.92%, Test Loss: 1.2310, Test Accuracy: 45.00%, LR: 0.000010
#   ✓ Validation loss improved from 1.2311 to 1.2310
#
# Epoch 76/100
# Epoch 76, Loss: 1.0289, Accuracy: 55.02%, Test Loss: 1.2309, Test Accuracy: 45.00%, LR: 0.000010
#   ✓ Validation loss improved from 1.2310 to 1.2309
#
# Epoch 77/100
# Epoch 77, Loss: 1.0272, Accuracy: 55.12%, Test Loss: 1.2309, Test Accuracy: 44.96%, LR: 0.000010
#   ✓ Validation loss improved from 1.2309 to 1.2309
#
# Epoch 78/100
# Epoch 78, Loss: 1.0258, Accuracy: 55.19%, Test Loss: 1.2308, Test Accuracy: 44.99%, LR: 0.000010
#   ✓ Validation loss improved from 1.2309 to 1.2308
#
# Epoch 79/100
# Epoch 79, Loss: 1.0247, Accuracy: 55.26%, Test Loss: 1.2308, Test Accuracy: 44.95%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.2308)
#
# Epoch 80/100
# Epoch 80, Loss: 1.0232, Accuracy: 55.36%, Test Loss: 1.2309, Test Accuracy: 44.94%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.2308)
#
# Epoch 81/100
# Epoch 81, Loss: 1.0217, Accuracy: 55.43%, Test Loss: 1.2308, Test Accuracy: 44.96%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.2308)
#   → Learning rate already at minimum (0.000010)
#
# Epoch 82/100
# Epoch 82, Loss: 1.0206, Accuracy: 55.52%, Test Loss: 1.2308, Test Accuracy: 44.98%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 1.2308)
#   → Learning rate already at minimum (0.000010)
#
#  Early stopping triggered! No improvement for 4 epochs.
#   Restoring best weights from epoch 78
#
# Training completed!
# Best validation loss: 1.2308

# %% [markdown]
# ## 4.1. Persistencia del modelo entrenado
#
# Se guarda el modelo en formato Keras (.keras) junto con los objetos de preprocesamiento necesarios para realizar predicciones futuras.

# %%
# Guardar el modelo entrenado en formato Keras nativo
model.save("models/frijol/frijol_model_dnn_v4.keras")
print("Model saved successfully as 'models/frijol/frijol_model_dnn_v4.keras'")

# Guardar objetos de preprocesamiento (scaler, encoder) para uso en producción
with open('preprocessing_objects_frijol.pkl', 'wb') as f:
    pickle.dump({
        'scaler': scaler,                    # Estandarizador ajustado
        'label_encoder': label_encoder,      # Codificador de etiquetas
        'feature_columns': feature_columns   # Lista de características esperadas
    }, f)

print("Preprocessing objects saved as 'preprocessing_objects_frijol.pkl'")
# Out:
# Model saved successfully as 'models/frijol/frijol_model_dnn_v4.keras'
# Preprocessing objects saved as 'preprocessing_objects_frijol.pkl'

# %% [markdown]
# # 5. Evaluación del Modelo
#
# Esta sección carga el modelo entrenado y evalúa su rendimiento mediante:
# - **Generación de predicciones**: En conjuntos de entrenamiento y prueba
# - **Métricas de clasificación**: Accuracy, Precision, F1-Score, Kappa
# - **Matrices de confusión**: Visualización de aciertos y errores por clase
# - **Análisis de curvas de aprendizaje**: Evolución de pérdida y exactitud durante entrenamiento

# %%
# Carga del modelo entrenado desde archivo
trained_model = tf.keras.models.load_model('models/frijol/frijol_model_dnn_v4.keras', custom_objects={'InitialModel': InitialModel})
# Out:
# WARNING:tensorflow:From d:\1. Biblioteca Usuario\Documents\UNAL\MAESTRÍA\TESIS\disease-detection-multispectral-images\.venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# Generación de predicciones en el conjunto de prueba
print("Realizando predicciones en Test...")
y_pred_probs = trained_model.predict(X_test_scaled)  # Probabilidades para cada clase
y_pred = np.argmax(y_pred_probs, axis=1)             

# Generación de predicciones en el conjunto de entrenamiento
print("Realizando predicciones en Train...")
y_train_pred_probs = trained_model.predict(X_train_scaled)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)
# Out:
# Realizando predicciones en Test...
# 2988/2988 ━━━━━━━━━━━━━━━━━━━━ 2s 710us/step
# Realizando predicciones en Train...
# 7321/7321 ━━━━━━━━━━━━━━━━━━━━ 5s 705us/step

# %% [markdown]
# ## 5.1. Guardar predicciones

# %%
# Guardar predicciones del conjunto de prueba
joblib.dump(y_pred, "results/predictions/frijol/test/predicciones_dnn_test_v4.pkl")
print("✓ Predicciones de prueba guardadas en: results/predictions/frijol/test/predicciones_dnn_test_v4.pkl")

# Guardar predicciones del conjunto de entrenamiento
joblib.dump(y_train_pred, "results/predictions/frijol/train/predicciones_dnn_train_v4.pkl")
print("✓ Predicciones de entrenamiento guardadas en: results/predictions/frijol/train/predicciones_dnn_train_v4.pkl")

# Guardar probabilidades predichas
joblib.dump(y_pred_probs, "results/predictions/frijol/test/predicciones_dnn_test_probs_v4.pkl")
joblib.dump(y_train_pred_probs, "results/predictions/frijol/train/predicciones_dnn_train_probs_v4.pkl")
print("✓ Probabilidades de predicción guardadas exitosamente")
# Out:
# ✓ Predicciones de prueba guardadas en: results/predictions/frijol/test/predicciones_dnn_test_v4.pkl
# ✓ Predicciones de entrenamiento guardadas en: results/predictions/frijol/train/predicciones_dnn_train_v4.pkl
# ✓ Probabilidades de predicción guardadas exitosamente

# %% [markdown]
# # 6. Resultados

# %%
# Cálculo de métricas para el conjunto de prueba (Test)
accuracy = accuracy_score(y_test, y_pred)                        # Exactitud: proporción de predicciones correctas
precision = precision_score(y_test, y_pred, average='weighted')  # Precisión ponderada por clase
f1 = f1_score(y_test, y_pred, average='weighted')                # F1-Score: media armónica de precisión y recall
kappa = cohen_kappa_score(y_test, y_pred)                        # Kappa de Cohen: acuerdo ajustado por azar

# Cálculo de métricas para el conjunto de entrenamiento (Train)
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, average='weighted')
train_f1 = f1_score(y_train, y_train_pred, average='weighted')
train_kappa = cohen_kappa_score(y_train, y_train_pred)

# Presentación comparativa de métricas
print("-" * 65)
print(f"{'Métrica':<20} | {'Train':<20} | {'Test':<20}")
print("-" * 65)
print(f"{'Accuracy':<20} | {train_accuracy:<20.4f} | {accuracy:<20.4f}")
print(f"{'Precision':<20} | {train_precision:<20.4f} | {precision:<20.4f}")
print(f"{'F1-Score':<20} | {train_f1:<20.4f} | {f1:<20.4f}")
print(f"{'Kappa Score':<20} | {train_kappa:<20.4f} | {kappa:<20.4f}")
print("-" * 65)
# Out:
# -----------------------------------------------------------------
# Métrica              | Train                | Test
# -----------------------------------------------------------------
# Accuracy             | 0.5600               | 0.4499
# Precision            | 0.5562               | 0.4511
# F1-Score             | 0.5544               | 0.4429
# Kappa Score          | 0.4069               | 0.2627
# -----------------------------------------------------------------

# %%
# Obtención de nombres de clases para los reportes
target_names = label_encoder.classes_.astype(str)

# Reporte de clasificación para conjunto de prueba
print("\nReporte de Clasificación (Test):")
print(classification_report(y_test, y_pred, target_names=target_names))

# Reporte de clasificación para conjunto de entrenamiento
print("\nReporte de Clasificación (Train):")
print(classification_report(y_train, y_train_pred, target_names=target_names))
# Out:
# Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#            1       0.50      0.56      0.53     28070
#            2       0.53      0.36      0.43     25360
#            3       0.30      0.25      0.27     20287
#            4       0.44      0.59      0.50     21871
#
#     accuracy                           0.45     95588
#    macro avg       0.44      0.44      0.43     95588
# weighted avg       0.45      0.45      0.44     95588
#
#
# Reporte de Clasificación (Train):
#               precision    recall  f1-score   support
#
#            1       0.62      0.67      0.65     68623
#            2       0.62      0.52      0.56     59593
#            3       0.41      0.33      0.37     46203
#            4       0.53      0.65      0.59     59838
#
#     accuracy                           0.56    234257
#    macro avg       0.55      0.54      0.54    234257
# weighted avg       0.56      0.56      0.55    234257

# %%
# Visualización comparativa de matrices de confusión
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']

# Matriz de confusión para conjunto de entrenamiento
cm_train = confusion_matrix(y_train, y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=tratamiento_labels)
disp_train.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Matriz de Confusión DNN - Entrenamiento', fontsize=14)
axes[0].set_xlabel('Etiqueta predicha', fontsize=12)
axes[0].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[0].grid(False)

# Matriz de confusión para conjunto de prueba
cm_test = confusion_matrix(y_test, y_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=tratamiento_labels)
disp_test.plot(ax=axes[1], cmap='Blues', colorbar=False)
axes[1].set_title('Matriz de Confusión DNN - Testing', fontsize=14)
axes[1].set_xlabel('Etiqueta predicha', fontsize=12)
axes[1].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[1].grid(False)

plt.tight_layout()
plt.show()
