# %% [markdown]
# <div style="font-family:'Georgia','Times New Roman',Times,serif; width:80%; margin:20px auto; padding:10px 20px 20px 20px; background:#ffffff; border-left:20px solid #003366; box-shadow:0 5px 20px rgba(0,0,0,0.1); text-align:center; border-radius:8px;">
#
#   <div style="display:flex; align-items:center; justify-content:center; gap:20px; margin-bottom:15px; padding-bottom:1px; border-bottom:2px solid #eeeeee;">
#     <img src="assets/Logotipo_de_la_Universidad_Nacional_de_Colombia.svg.png" alt="Logo Universidad" style="max-width:80px; height:auto;">
#     <div style="font-size:1.1em; color:#003366; font-weight:bold; text-align:left;">Universidad Nacional de Colombia</div>
#   </div>
#
#   <h1 style="color:#003366; font-size:2.2em; margin:0.6em 0; font-weight:bold; line-height:1.2;">Detección de enfermedades en plantas de maíz y fríjol común con Inteligencia Artificial e imágenes multiespectrales</h1>
#   <h2 style="color:#444444; font-size:1.4em; margin-bottom:0.8em; font-weight:normal; font-style:italic;">Análisis exploratorio de datos y entrenamiento de modelos de aprendizaje de máquina con datos de fríjol — Dataset v2</h2>
#
#   <div style="margin-bottom:0em; font-size:1.1em; color:#222222;">
#     <p style="text-align:center; margin:0;"><strong>Autor:</strong> Selene Solano Vera</p>
#   </div>
#
#   <div style="margin:1.0em 0 1.0em 0; padding:0.8em 0; color:#666666; font-size:1em;">Medellín, Abril de 2026</div>
#
#   <div style="height:0.1rem;"></div>
#
# </div>

# %% [markdown]
# # Utilidades y Configuración Inicial
#
# Esta sección incluye la importación de bibliotecas necesarias y la configuración del entorno de trabajo para el análisis exploratorio de datos y el entrenamiento de modelos de aprendizaje automático. Se utiliza el dataset v2 generado en `build_dataset_v2.ipynb`, el cual tiene formato largo (una fila por píxel por banda).

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import joblib
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, ConfusionMatrixDisplay, accuracy_score, f1_score
import warnings
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
import math
import os
import pickle
from datetime import datetime
import time

# %% [markdown]
# ## Configurar estilo de visualización

# %%
sns.set_theme(style="whitegrid", palette="viridis")
plt.rcParams['figure.figsize'] = (12, 7)
plt.rcParams['axes.titlesize'] = 18
plt.rcParams['axes.labelsize'] = 14
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Definición del Problema y Recopilación de Datos
#
# **Pregunta de Investigación:** ¿Es posible determinar el nivel de deficiencia de fósforo en plantas de fríjol mediante el análisis de la intensidad de reflectancia en imágenes multiespectrales?
#
# **Hipótesis:** Las plantas con diferentes niveles de deficiencia de fósforo presentarán patrones distintivos en su reflectancia espectral que permitirán su clasificación automática.
#
# **Descripción de los datos**
#
# - Variable Objetivo:
#     - Tratamiento 1: 25% de la dosis óptima de fósforo (deficiencia severa)
#     - Tratamiento 2: 50% de la dosis óptima de fósforo (deficiencia moderada)
#     - Tratamiento 3: 75% de la dosis óptima de fósforo (deficiencia leve)
#     - Tratamiento 4: 100% de la dosis óptima de fósforo (control saludable)
#
# - Variables Predictoras:
#     - `pixel_relativo_x/y`: Coordenadas relativas al centroide de la planta
#     - `intensidad (int_*)`: Valor de reflectancia espectral por banda
#     - `genotipo`: Identificador del genotipo (1-8)
#
# **Dataset v2:** Generado con split por objeto (70/30), formato largo convertido a formato ancho con una columna `int_{longitud_de_onda}` por banda espectral.

# %% [markdown]
# # 2. Carga y Primera Inspección de Datos

# %% [markdown]
# ## 2.1. Leer datos de fríjol (v2)
#
# Se cargan los datos de la versión 2 del dataset. Este dataset tiene formato **largo** (una fila por píxel por banda). Se trabaja directamente con este formato, usando `banda` e `intensidad` como variables predictoras.

# %%
# Cargar datos en formato largo (una fila por píxel por banda)
data_train = pd.read_csv("datasets/dataset_frijol_fix_obj_train_v2.csv")
data_test  = pd.read_csv("datasets/dataset_frijol_fix_obj_test_v2.csv")

print(f"Train: {data_train.shape}")
print(f"Test:  {data_test.shape}")
print(f"Columnas: {list(data_train.columns)}")
# Out:
# Train: (2271930, 8)
# Test:  (1025150, 8)
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'tratamiento', 'banda', 'object_id', 'split']

# %% [markdown]
# ## 2.2. Unión de datasets

# %%
# Dataset completo para EDA (train + test)
data = pd.concat([data_train, data_test], ignore_index=True)
print(f"Dataset completo: {data.shape}")
print(f"Columnas: {list(data.columns)}")
print(f"Valores únicos de 'banda': {sorted(data['banda'].unique())}")
# Out:
# Dataset completo: (3297080, 8)
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'tratamiento', 'banda', 'object_id', 'split']
# Valores únicos de 'banda': [np.int64(444), np.int64(475), np.int64(531), np.int64(560), np.int64(650), np.int64(668), np.int64(705), np.int64(717), np.int64(740), np.int64(848)]

# %% [markdown]
# ## 2.4. Optimización de memoria

# %%
def reduce_mem_usage(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f'Uso de memoria del dataframe: {start_mem:.2f} MB')
    for col in df.columns:
        col_type = df[col].dtype
        if col_type != object and col_type.name != 'category':
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                else:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        elif col_type == 'object':
            if len(df[col].unique()) / len(df[col]) < 0.5:
                df[col] = df[col].astype('category')
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f'Uso de memoria tras optimización: {end_mem:.2f} MB')
        print(f'Reducción del {100 * (start_mem - end_mem) / start_mem:.1f}%')
    return df

df_optimizado = reduce_mem_usage(data)
# Out:
# Uso de memoria del dataframe: 201.24 MB
# Uso de memoria tras optimización: 50.32 MB
# Reducción del 75.0%

# %% [markdown]
# ## 2.5. Exploración inicial

# %%
data.head()
# Out:
#    pixel_relativo_x  pixel_relativo_y  intensidad  genotipo  tratamiento  \
# 0              3.53        -34.720001           2         4            2
# 1              4.53        -34.720001           2         4            2
# 2              5.53        -34.720001           1         4            2
# 3              6.53        -34.720001           1         4            2
# 4              2.53        -33.720001           2         4            2
#
#    banda                object_id  split
# 0    444  REF__0000_T2R1__obj_001  train
# 1    444  REF__0000_T2R1__obj_001  train
# 2    444  REF__0000_T2R1__obj_001  train
# 3    444  REF__0000_T2R1__obj_001  train
# 4    444  REF__0000_T2R1__obj_001  train

# %%
data.tail()
# Out:
#          pixel_relativo_x  pixel_relativo_y  intensidad  genotipo  \
# 3297075              8.56             20.73          22         6
# 3297076              5.56             21.73          22         6
# 3297077              6.56             21.73          21         6
# 3297078              7.56             21.73          21         6
# 3297079              8.56             21.73          21         6
#
#          tratamiento  banda                object_id split
# 3297075            4    848  REF__0017_T4R3__obj_020  test
# 3297076            4    848  REF__0017_T4R3__obj_020  test
# 3297077            4    848  REF__0017_T4R3__obj_020  test
# 3297078            4    848  REF__0017_T4R3__obj_020  test
# 3297079            4    848  REF__0017_T4R3__obj_020  test

# %%
print(f"Tamaño del dataset: {data.shape}")
# Out:
# Tamaño del dataset: (3297080, 8)

# %%
print(f"Columnas:\n {data.columns.tolist()}")
# Out:
# Columnas:
#  ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'tratamiento', 'banda', 'object_id', 'split']

# %%
data.describe()
# Out:
#        pixel_relativo_x  pixel_relativo_y    intensidad      genotipo  \
# count      3.297080e+06      3.297080e+06  3.297080e+06  3.297080e+06
# mean      -9.623253e-04     -3.427075e-02  7.827503e+00  4.562489e+00
# std        9.089346e+00      1.077204e+01  7.690755e+00  2.266736e+00
# min       -3.108000e+01     -4.513000e+01  0.000000e+00  1.000000e+00
# 25%       -6.350000e+00     -7.330000e+00  2.000000e+00  3.000000e+00
# 50%       -1.000000e-01      6.300000e-01  5.000000e+00  5.000000e+00
# 75%        6.322500e+00      7.860000e+00  1.200000e+01  6.000000e+00
# max        3.707000e+01      3.330000e+01  3.900000e+01  8.000000e+00
#
#         tratamiento         banda
# count  3.297080e+06  3.297080e+06
# mean   2.403208e+00  6.338000e+02
# std    1.149775e+00  1.215893e+02
# min    1.000000e+00  4.440000e+02
# 25%    1.000000e+00  5.310000e+02
# 50%    2.000000e+00  6.590000e+02
# 75%    3.000000e+00  7.170000e+02
# max    4.000000e+00  8.480000e+02

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3297080 entries, 0 to 3297079
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   pixel_relativo_x  float32
#  1   pixel_relativo_y  float32
#  2   intensidad        int8
#  3   genotipo          int8
#  4   tratamiento       int8
#  5   banda             int16
#  6   object_id         category
#  7   split             category
# dtypes: category(2), float32(2), int16(1), int8(3)
# memory usage: 50.3 MB

# %%
data.isnull().sum()
# Out:
# pixel_relativo_x    0
# pixel_relativo_y    0
# intensidad          0
# genotipo            0
# tratamiento         0
# banda               0
# object_id           0
# split               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 3. Análisis Exploratorio de Datos (EDA)

# %%
columnas_numericas = ["pixel_relativo_x", "pixel_relativo_y", "banda", "intensidad"]
columnas_categoricas = ["genotipo", "tratamiento"]

# %% [markdown]
# ## 3.1. Análisis univariado de variables categóricas

# %%
print("Valores únicos de las variables categóricas:\n")
for variable in columnas_categoricas:
    print(f"{variable}: {data[variable].unique()}")
# Out:
# Valores únicos de las variables categóricas:
#
# genotipo: [4 5 3 8 2 6 7 1]
# tratamiento: [2 1 3 4]

# %%
data['genotipo'].value_counts()
# Out:
# genotipo
# 5    442670
# 6    442160
# 4    433370
# 8    432390
# 3    398280
# 1    395080
# 7    377560
# 2    375570
# Name: count, dtype: int64

# %%
data['tratamiento'].value_counts()
# Out:
# tratamiento
# 1    966930
# 2    849530
# 4    815720
# 3    664900
# Name: count, dtype: int64

# %%
for col in columnas_categoricas:
    plt.figure(figsize=(10, 6))
    ax = sns.countplot(x=col, data=data, order=data[col].value_counts().index, palette='viridis')
    ax.set_title(f'Distribución de la Variable: {col}', fontsize=16, fontweight='bold')
    ax.set_xlabel(f'Categorías de {col}', fontsize=12)
    ax.set_ylabel('Frecuencia (Conteo)', fontsize=12)
    for p in ax.patches:
        ax.annotate(f'{p.get_height():,}',
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center',
                    xytext=(0, 9),
                    textcoords='offset points')
    plt.tight_layout()
    plt.show()

# %%
counts = data['tratamiento'].value_counts()
colors = sns.color_palette('viridis', len(counts))
explode = [0.1 if i == counts.idxmax() else 0 for i, _ in enumerate(counts)]

plt.figure(figsize=(8, 8))
plt.pie(counts,
        labels=counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=colors,
        explode=explode,
        shadow=True,
        textprops={'fontsize': 12})
plt.title('Proporción de la Clase Objetivo', fontsize=16, fontweight='bold')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## 3.2. Análisis de reflectancia espectral por tratamiento

# %%
data_long_sample = data.sample(n=min(50000, len(data)), random_state=42)

# %%
plt.figure(figsize=(14, 6))
ax = sns.boxplot(
    data=data_long_sample,
    x="banda",
    y="intensidad",
    hue="tratamiento",
    palette="viridis",
)
ax.set_title("Distribución de intensidad por banda y tratamiento (fríjol)", fontsize=15)
ax.set_xlabel("Banda espectral")
ax.set_ylabel("Intensidad")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.3. Matriz de correlación entre variables numéricas

# %%
corr_matrix = data[columnas_numericas].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlación entre variables numéricas (fríjol v2)", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Preprocesamiento de Datos

# %% [markdown]
# ## 4.1 Definición de características y grupo

# %%
# Columnas de features y objetivo
feature_cols = ["pixel_relativo_x", "pixel_relativo_y", "genotipo", "banda", "intensidad"]
target_col = "tratamiento"

# Columna de agrupación para evitar fuga de datos
if "object_id" in data_train.columns and "object_id" in data_test.columns:
    group_col = "object_id"
else:
    raise ValueError("No se encontró columna de grupo 'object_id' en el dataset.")

required_cols = feature_cols + [target_col, group_col]
missing_train = [c for c in required_cols if c not in data_train.columns]
missing_test  = [c for c in required_cols if c not in data_test.columns]
if missing_train or missing_test:
    raise ValueError(f"Faltan columnas. train: {missing_train}, test: {missing_test}")

# Separar en conjuntos de entrenamiento y prueba
X_train = data_train[feature_cols].copy()
y_train = data_train[target_col].copy()
groups_train = data_train[group_col].copy()

X_test = data_test[feature_cols].copy()
y_test = data_test[target_col].copy()
groups_test = data_test[group_col].copy()

print(f"Train: {X_train.shape[0]:,} filas | Test: {X_test.shape[0]:,} filas")
print(f"Features ({len(feature_cols)}): {feature_cols}")
print(f"Columna de grupo usada: {group_col}")
# Out:
# Train: 2,271,930 filas | Test: 1,025,150 filas
# Features (5): ['pixel_relativo_x', 'pixel_relativo_y', 'genotipo', 'banda', 'intensidad']
# Columna de grupo usada: object_id

# %%
# Validación del split por grupos
overlap_groups = set(groups_train.astype(str)).intersection(set(groups_test.astype(str)))
print(f"Grupos únicos train: {groups_train.nunique():,}")
print(f"Grupos únicos test:  {groups_test.nunique():,}")
print(f"Cruce de grupos train/test: {len(overlap_groups)}")
if len(overlap_groups) > 0:
    print("⚠️ Advertencia: hay fuga de grupos entre train y test")
else:
    print("✅ Sin fuga de grupos entre train y test")
# Out:
# Grupos únicos train: 267
# Grupos únicos test:  115
# Cruce de grupos train/test: 0
# ✅ Sin fuga de grupos entre train y test

# %% [markdown]
# ## 4.2 Balanceo de características `genotipo`
#
# Se aplica undersampling por genotipo al conjunto de entrenamiento para evitar sesgos hacia genotipos con más muestras.

# %%
train_df = pd.concat([X_train, y_train], axis=1).copy()
train_df["__group_id__"] = groups_train.values

print("Distribución de 'genotipo' en el set de entrenamiento (ANTES):")
print(train_df['genotipo'].value_counts())
print("-" * 30)

min_size_train = int(train_df['genotipo'].value_counts().min())
train_df_resampled = train_df.groupby('genotipo', group_keys=False).sample(
    n=min_size_train, random_state=42
).reset_index(drop=True)

print("Distribución de 'genotipo' en el set de entrenamiento (DESPUÉS):")
print(train_df_resampled['genotipo'].value_counts())
print("-" * 30)

X_train_resampled = train_df_resampled.drop(columns=['tratamiento', '__group_id__'])
y_train_resampled = train_df_resampled['tratamiento']
groups_train_resampled = train_df_resampled['__group_id__']
# Out:
# Distribución de 'genotipo' en el set de entrenamiento (ANTES):
# genotipo
# 4    339220
# 6    317950
# 2    294480
# 1    294120
# 7    281050
# 5    270090
# 3    243160
# 8    231860
# Name: count, dtype: int64
# ------------------------------
# Distribución de 'genotipo' en el set de entrenamiento (DESPUÉS):
# genotipo
# 1    231860
# 2    231860
# 3    231860
# 4    231860
# 5    231860
# 6    231860
# 7    231860
# 8    231860
# Name: count, dtype: int64
# ------------------------------

# %%
print("Distribución de 'tratamiento' en el set de entrenamiento (DESPUÉS del balanceo):")
print(y_train_resampled.value_counts())
# Out:
# Distribución de 'tratamiento' en el set de entrenamiento (DESPUÉS del balanceo):
# tratamiento
# 2    490435
# 1    488152
# 4    470163
# 3    406130
# Name: count, dtype: int64

# %% [markdown]
# ## 4.3 Normalizar datos
#
# La normalización mediante MinMaxScaler transforma las características al rango [0, 1].

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_resampled)
X_test_scaled  = scaler.transform(X_test)

# %% [markdown]
# ## 4.4 Codificación de tratamiento (para XGBoost)
#
# XGBoost requiere etiquetas de clase como enteros consecutivos comenzando desde 0.

# %%
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train_resampled)
y_test_encoded  = le.transform(y_test)

# %% [markdown]
# ## 4.5 Persistencia de datos procesados

# %%
os.makedirs("results/data", exist_ok=True)
np.savez(
    "results/data/train_data_frijol_v2.npz",
    X_train_scaled=X_train_scaled,
    X_test_scaled=X_test_scaled,
    y_train=y_train,
    y_test=y_test,
    X_train_resampled=X_train_resampled,
    y_train_resampled=y_train_resampled,
    y_train_encoded=y_train_encoded,
    y_test_encoded=y_test_encoded,
    groups_train_resampled=groups_train_resampled,
)
print("✅ Datos procesados guardados en results/data/train_data_frijol_v2.npz")
# Out:
# ✅ Datos procesados guardados en results/data/train_data_frijol_v2.npz

# %% [markdown]
# ## 4.6 Cargar datos preprocesados (opcional)

# %%
train_data = np.load("results/data/train_data_frijol_v2.npz", allow_pickle=True)
X_train_scaled          = train_data["X_train_scaled"]
X_test_scaled           = train_data["X_test_scaled"]
y_train                 = train_data["y_train"]
y_test                  = train_data["y_test"]
X_train_resampled       = train_data["X_train_resampled"]
y_train_resampled       = train_data["y_train_resampled"]
y_train_encoded         = train_data["y_train_encoded"]
y_test_encoded          = train_data["y_test_encoded"]
groups_train_resampled  = train_data["groups_train_resampled"] if "groups_train_resampled" in train_data.files else None

# %% [markdown]
# # 5. Entrenamiento de Modelos de Aprendizaje Automático
#
# Se implementan y entrenan cuatro algoritmos de clasificación:
# 1. **K-Nearest Neighbors (KNN)**: Clasificador basado en instancias
# 2. **Random Forest (RF)**: Ensemble de árboles de decisión
# 3. **XGBoost**: Gradient boosting optimizado
# 4. **MLP**: Red neuronal artificial

# %%
def medir_tiempo_entrenamiento(func):
    def wrapper(*args, nombre_modelo=None, **kwargs):
        modelo = args[0] if args else kwargs.get("estimator")
        etiqueta = nombre_modelo or (modelo.__class__.__name__ if modelo is not None else func.__name__)
        inicio = time.time()
        resultado = func(*args, **kwargs)
        fin = time.time()
        print(f"⏱️ {etiqueta} entrenado en {fin - inicio:.2f}s")
        return resultado
    return wrapper

@medir_tiempo_entrenamiento
def train_model(estimator):
    estimator.fit(X_train_scaled, y_train_resampled)
    return estimator

os.makedirs("models/frijol", exist_ok=True)

# %% [markdown]
# ## 5.1 K-Nearest Neighbors (KNN)

# %%
knn = KNeighborsClassifier(n_jobs=-1)

# %%
knn_classifier = train_model(knn)
# Out:
# ⏱️ KNeighborsClassifier entrenado en 3.76s

# %%
joblib.dump(knn_classifier, 'models/frijol/modelo_knn_v2.pkl')
# Out:
# ['models/frijol/modelo_knn_v2.pkl']

# %% [markdown]
# ## 5.2 Random Forest (RF)

# %%
rfc = RandomForestClassifier(n_jobs=1, random_state=12)

# %%
rf_classifier = train_model(rfc)
# Out:
# ⏱️ RandomForestClassifier entrenado en 631.69s

# %%
joblib.dump(rf_classifier, 'models/frijol/modelo_rfc_v2.pkl')
# Out:
# ['models/frijol/modelo_rfc_v2.pkl']

# %% [markdown]
# ## 5.3 XGBoost

# %%
xgbc = xgb.XGBClassifier(objective='multi:softmax', random_state=42)

# %%
inicio = time.time()
xgb_classifier = xgbc.fit(X_train_scaled, y_train_encoded)
fin = time.time()
print(f"⏱️ XGBClassifier entrenado en {fin - inicio:.2f}s")
# Out:
# ⏱️ XGBClassifier entrenado en 32.69s

# %%
joblib.dump(xgb_classifier, 'models/frijol/modelo_xgb_v2.pkl')
# Out:
# ['models/frijol/modelo_xgb_v2.pkl']

# %% [markdown]
# ## 5.4 MLP

# %%
mlp = MLPClassifier()

# %%
mlp_classifier = train_model(mlp)
# Out:
# ⏱️ MLPClassifier entrenado en 2039.25s

# %%
joblib.dump(mlp_classifier, 'models/frijol/modelo_mlp_v2.pkl')
# Out:
# ['models/frijol/modelo_mlp_v2.pkl']

# %% [markdown]
# ## 5.5 Carga de modelos previamente entrenados

# %%
knn_classifier = joblib.load('models/frijol/modelo_knn_v2.pkl')

# %%
rf_classifier = joblib.load('models/frijol/modelo_rfc_v2.pkl')

# %%
xgb_classifier = joblib.load('models/frijol/modelo_xgb_v2.pkl')

# %%
mlp_classifier = joblib.load('models/frijol/modelo_mlp_v2.pkl')

# %% [markdown]
# # 6. Generación de Predicciones

# %%
def medir_tiempo_prediccion(func):
    def wrapper(estimator, type: str):
        etiqueta = estimator.__class__.__name__
        inicio = time.time()
        resultado = func(estimator, type)
        fin = time.time()
        print(f"⏱️ {etiqueta} ({type}) predicho en {fin - inicio:.2f}s")
        return resultado
    return wrapper

@medir_tiempo_prediccion
def make_prediction(estimator, type: str):
    if type == "test":
        return estimator.predict(X_test_scaled)
    elif type == "train":
        return estimator.predict(X_train_scaled)

os.makedirs("results/predictions/frijol/test",  exist_ok=True)
os.makedirs("results/predictions/frijol/train", exist_ok=True)

# %% [markdown]
# ## 6.1 Predicciones con KNN

# %%
knn_prediction_test  = make_prediction(knn_classifier, "test")
# Out:
# ⏱️ KNeighborsClassifier (test) predicho en 11.70s

# %%
knn_prediction_train = make_prediction(knn_classifier, "train")
# Out:
# ⏱️ KNeighborsClassifier (train) predicho en 29.55s

# %%
joblib.dump(knn_prediction_test,  "results/predictions/frijol/test/predicciones_knn_test_v2.pkl")
joblib.dump(knn_prediction_train, "results/predictions/frijol/train/predicciones_knn_train_v2.pkl")
# Out:
# ['results/predictions/frijol/train/predicciones_knn_train_v2.pkl']

# %%
print("=" * 50)
print("Clasificación Report - Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, knn_prediction_train))
print("\n" + "=" * 50)
print("Clasificación Report - Prueba")
print("=" * 50)
print(classification_report(y_test, knn_prediction_test))
# Out:
# ==================================================
# Clasificación Report - Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.55      0.68      0.61    488152
#            2       0.54      0.60      0.57    490435
#            3       0.54      0.48      0.51    406130
#            4       0.66      0.49      0.56    470163
#
#     accuracy                           0.57   1854880
#    macro avg       0.57      0.56      0.56   1854880
# weighted avg       0.57      0.57      0.56   1854880
#
#
# ==================================================
# Clasificación Report - Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.39      0.33      0.35    378590
#            2       0.22      0.27      0.24    238270
#            3       0.16      0.19      0.17    168050
#            4       0.34      0.31      0.32    240240
#
#     accuracy                           0.28   1025150
#    macro avg       0.28      0.27      0.27   1025150
# weighted avg       0.30      0.28      0.29   1025150

# %%
knn_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=knn_prediction_train)
knn_cm_test  = confusion_matrix(y_true=y_test,            y_pred=knn_prediction_test)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']
for ax, matriz, split in zip(axes, [knn_cm_train, knn_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=tratamiento_labels)
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'Matriz de Confusión KNN - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6.2 Predicciones con Random Forest

# %%
rf_prediction_test  = make_prediction(rf_classifier, "test")
rf_prediction_train = make_prediction(rf_classifier, "train")
joblib.dump(rf_prediction_test,  "results/predictions/frijol/test/predicciones_rf_test_v2.pkl")
joblib.dump(rf_prediction_train, "results/predictions/frijol/train/predicciones_rf_train_v2.pkl")
# Out:
# ⏱️ RandomForestClassifier (test) predicho en 28.82s
# ⏱️ RandomForestClassifier (train) predicho en 60.52s
# ['results/predictions/frijol/train/predicciones_rf_train_v2.pkl']

# %%
print("=" * 50)
print("Clasificación Report - Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, rf_prediction_train))
print("\n" + "=" * 50)
print("Clasificación Report - Prueba")
print("=" * 50)
print(classification_report(y_test, rf_prediction_test))
# Out:
# ==================================================
# Clasificación Report - Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00    488152
#            2       1.00      1.00      1.00    490435
#            3       1.00      1.00      1.00    406130
#            4       1.00      1.00      1.00    470163
#
#     accuracy                           1.00   1854880
#    macro avg       1.00      1.00      1.00   1854880
# weighted avg       1.00      1.00      1.00   1854880
#
#
# ==================================================
# Clasificación Report - Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.36      0.22      0.28    378590
#            2       0.23      0.28      0.25    238270
#            3       0.15      0.20      0.17    168050
#            4       0.33      0.38      0.35    240240
#
#     accuracy                           0.27   1025150
#    macro avg       0.27      0.27      0.26   1025150
# weighted avg       0.29      0.27      0.27   1025150

# %%
rf_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=rf_prediction_train)
rf_cm_test  = confusion_matrix(y_true=y_test,            y_pred=rf_prediction_test)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']
for ax, matriz, split in zip(axes, [rf_cm_train, rf_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=tratamiento_labels)
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'Matriz de Confusión Random Forest - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6.3 Predicciones con XGBoost

# %%
xgb_prediction_test  = make_prediction(xgb_classifier, "test")
xgb_prediction_train = make_prediction(xgb_classifier, "train")
joblib.dump(xgb_prediction_test,  "results/predictions/frijol/test/predicciones_xgb_test_v2.pkl")
joblib.dump(xgb_prediction_train, "results/predictions/frijol/train/predicciones_xgb_train_v2.pkl")
# Out:
# ⏱️ XGBClassifier (test) predicho en 1.32s
# ⏱️ XGBClassifier (train) predicho en 2.52s
# ['results/predictions/frijol/train/predicciones_xgb_train_v2.pkl']

# %%
print("=" * 50)
print("Clasificación Report - Entrenamiento")
print("=" * 50)
print(classification_report(y_train_encoded, xgb_prediction_train))
print("\n" + "=" * 50)
print("Clasificación Report - Prueba")
print("=" * 50)
print(classification_report(y_test_encoded, xgb_prediction_test))
# Out:
# ==================================================
# Clasificación Report - Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.60      0.62      0.61    488152
#            1       0.55      0.60      0.57    490435
#            2       0.54      0.53      0.53    406130
#            3       0.65      0.57      0.61    470163
#
#     accuracy                           0.58   1854880
#    macro avg       0.58      0.58      0.58   1854880
# weighted avg       0.59      0.58      0.58   1854880
#
#
# ==================================================
# Clasificación Report - Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.37      0.26      0.31    378590
#            1       0.20      0.25      0.22    238270
#            2       0.17      0.23      0.19    168050
#            3       0.36      0.35      0.35    240240
#
#     accuracy                           0.27   1025150
#    macro avg       0.27      0.27      0.27   1025150
# weighted avg       0.29      0.27      0.28   1025150

# %%
xgb_cm_train = confusion_matrix(y_true=y_train_encoded, y_pred=xgb_prediction_train)
xgb_cm_test  = confusion_matrix(y_true=y_test_encoded,  y_pred=xgb_prediction_test)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']
for ax, matriz, split in zip(axes, [xgb_cm_train, xgb_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=tratamiento_labels)
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'Matriz de Confusión XGBoost - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6.4 Predicciones con MLP

# %%
mlp_prediction_test  = make_prediction(mlp_classifier, "test")
mlp_prediction_train = make_prediction(mlp_classifier, "train")
joblib.dump(mlp_prediction_test,  "results/predictions/frijol/test/predicciones_mlp_test_v2.pkl")
joblib.dump(mlp_prediction_train, "results/predictions/frijol/train/predicciones_mlp_train_v2.pkl")
# Out:
# ⏱️ MLPClassifier (test) predicho en 1.10s
# ⏱️ MLPClassifier (train) predicho en 2.27s
# ['results/predictions/frijol/train/predicciones_mlp_train_v2.pkl']

# %%
print("=" * 50)
print("Clasificación Report - Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, mlp_prediction_train))
print("\n" + "=" * 50)
print("Clasificación Report - Prueba")
print("=" * 50)
print(classification_report(y_test, mlp_prediction_test))
# Out:
# ==================================================
# Clasificación Report - Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.42      0.51      0.46    488152
#            2       0.38      0.41      0.39    490435
#            3       0.32      0.16      0.21    406130
#            4       0.43      0.48      0.45    470163
#
#     accuracy                           0.40   1854880
#    macro avg       0.39      0.39      0.38   1854880
# weighted avg       0.39      0.40      0.39   1854880
#
#
# ==================================================
# Clasificación Report - Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.38      0.31      0.34    378590
#            2       0.19      0.24      0.21    238270
#            3       0.20      0.13      0.15    168050
#            4       0.35      0.45      0.40    240240
#
#     accuracy                           0.30   1025150
#    macro avg       0.28      0.28      0.28   1025150
# weighted avg       0.30      0.30      0.29   1025150

# %%
mlp_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=mlp_prediction_train)
mlp_cm_test  = confusion_matrix(y_true=y_test,            y_pred=mlp_prediction_test)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, matriz, split in zip(axes, [mlp_cm_train, mlp_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'Matriz de Confusión MLP - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Evaluación de Modelos Baseline

# %%
classifiers_names  = ["knn", "rfc", "xgb", "mlp"]
predictions_train  = [knn_prediction_train, rf_prediction_train, xgb_prediction_train, mlp_prediction_train]
predictions_test   = [knn_prediction_test,  rf_prediction_test,  xgb_prediction_test,  mlp_prediction_test]
cmxs_train         = [knn_cm_train, rf_cm_train, xgb_cm_train, mlp_cm_train]
cmxs_test          = [knn_cm_test,  rf_cm_test,  xgb_cm_test,  mlp_cm_test]

classifier_display_names = {
    "knn": "K-Nearest Neighbors",
    "rfc": "Random Forest",
    "xgb": "XGBoost",
    "mlp": "Perceptrón Multicapa"
}

# %%
num_models = 4
ncols = 2
nrows = math.ceil(num_models / ncols)
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()

for i, (cm, cname) in enumerate(zip(cmxs_train, classifiers_names)):
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=axes[i], cmap='Blues', colorbar=False)
    axes[i].set_title(f"{classifier_display_names[cname]}")
    axes[i].grid(False)

for j in range(num_models, len(axes)):
    axes[j].axis('off')
plt.suptitle("Matrices de Confusión Baseline — Entrenamiento", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(5 * ncols, 4 * nrows))
axes = axes.flatten()

for i, (cm, cname) in enumerate(zip(cmxs_test, classifiers_names)):
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=axes[i], cmap='Blues', colorbar=False)
    axes[i].set_title(f"{classifier_display_names[cname]}")
    axes[i].grid(False)

for j in range(num_models, len(axes)):
    axes[j].axis('off')
plt.suptitle("Matrices de Confusión Baseline — Prueba", fontsize=14, y=1.01)
plt.tight_layout()
plt.show()

# %%
results_list = []
for preds, cname in zip(predictions_train, classifiers_names):
    y_true_ref = y_train_encoded if cname == 'xgb' else y_train_resampled
    report_dict = classification_report(y_true_ref, preds, output_dict=True)
    results_list.append({
        'Modelo': cname,
        'Accuracy': report_dict['accuracy'],
        'Precision (Ponderada)': report_dict['weighted avg']['precision'],
        'Recall (Ponderado)': report_dict['weighted avg']['recall'],
        'F1-Score (Ponderado)': report_dict['weighted avg']['f1-score'],
        'Kappa Score': cohen_kappa_score(y_true_ref, preds),
    })
results_df = pd.DataFrame(results_list).set_index('Modelo')
display(results_df.style.background_gradient(cmap='summer_r', axis=0))
# Out:
# <style type="text/css">
# #T_8ff99_row0_col0, #T_8ff99_row0_col2, #T_8ff99_row0_col4 {
#   background-color: #b8dc66;
#   color: #000000;
# }
# #T_8ff99_row0_col1 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_8ff99_row0_col3 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_8ff99_row1_col0, #T_8ff99_row1_col1, #T_8ff99_row1_col2, #T_8ff99_row1_col3, #T_8ff99_row1_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_8ff99_row2_col0, #T_8ff99_row2_col2 {
#   background-color: #b1d866;
#   color: #000000;
# }
# #T_8ff99_row2_col1, #T_8ff99_row2_col3 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_8ff99_row2_col4 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_8ff99_row3_col0, #T_8ff99_row3_col1, #T_8ff99_row3_col2, #T_8ff99_row3_col3, #T_8ff99_row3_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_8ff99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ff99_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8ff99_level0_col1" class="col_heading level0 col1" >Precision (Ponderada)</th>
#       <th id="T_8ff99_level0_col2" class="col_heading level0 col2" >Recall (Ponderado)</th>
#       <th id="T_8ff99_level0_col3" class="col_heading level0 col3" >F1-Score (Ponderado)</th>
#       <th id="T_8ff99_level0_col4" class="col_heading level0 col4" >Kappa Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ff99_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_8ff99_row0_col0" class="data row0 col0" >0.565300</td>
#       <td id="T_8ff99_row0_col1" class="data row0 col1" >0.572570</td>
#       <td id="T_8ff99_row0_col2" class="data row0 col2" >0.565300</td>
#       <td id="T_8ff99_row0_col3" class="data row0 col3" >0.563148</td>
#       <td id="T_8ff99_row0_col4" class="data row0 col4" >0.417991</td>
#     </tr>
#     <tr>
#       <th id="T_8ff99_level0_row1" class="row_heading level0 row1" >rfc</th>
#       <td id="T_8ff99_row1_col0" class="data row1 col0" >0.999999</td>
#       <td id="T_8ff99_row1_col1" class="data row1 col1" >0.999999</td>
#       <td id="T_8ff99_row1_col2" class="data row1 col2" >0.999999</td>
#       <td id="T_8ff99_row1_col3" class="data row1 col3" >0.999999</td>
#       <td id="T_8ff99_row1_col4" class="data row1 col4" >0.999999</td>
#     </tr>
#     <tr>
#       <th id="T_8ff99_level0_row2" class="row_heading level0 row2" >xgb</th>
#       <td id="T_8ff99_row2_col0" class="data row2 col0" >0.583074</td>
#       <td id="T_8ff99_row2_col1" class="data row2 col1" >0.585679</td>
#       <td id="T_8ff99_row2_col2" class="data row2 col2" >0.583074</td>
#       <td id="T_8ff99_row2_col3" class="data row2 col3" >0.583386</td>
#       <td id="T_8ff99_row2_col4" class="data row2 col4" >0.442713</td>
#     </tr>
#     <tr>
#       <th id="T_8ff99_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_8ff99_row3_col0" class="data row3 col0" >0.398196</td>
#       <td id="T_8ff99_row3_col1" class="data row3 col1" >0.387756</td>
#       <td id="T_8ff99_row3_col2" class="data row3 col2" >0.398196</td>
#       <td id="T_8ff99_row3_col3" class="data row3 col3" >0.385598</td>
#       <td id="T_8ff99_row3_col4" class="data row3 col4" >0.191228</td>
#     </tr>
#   </tbody>
# </table>

# %%
results_list = []
for preds, cname in zip(predictions_test, classifiers_names):
    y_true_ref = y_test_encoded if cname == 'xgb' else y_test
    report_dict = classification_report(y_true_ref, preds, output_dict=True)
    results_list.append({
        'Modelo': cname,
        'Accuracy': report_dict['accuracy'],
        'Precision (Ponderada)': report_dict['weighted avg']['precision'],
        'Recall (Ponderado)': report_dict['weighted avg']['recall'],
        'F1-Score (Ponderado)': report_dict['weighted avg']['f1-score'],
        'Kappa Score': cohen_kappa_score(y_true_ref, preds),
    })
results_df = pd.DataFrame(results_list).set_index('Modelo')
display(results_df.style.background_gradient(cmap='summer_r', axis=0))
# Out:
# <style type="text/css">
# #T_26f1d_row0_col0, #T_26f1d_row0_col2 {
#   background-color: #75ba66;
#   color: #f1f1f1;
# }
# #T_26f1d_row0_col1, #T_26f1d_row3_col0, #T_26f1d_row3_col2, #T_26f1d_row3_col3, #T_26f1d_row3_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_26f1d_row0_col3 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_26f1d_row0_col4 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_26f1d_row1_col0, #T_26f1d_row1_col1, #T_26f1d_row1_col2, #T_26f1d_row1_col3, #T_26f1d_row1_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_26f1d_row2_col0, #T_26f1d_row2_col2 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_26f1d_row2_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_26f1d_row2_col3 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_26f1d_row2_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_26f1d_row3_col1 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26f1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26f1d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_26f1d_level0_col1" class="col_heading level0 col1" >Precision (Ponderada)</th>
#       <th id="T_26f1d_level0_col2" class="col_heading level0 col2" >Recall (Ponderado)</th>
#       <th id="T_26f1d_level0_col3" class="col_heading level0 col3" >F1-Score (Ponderado)</th>
#       <th id="T_26f1d_level0_col4" class="col_heading level0 col4" >Kappa Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26f1d_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_26f1d_row0_col0" class="data row0 col0" >0.284283</td>
#       <td id="T_26f1d_row0_col1" class="data row0 col1" >0.299956</td>
#       <td id="T_26f1d_row0_col2" class="data row0 col2" >0.284283</td>
#       <td id="T_26f1d_row0_col3" class="data row0 col3" >0.290003</td>
#       <td id="T_26f1d_row0_col4" class="data row0 col4" >0.030699</td>
#     </tr>
#     <tr>
#       <th id="T_26f1d_level0_row1" class="row_heading level0 row1" >rfc</th>
#       <td id="T_26f1d_row1_col0" class="data row1 col0" >0.269405</td>
#       <td id="T_26f1d_row1_col1" class="data row1 col1" >0.289876</td>
#       <td id="T_26f1d_row1_col2" class="data row1 col2" >0.269405</td>
#       <td id="T_26f1d_row1_col3" class="data row1 col3" >0.271768</td>
#       <td id="T_26f1d_row1_col4" class="data row1 col4" >0.027228</td>
#     </tr>
#     <tr>
#       <th id="T_26f1d_level0_row2" class="row_heading level0 row2" >xgb</th>
#       <td id="T_26f1d_row2_col0" class="data row2 col0" >0.274118</td>
#       <td id="T_26f1d_row2_col1" class="data row2 col1" >0.294519</td>
#       <td id="T_26f1d_row2_col2" class="data row2 col2" >0.274118</td>
#       <td id="T_26f1d_row2_col3" class="data row2 col3" >0.279667</td>
#       <td id="T_26f1d_row2_col4" class="data row2 col4" >0.027456</td>
#     </tr>
#     <tr>
#       <th id="T_26f1d_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_26f1d_row3_col0" class="data row3 col0" >0.296832</td>
#       <td id="T_26f1d_row3_col1" class="data row3 col1" >0.299280</td>
#       <td id="T_26f1d_row3_col2" class="data row3 col2" >0.296832</td>
#       <td id="T_26f1d_row3_col3" class="data row3 col3" >0.293478</td>
#       <td id="T_26f1d_row3_col4" class="data row3 col4" >0.040412</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 8. Selección de Hiperparámetros

# %%
def make_rand_grid_search(estimator, param_dist, cv_splitter):
    return RandomizedSearchCV(
        estimator=estimator,
        param_distributions=param_dist,
        n_iter=10,
        cv=cv_splitter,
        scoring="accuracy",
        random_state=12,
        refit=True,
    )

for stage_dir in ['hyperparameter_tuning', 'best']:
    os.makedirs(f'models/frijol/{stage_dir}', exist_ok=True)

def save_model_and_params(model, model_name, best_params, score, stage="hyperparameter_tuning"):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    model_info = {'model': model, 'best_params': best_params, 'best_score': score,
                  'timestamp': timestamp, 'model_name': model_name, 'stage': stage}
    save_path = f'models/frijol/{stage}/{model_name}_{timestamp}_v2.pkl'
    with open(save_path, 'wb') as f:
        pickle.dump(model_info, f)
    print(f"✅ Modelo {model_name} guardado en: {save_path}")
    return save_path

def load_model_info(filepath):
    with open(filepath, 'rb') as f:
        model_info = pickle.load(f)
    print(f"📁 Modelo {model_info['model_name']} cargado | Score: {model_info['best_score']:.4f}")
    return model_info

# %% [markdown]
# ## 8.1 Selección de muestra y validación cruzada GroupKFold

# %%
HYPERPARAMETER_SAMPLE_SIZE = 0.15
RANDOM_STATE = 42

print(f"Dataset original de entrenamiento: {X_train_scaled.shape[0]:,} muestras")

X_train_sample, _, y_train_sample, _, groups_sample, _ = train_test_split(
    X_train_scaled,
    y_train_resampled,
    groups_train_resampled,
    test_size=1 - HYPERPARAMETER_SAMPLE_SIZE,
    stratify=y_train_resampled,
    random_state=RANDOM_STATE,
)

y_train_sample_encoded = le.transform(y_train_sample)
gkf = GroupKFold(n_splits=5)

print(f"Muestra para hiperparámetros: {X_train_sample.shape[0]:,} ({HYPERPARAMETER_SAMPLE_SIZE*100:.1f}%)")
print("\nDistribución de clases en muestra:")
print(pd.Series(y_train_sample).value_counts().sort_index())
# Out:
# Dataset original de entrenamiento: 1,854,880 muestras
# Muestra para hiperparámetros: 278,232 (15.0%)
#
# Distribución de clases en muestra:
# 1    73223
# 2    73565
# 3    60920
# 4    70524
# Name: count, dtype: int64

# %%
cv_rows = []
for fold, (tr_idx, te_idx) in enumerate(gkf.split(X_train_sample, y_train_sample, groups_sample), start=1):
    X_tr, X_te = X_train_sample[tr_idx], X_train_sample[te_idx]
    y_tr = pd.Series(y_train_sample).iloc[tr_idx]
    y_te = pd.Series(y_train_sample).iloc[te_idx]
    fold_model = RandomForestClassifier(n_estimators=120, random_state=42, n_jobs=-1)
    fold_model.fit(X_tr, y_tr)
    y_pred = fold_model.predict(X_te)
    cv_rows.append({"fold": fold, "accuracy": accuracy_score(y_te, y_pred), "f1_macro": f1_score(y_te, y_pred, average="macro")})

cv_df = pd.DataFrame(cv_rows)
display(cv_df)
summary_cv = pd.DataFrame({"metric": ["accuracy", "f1_macro"],
                            "mean": [cv_df["accuracy"].mean(), cv_df["f1_macro"].mean()],
                            "std":  [cv_df["accuracy"].std(ddof=1), cv_df["f1_macro"].std(ddof=1)]})
display(summary_cv)
# Out:
#    fold  accuracy  f1_macro
# 0     1  0.303229  0.295900
# 1     2  0.252026  0.250522
# 2     3  0.310786  0.305465
# 3     4  0.250031  0.244740
# 4     5  0.286036  0.285995
#      metric      mean       std
# 0  accuracy  0.280422  0.028300
# 1  f1_macro  0.276524  0.027336

# %% [markdown]
# ## 8.2 KNN — Búsqueda de hiperparámetros

# %%
knn_param_grid = {
    'n_neighbors': [15, 30, 50, 100],
    'weights': ['uniform', 'distance'],
    'p': [1, 2],
}

# %%
print("🔍 Iniciando búsqueda de hiperparámetros para KNN...")
search_start = time.time()
knn_gridSearchCV = make_rand_grid_search(KNeighborsClassifier(n_jobs=-1), knn_param_grid, gkf)
knn_gridSearchCV.fit(X_train_sample, y_train_sample, groups=groups_sample)
search_elapsed = time.time() - search_start
print(f"⏱️ Búsqueda KNN: {search_elapsed:.2f}s ({search_elapsed/60:.2f} min)")
save_model_and_params(knn_gridSearchCV, "KNN", knn_gridSearchCV.best_params_, knn_gridSearchCV.best_score_, "hyperparameter_tuning")
print(f"Mejores parámetros: {knn_gridSearchCV.best_params_}")
print(f"Score CV: {knn_gridSearchCV.best_score_:.4f}")
# Out:
# 🔍 Iniciando búsqueda de hiperparámetros para KNN...
# ⏱️ Búsqueda KNN: 97.35s (1.62 min)
# ✅ Modelo KNN guardado en: models/frijol/hyperparameter_tuning/KNN_20260427_145625_v2.pkl
# Mejores parámetros: {'weights': 'distance', 'p': 1, 'n_neighbors': 30}
# Score CV: 0.2634

# %%
print(f"🚀 Entrenando KNN final con {X_train_scaled.shape[0]:,} muestras...")
knn_final = KNeighborsClassifier(n_jobs=-1, **knn_gridSearchCV.best_params_)
train_start = time.time()
knn_final.fit(X_train_scaled, y_train_resampled)
print(f"⏱️ KNN final entrenado en {time.time()-train_start:.2f}s")
save_model_and_params(knn_final, "KNN_final", knn_gridSearchCV.best_params_, knn_gridSearchCV.best_score_, "best")
# Out:
# 🚀 Entrenando KNN final con 1,854,880 muestras...
# ⏱️ KNN final entrenado en 3.51s
# ✅ Modelo KNN_final guardado en: models/frijol/best/KNN_final_20260427_152106_v2.pkl
# 'models/frijol/best/KNN_final_20260427_152106_v2.pkl'

# %%
knn_y_test_pred  = knn_final.predict(X_test_scaled)
knn_y_train_pred = knn_final.predict(X_train_scaled)
joblib.dump(knn_y_test_pred,  "results/predictions/frijol/test/best_predicciones_knn_test_v2.pkl")
joblib.dump(knn_y_train_pred, "results/predictions/frijol/train/best_predicciones_knn_train_v2.pkl")
# Out:
# ['results/predictions/frijol/train/best_predicciones_knn_train_v2.pkl']

# %%
print("=" * 50)
print("KNN Optimizado — Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, knn_y_train_pred))
print("\n" + "=" * 50)
print("KNN Optimizado — Prueba")
print("=" * 50)
print(classification_report(y_test, knn_y_test_pred))
# Out:
# ==================================================
# KNN Optimizado — Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00    488152
#            2       1.00      1.00      1.00    490435
#            3       1.00      1.00      1.00    406130
#            4       1.00      1.00      1.00    470163
#
#     accuracy                           1.00   1854880
#    macro avg       1.00      1.00      1.00   1854880
# weighted avg       1.00      1.00      1.00   1854880
#
#
# ==================================================
# KNN Optimizado — Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.38      0.25      0.30    378590
#            2       0.21      0.24      0.23    238270
#            3       0.16      0.22      0.18    168050
#            4       0.33      0.37      0.35    240240
#
#     accuracy                           0.27   1025150
#    macro avg       0.27      0.27      0.27   1025150
# weighted avg       0.29      0.27      0.28   1025150

# %%
knn_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=knn_y_train_pred)
knn_cm_test  = confusion_matrix(y_true=y_test,            y_pred=knn_y_test_pred)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, matriz, split in zip(axes, [knn_cm_train, knn_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'KNN Optimizado - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8.3 Random Forest — Búsqueda de hiperparámetros

# %%
rf_param_grid = {
    'n_estimators': [100, 150],
    'max_depth': [5, 10, 15],
    'min_samples_split': [20, 50, 100],
    'min_samples_leaf': [10, 20, 50],
    'max_features': ['sqrt', 'log2'],
}

# %%
print("🔍 Iniciando búsqueda de hiperparámetros para Random Forest...")
search_start = time.time()
rf_gridSearchCV = make_rand_grid_search(RandomForestClassifier(n_jobs=-1, random_state=12), rf_param_grid, gkf)
rf_gridSearchCV.fit(X_train_sample, y_train_sample, groups=groups_sample)
search_elapsed = time.time() - search_start
print(f"⏱️ Búsqueda RF: {search_elapsed:.2f}s ({search_elapsed/60:.2f} min)")
save_model_and_params(rf_gridSearchCV, "RandomForest", rf_gridSearchCV.best_params_, rf_gridSearchCV.best_score_, "hyperparameter_tuning")
print(f"Mejores parámetros: {rf_gridSearchCV.best_params_}")
print(f"Score CV: {rf_gridSearchCV.best_score_:.4f}")
# Out:
# 🔍 Iniciando búsqueda de hiperparámetros para Random Forest...
# ⏱️ Búsqueda RF: 441.98s (7.37 min)
# ✅ Modelo RandomForest guardado en: models/frijol/hyperparameter_tuning/RandomForest_20260427_153905_v2.pkl
# Mejores parámetros: {'n_estimators': 100, 'min_samples_split': 20, 'min_samples_leaf': 50, 'max_features': 'log2', 'max_depth': 15}
# Score CV: 0.2394

# %%
print(f"🚀 Entrenando Random Forest final con {X_train_scaled.shape[0]:,} muestras...")
rf_final = RandomForestClassifier(n_jobs=-1, random_state=12, **rf_gridSearchCV.best_params_)
train_start = time.time()
rf_final.fit(X_train_scaled, y_train_resampled)
print(f"⏱️ RF final entrenado en {time.time()-train_start:.2f}s")
save_model_and_params(rf_final, "RandomForest_final", rf_gridSearchCV.best_params_, rf_gridSearchCV.best_score_, "best")
# Out:
# 🚀 Entrenando Random Forest final con 1,854,880 muestras...
# ⏱️ RF final entrenado en 117.25s
# ✅ Modelo RandomForest_final guardado en: models/frijol/best/RandomForest_final_20260427_154119_v2.pkl
# 'models/frijol/best/RandomForest_final_20260427_154119_v2.pkl'

# %%
rf_y_test_pred  = rf_final.predict(X_test_scaled)
rf_y_train_pred = rf_final.predict(X_train_scaled)
joblib.dump(rf_y_test_pred,  "results/predictions/frijol/test/best_predicciones_rf_test_v2.pkl")
joblib.dump(rf_y_train_pred, "results/predictions/frijol/train/best_predicciones_rf_train_v2.pkl")
# Out:
# ['results/predictions/frijol/train/best_predicciones_rf_train_v2.pkl']

# %%
print("=" * 50)
print("RF Optimizado — Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, rf_y_train_pred))
print("\n" + "=" * 50)
print("RF Optimizado — Prueba")
print("=" * 50)
print(classification_report(y_test, rf_y_test_pred))
# Out:
# ==================================================
# RF Optimizado — Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.50      0.55      0.53    488152
#            2       0.44      0.51      0.47    490435
#            3       0.41      0.32      0.36    406130
#            4       0.51      0.47      0.49    470163
#
#     accuracy                           0.47   1854880
#    macro avg       0.46      0.46      0.46   1854880
# weighted avg       0.47      0.47      0.47   1854880
#
#
# ==================================================
# RF Optimizado — Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.34      0.24      0.28    378590
#            2       0.18      0.24      0.21    238270
#            3       0.15      0.16      0.16    168050
#            4       0.33      0.35      0.34    240240
#
#     accuracy                           0.25   1025150
#    macro avg       0.25      0.25      0.25   1025150
# weighted avg       0.27      0.25      0.26   1025150

# %%
rf_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=rf_y_train_pred)
rf_cm_test  = confusion_matrix(y_true=y_test,            y_pred=rf_y_test_pred)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, matriz, split in zip(axes, [rf_cm_train, rf_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'Random Forest Optimizado - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8.4 XGBoost — Búsqueda de hiperparámetros

# %%
xgb_param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.6, 0.8],
    'colsample_bytree': [0.6, 0.8],
    'reg_lambda': [1, 10, 50],
    'gamma': [0, 1, 5],
}

# %%
print("🔍 Iniciando búsqueda de hiperparámetros para XGBoost...")
search_start = time.time()
xgb_gridSearchCV = make_rand_grid_search(xgb.XGBClassifier(random_state=42), xgb_param_grid, gkf)
xgb_gridSearchCV.fit(X_train_sample, y_train_sample_encoded, groups=groups_sample)
search_elapsed = time.time() - search_start
print(f"⏱️ Búsqueda XGB: {search_elapsed:.2f}s ({search_elapsed/60:.2f} min)")
save_model_and_params(xgb_gridSearchCV, "XGBoost", xgb_gridSearchCV.best_params_, xgb_gridSearchCV.best_score_, "hyperparameter_tuning")
print(f"Mejores parámetros: {xgb_gridSearchCV.best_params_}")
print(f"Score CV: {xgb_gridSearchCV.best_score_:.4f}")
# Out:
# 🔍 Iniciando búsqueda de hiperparámetros para XGBoost...
# ⏱️ Búsqueda XGB: 219.49s (3.66 min)
# ✅ Modelo XGBoost guardado en: models/frijol/hyperparameter_tuning/XGBoost_20260427_154526_v2.pkl
# Mejores parámetros: {'subsample': 0.8, 'reg_lambda': 50, 'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.6}
# Score CV: 0.2588

# %%
print(f"🚀 Entrenando XGBoost final con {X_train_scaled.shape[0]:,} muestras...")
xgb_final = xgb.XGBClassifier(random_state=42, **xgb_gridSearchCV.best_params_)
train_start = time.time()
xgb_final.fit(X_train_scaled, y_train_encoded)
print(f"⏱️ XGBoost final entrenado en {time.time()-train_start:.2f}s")
save_model_and_params(xgb_final, "XGBoost_final", xgb_gridSearchCV.best_params_, xgb_gridSearchCV.best_score_, "best")
# Out:
# 🚀 Entrenando XGBoost final con 1,854,880 muestras...
# ⏱️ XGBoost final entrenado en 45.75s
# ✅ Modelo XGBoost_final guardado en: models/frijol/best/XGBoost_final_20260427_152917_v2.pkl
# 'models/frijol/best/XGBoost_final_20260427_152917_v2.pkl'

# %%
xgb_y_test_pred  = xgb_final.predict(X_test_scaled)
xgb_y_train_pred = xgb_final.predict(X_train_scaled)
joblib.dump(xgb_y_test_pred,  "results/predictions/frijol/test/best_predicciones_xgb_test_v2.pkl")
joblib.dump(xgb_y_train_pred, "results/predictions/frijol/train/best_predicciones_xgb_train_v2.pkl")
# Out:
# ['results/predictions/frijol/train/best_predicciones_xgb_train_v2.pkl']

# %%
print("=" * 50)
print("XGBoost Optimizado — Entrenamiento")
print("=" * 50)
print(classification_report(y_train_encoded, xgb_y_train_pred))
print("\n" + "=" * 50)
print("XGBoost Optimizado — Prueba")
print("=" * 50)
print(classification_report(y_test_encoded, xgb_y_test_pred))
# Out:
# ==================================================
# XGBoost Optimizado — Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53    488152
#            1       0.45      0.51      0.47    490435
#            2       0.43      0.43      0.43    406130
#            3       0.57      0.42      0.49    470163
#
#     accuracy                           0.48   1854880
#    macro avg       0.49      0.48      0.48   1854880
# weighted avg       0.49      0.48      0.48   1854880
#
#
# ==================================================
# XGBoost Optimizado — Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            0       0.36      0.28      0.31    378590
#            1       0.18      0.23      0.20    238270
#            2       0.19      0.25      0.21    168050
#            3       0.36      0.32      0.34    240240
#
#     accuracy                           0.27   1025150
#    macro avg       0.27      0.27      0.27   1025150
# weighted avg       0.29      0.27      0.28   1025150

# %%
xgb_cm_train = confusion_matrix(y_true=y_train_encoded, y_pred=xgb_y_train_pred)
xgb_cm_test  = confusion_matrix(y_true=y_test_encoded,  y_pred=xgb_y_test_pred)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, matriz, split in zip(axes, [xgb_cm_train, xgb_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'XGBoost Optimizado - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8.5 MLP — Búsqueda de hiperparámetros

# %%
mlp_param_grid = [
    {
        'hidden_layer_sizes': [(100, 100, 100), (128, 64, 32)],
        'batch_size': [256],
        'learning_rate_init': [0.001],
        'alpha': [1e-4],
        'early_stopping': [True],
    }
]

# %%
print("🔍 Iniciando búsqueda de hiperparámetros para MLP...")
search_start = time.time()
mlp_gridSearchCV = make_rand_grid_search(MLPClassifier(), mlp_param_grid, gkf)
mlp_gridSearchCV.fit(X_train_sample, y_train_sample, groups=groups_sample)
search_elapsed = time.time() - search_start
print(f"⏱️ Búsqueda MLP: {search_elapsed:.2f}s ({search_elapsed/60:.2f} min)")
save_model_and_params(mlp_gridSearchCV, "MLP", mlp_gridSearchCV.best_params_, mlp_gridSearchCV.best_score_, "hyperparameter_tuning")
print(f"Mejores parámetros: {mlp_gridSearchCV.best_params_}")
print(f"Score CV: {mlp_gridSearchCV.best_score_:.4f}")
# Out:
# 🔍 Iniciando búsqueda de hiperparámetros para MLP...
# ⏱️ Búsqueda MLP: 4100.04s (68.33 min)
# ✅ Modelo MLP guardado en: models/frijol/hyperparameter_tuning/MLP_20260427_172120_v2.pkl
# Mejores parámetros: {'learning_rate_init': 0.001, 'hidden_layer_sizes': (128, 64, 32), 'early_stopping': True, 'batch_size': 256, 'alpha': 0.0001}
# Score CV: 0.2708

# %%
print(f"🚀 Entrenando MLP final con {X_train_scaled.shape[0]:,} muestras...")
mlp_final = MLPClassifier(**mlp_gridSearchCV.best_params_)
train_start = time.time()
mlp_final.fit(X_train_scaled, y_train_resampled)
print(f"⏱️ MLP final entrenado en {time.time()-train_start:.2f}s")
save_model_and_params(mlp_final, "MLP_final", mlp_gridSearchCV.best_params_, mlp_gridSearchCV.best_score_, "best")
# Out:
# 🚀 Entrenando MLP final con 1,854,880 muestras...
# ⏱️ MLP final entrenado en 2738.44s
# ✅ Modelo MLP_final guardado en: models/frijol/best/MLP_final_20260427_190226_v2.pkl
# 'models/frijol/best/MLP_final_20260427_190226_v2.pkl'

# %%
mlp_y_test_pred  = mlp_final.predict(X_test_scaled)
mlp_y_train_pred = mlp_final.predict(X_train_scaled)
joblib.dump(mlp_y_test_pred,  "results/predictions/frijol/test/best_predicciones_mlp_test_v2.pkl")
joblib.dump(mlp_y_train_pred, "results/predictions/frijol/train/best_predicciones_mlp_train_v2.pkl")
# Out:
# ['results/predictions/frijol/train/best_predicciones_mlp_train_v2.pkl']

# %%
print("=" * 50)
print("MLP Optimizado — Entrenamiento")
print("=" * 50)
print(classification_report(y_train_resampled, mlp_y_train_pred))
print("\n" + "=" * 50)
print("MLP Optimizado — Prueba")
print("=" * 50)
print(classification_report(y_test, mlp_y_test_pred))
# Out:
# ==================================================
# MLP Optimizado — Entrenamiento
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.48      0.51      0.50    488152
#            2       0.45      0.42      0.44    490435
#            3       0.38      0.41      0.39    406130
#            4       0.49      0.46      0.48    470163
#
#     accuracy                           0.45   1854880
#    macro avg       0.45      0.45      0.45   1854880
# weighted avg       0.46      0.45      0.45   1854880
#
#
# ==================================================
# MLP Optimizado — Prueba
# ==================================================
#               precision    recall  f1-score   support
#
#            1       0.38      0.27      0.32    378590
#            2       0.21      0.21      0.21    238270
#            3       0.16      0.24      0.19    168050
#            4       0.35      0.39      0.37    240240
#
#     accuracy                           0.28   1025150
#    macro avg       0.28      0.28      0.27   1025150
# weighted avg       0.30      0.28      0.28   1025150

# %%
mlp_cm_train = confusion_matrix(y_true=y_train_resampled, y_pred=mlp_y_train_pred)
mlp_cm_test  = confusion_matrix(y_true=y_test,            y_pred=mlp_y_test_pred)
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, matriz, split in zip(axes, [mlp_cm_train, mlp_cm_test], ["Entrenamiento", "Prueba"]):
    disp = ConfusionMatrixDisplay(confusion_matrix=matriz, display_labels=['T1','T2','T3','T4'])
    disp.plot(ax=ax, cmap='Blues', colorbar=False)
    ax.set_title(f'MLP Optimizado - {split}', fontsize=14)
    ax.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8.6 Evaluación de modelos optimizados

# %%
classifiers_names  = ["knn", "rfc", "xgb", "mlp"]
predictions_train  = [knn_y_train_pred, rf_y_train_pred, xgb_y_train_pred, mlp_y_train_pred]
predictions_test   = [knn_y_test_pred,  rf_y_test_pred,  xgb_y_test_pred,  mlp_y_test_pred]

# %%
results_list = []
for preds, cname in zip(predictions_train, classifiers_names):
    y_true_ref = y_train_encoded if cname == 'xgb' else y_train_resampled
    rd = classification_report(y_true_ref, preds, output_dict=True)
    results_list.append({'Modelo': cname, 'Accuracy': rd['accuracy'],
                         'Precision (Ponderada)': rd['weighted avg']['precision'],
                         'Recall (Ponderado)': rd['weighted avg']['recall'],
                         'F1-Score (Ponderado)': rd['weighted avg']['f1-score'],
                         'Kappa Score': cohen_kappa_score(y_true_ref, preds)})
results_df = pd.DataFrame(results_list).set_index('Modelo')
print("Comparativo de métricas — Entrenamiento (modelos optimizados):")
display(results_df.style.background_gradient(cmap='summer_r', axis=0))
# Out:
# Comparativo de métricas — Entrenamiento (modelos optimizados):
# <style type="text/css">
# #T_689d3_row0_col0, #T_689d3_row0_col1, #T_689d3_row0_col2, #T_689d3_row0_col3, #T_689d3_row0_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_689d3_row1_col0, #T_689d3_row1_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_689d3_row1_col1, #T_689d3_row1_col3, #T_689d3_row1_col4 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_689d3_row2_col0, #T_689d3_row2_col2, #T_689d3_row2_col3, #T_689d3_row2_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_689d3_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_689d3_row3_col0, #T_689d3_row3_col1, #T_689d3_row3_col2, #T_689d3_row3_col3, #T_689d3_row3_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_689d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_689d3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_689d3_level0_col1" class="col_heading level0 col1" >Precision (Ponderada)</th>
#       <th id="T_689d3_level0_col2" class="col_heading level0 col2" >Recall (Ponderado)</th>
#       <th id="T_689d3_level0_col3" class="col_heading level0 col3" >F1-Score (Ponderado)</th>
#       <th id="T_689d3_level0_col4" class="col_heading level0 col4" >Kappa Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_689d3_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_689d3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_689d3_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_689d3_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_689d3_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_689d3_row0_col4" class="data row0 col4" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_689d3_level0_row1" class="row_heading level0 row1" >rfc</th>
#       <td id="T_689d3_row1_col0" class="data row1 col0" >0.468232</td>
#       <td id="T_689d3_row1_col1" class="data row1 col1" >0.466905</td>
#       <td id="T_689d3_row1_col2" class="data row1 col2" >0.468232</td>
#       <td id="T_689d3_row1_col3" class="data row1 col3" >0.465279</td>
#       <td id="T_689d3_row1_col4" class="data row1 col4" >0.287516</td>
#     </tr>
#     <tr>
#       <th id="T_689d3_level0_row2" class="row_heading level0 row2" >xgb</th>
#       <td id="T_689d3_row2_col0" class="data row2 col0" >0.481024</td>
#       <td id="T_689d3_row2_col1" class="data row2 col1" >0.487636</td>
#       <td id="T_689d3_row2_col2" class="data row2 col2" >0.481024</td>
#       <td id="T_689d3_row2_col3" class="data row2 col3" >0.480716</td>
#       <td id="T_689d3_row2_col4" class="data row2 col4" >0.306193</td>
#     </tr>
#     <tr>
#       <th id="T_689d3_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_689d3_row3_col0" class="data row3 col0" >0.453467</td>
#       <td id="T_689d3_row3_col1" class="data row3 col1" >0.455189</td>
#       <td id="T_689d3_row3_col2" class="data row3 col2" >0.453467</td>
#       <td id="T_689d3_row3_col3" class="data row3 col3" >0.453796</td>
#       <td id="T_689d3_row3_col4" class="data row3 col4" >0.270692</td>
#     </tr>
#   </tbody>
# </table>

# %%
results_list = []
for preds, cname in zip(predictions_test, classifiers_names):
    y_true_ref = y_test_encoded if cname == 'xgb' else y_test
    rd = classification_report(y_true_ref, preds, output_dict=True)
    results_list.append({'Modelo': cname, 'Accuracy': rd['accuracy'],
                         'Precision (Ponderada)': rd['weighted avg']['precision'],
                         'Recall (Ponderado)': rd['weighted avg']['recall'],
                         'F1-Score (Ponderado)': rd['weighted avg']['f1-score'],
                         'Kappa Score': cohen_kappa_score(y_true_ref, preds)})
results_df = pd.DataFrame(results_list).set_index('Modelo')
print("Comparativo de métricas — Prueba (modelos optimizados):")
display(results_df.style.background_gradient(cmap='summer_r', axis=0))
# Out:
# Comparativo de métricas — Prueba (modelos optimizados):
# <style type="text/css">
# #T_46799_row0_col0, #T_46799_row0_col2 {
#   background-color: #4da666;
#   color: #f1f1f1;
# }
# #T_46799_row0_col1 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_46799_row0_col3 {
#   background-color: #48a366;
#   color: #f1f1f1;
# }
# #T_46799_row0_col4 {
#   background-color: #329866;
#   color: #f1f1f1;
# }
# #T_46799_row1_col0, #T_46799_row1_col1, #T_46799_row1_col2, #T_46799_row1_col3, #T_46799_row1_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_46799_row2_col0, #T_46799_row2_col2 {
#   background-color: #57ab66;
#   color: #f1f1f1;
# }
# #T_46799_row2_col1 {
#   background-color: #369b66;
#   color: #f1f1f1;
# }
# #T_46799_row2_col3 {
#   background-color: #3d9e66;
#   color: #f1f1f1;
# }
# #T_46799_row2_col4 {
#   background-color: #6db666;
#   color: #f1f1f1;
# }
# #T_46799_row3_col0, #T_46799_row3_col1, #T_46799_row3_col2, #T_46799_row3_col3, #T_46799_row3_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_46799">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46799_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_46799_level0_col1" class="col_heading level0 col1" >Precision (Ponderada)</th>
#       <th id="T_46799_level0_col2" class="col_heading level0 col2" >Recall (Ponderado)</th>
#       <th id="T_46799_level0_col3" class="col_heading level0 col3" >F1-Score (Ponderado)</th>
#       <th id="T_46799_level0_col4" class="col_heading level0 col4" >Kappa Score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelo</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46799_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_46799_row0_col0" class="data row0 col0" >0.272125</td>
#       <td id="T_46799_row0_col1" class="data row0 col1" >0.293432</td>
#       <td id="T_46799_row0_col2" class="data row0 col2" >0.272125</td>
#       <td id="T_46799_row0_col3" class="data row0 col3" >0.276339</td>
#       <td id="T_46799_row0_col4" class="data row0 col4" >0.028845</td>
#     </tr>
#     <tr>
#       <th id="T_46799_level0_row1" class="row_heading level0 row1" >rfc</th>
#       <td id="T_46799_row1_col0" class="data row1 col0" >0.254270</td>
#       <td id="T_46799_row1_col1" class="data row1 col1" >0.267901</td>
#       <td id="T_46799_row1_col2" class="data row1 col2" >0.254270</td>
#       <td id="T_46799_row1_col3" class="data row1 col3" >0.257380</td>
#       <td id="T_46799_row1_col4" class="data row1 col4" >-0.003963</td>
#     </tr>
#     <tr>
#       <th id="T_46799_level0_row2" class="row_heading level0 row2" >xgb</th>
#       <td id="T_46799_row2_col0" class="data row2 col0" >0.271118</td>
#       <td id="T_46799_row2_col1" class="data row2 col1" >0.291492</td>
#       <td id="T_46799_row2_col2" class="data row2 col2" >0.271118</td>
#       <td id="T_46799_row2_col3" class="data row2 col3" >0.277545</td>
#       <td id="T_46799_row2_col4" class="data row2 col4" >0.019435</td>
#     </tr>
#     <tr>
#       <th id="T_46799_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_46799_row3_col0" class="data row3 col0" >0.279917</td>
#       <td id="T_46799_row3_col1" class="data row3 col1" >0.297846</td>
#       <td id="T_46799_row3_col2" class="data row3 col2" >0.279917</td>
#       <td id="T_46799_row3_col3" class="data row3 col3" >0.283878</td>
#       <td id="T_46799_row3_col4" class="data row3 col4" >0.036891</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 9. Análisis de Costos Computacionales
#
# Se consolidan los tiempos de entrenamiento y búsqueda de hiperparámetros y se visualiza la relación costo–beneficio (tiempo vs exactitud) para seleccionar el modelo más adecuado para producción.

# %%
# Actualizar con los tiempos reales registrados durante el entrenamiento
performance_data = {
    'Modelo': ['KNN', 'Random Forest', 'XGBoost', 'MLP'],
    'Accuracy_Test': [0.0, 0.0, 0.0, 0.0],   # Rellenar con valores reales
    'Kappa_Score':   [0.0, 0.0, 0.0, 0.0],   # Rellenar con valores reales
    'Tiempo_Entrenamiento_Min': [0.0, 0.0, 0.0, 0.0],  # Rellenar con valores reales
    'Tiempo_Texto': ['—', '—', '—', '—'],
}
df_perf = pd.DataFrame(performance_data)
display(df_perf.style
    .background_gradient(subset=['Accuracy_Test', 'Kappa_Score'], cmap='Greens')
    .background_gradient(subset=['Tiempo_Entrenamiento_Min'], cmap='Reds'))

# %%
plt.figure(figsize=(12, 7))
sns.set_style("whitegrid")
sns.scatterplot(data=df_perf, x='Tiempo_Entrenamiento_Min', y='Accuracy_Test',
                s=150, hue='Modelo', palette='viridis')
plt.xscale('log')
plt.title('Exactitud vs Tiempo de Entrenamiento (Fríjol v2)', fontsize=15, pad=20)
plt.xlabel('Tiempo de Entrenamiento (Minutos) — Escala Log', fontsize=13)
plt.ylabel('Exactitud en Prueba (Accuracy)', fontsize=13)
plt.grid(alpha=0.3)
for i in range(df_perf.shape[0]):
    plt.annotate(
        f"{df_perf.Modelo[i]}\nAcc: {df_perf.Accuracy_Test[i]:.3f}\n{df_perf.Tiempo_Texto[i]}",
        (df_perf.Tiempo_Entrenamiento_Min[i], df_perf.Accuracy_Test[i]),
        xytext=(10, 0), textcoords='offset points', va='center', fontsize=11,
        bbox=dict(boxstyle="round,pad=0.4", fc="white", ec="gray", alpha=0.8),
    )
plt.axhline(y=0.8, color='green', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
