# %% [markdown]
# # Entrenamiento CNN 2D Binario (Maíz): T4 vs Otros
#
# Entrena una CNN 2D con tensores multiespectrales `H x W x 10` para clasificar **T4** frente a **otros tratamientos (T1, T2, T3)**.

# %% [markdown]
# ## 0. Librerías y semilla

# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    cohen_kappa_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)
from sklearn.metrics import roc_auc_score, average_precision_score

tf.keras.utils.set_random_seed(42)

# %% [markdown]
# ## 1. Configuración

# %%
manifest_path = "datasets/object_split_maiz_tensors.csv"

# Los tensores nativos son 240x240x10; se redimensionan a 128x128 en la pipeline
IMG_HEIGHT   = 128
IMG_WIDTH    = 128
NUM_CHANNELS = 10
BATCH_SIZE   = 32

# Entrenamiento
EPOCHS        = 100
LEARNING_RATE = 3e-4

# Normalización: zscore_masked
NORMALIZATION_MODE = "zscore_masked"

# Regularización
L2_LAMBDA      = 5e-5
DROPOUT_BLOCK1 = 0.10
DROPOUT_BLOCK2 = 0.20
DROPOUT_BLOCK3 = 0.25
DROPOUT_DENSE  = 0.30

print("Configuración lista para T4 vs Otros (Maíz)")
print(f"- EPOCHS={EPOCHS}, LR={LEARNING_RATE}, BATCH_SIZE={BATCH_SIZE}")
print(f"- NORMALIZATION_MODE={NORMALIZATION_MODE}")
print(f"- L2_LAMBDA={L2_LAMBDA}")
# Out:
# Configuración lista para T4 vs Otros (Maíz)
# - EPOCHS=100, LR=0.0003, BATCH_SIZE=32
# - NORMALIZATION_MODE=zscore_masked
# - L2_LAMBDA=5e-05

# %% [markdown]
# ## 2. Carga de manifest y etiquetas binarias

# %%
if not os.path.isfile(manifest_path):
    raise FileNotFoundError(f"No existe manifest: {manifest_path}")

manifest_df = pd.read_csv(manifest_path).copy()
required_cols = {"object_id", "split", "tensor_path", "tratamiento", "plant_id"}
missing_cols = required_cols - set(manifest_df.columns)
if missing_cols:
    raise ValueError(f"Faltan columnas en manifest: {sorted(missing_cols)}")

manifest_df["tensor_path"] = manifest_df["tensor_path"].astype(str)
manifest_df["object_id"]   = manifest_df["object_id"].astype(str)
manifest_df["plant_id"]    = manifest_df["plant_id"].astype(str)
manifest_df["tratamiento"] = manifest_df["tratamiento"].astype(int)

# Etiqueta binaria: T4 = 1 (positivo / deficiencia severa), Otros = 0
manifest_df["label_name"] = np.where(manifest_df["tratamiento"] == 4, "T4", "Otros")
manifest_df["label"]      = np.where(manifest_df["tratamiento"] == 4, 1, 0).astype(int)

manifest_df["exists"] = manifest_df["tensor_path"].map(os.path.isfile)
n_missing = int((~manifest_df["exists"]).sum())
if n_missing > 0:
    display(manifest_df.loc[~manifest_df["exists"], ["object_id", "tensor_path"]].head(10))
    raise ValueError(f"Hay {n_missing} rutas de tensor no existentes.")

print("Registros totales:", len(manifest_df))
print("\nConteo binario por split:")
print(manifest_df.groupby(["split", "label_name"]).size().unstack(fill_value=0).to_string())
# Out:
# Registros totales: 577
#
# Conteo binario por split:
# label_name  Otros  T4
# split
# test           73  18
# train         324  77
# val            69  16

# %% [markdown]
# ## 3. Construcción de splits y validación

# %%
# Usar los splits definidos en el manifest
train_df = manifest_df[manifest_df["split"] == "train"].copy()
val_df   = manifest_df[manifest_df["split"] == "val"].copy()
test_df  = manifest_df[manifest_df["split"] == "test"].copy()

for df, name in [(train_df, "train"), (val_df, "val"), (test_df, "test")]:
    if df.empty:
        raise ValueError(f"Split '{name}' vacío en manifest.")

train_paths  = train_df["tensor_path"].values
train_labels = train_df["label"].values
val_paths    = val_df["tensor_path"].values
val_labels   = val_df["label"].values
test_paths   = test_df["tensor_path"].values
test_labels  = test_df["label"].values

# Validación: ningún objeto puede aparecer en más de un split
train_objects = set(train_df["object_id"].unique())
val_objects   = set(val_df["object_id"].unique())
test_objects  = set(test_df["object_id"].unique())

if train_objects & test_objects:
    raise ValueError(f"CRUCE train-test: {len(train_objects & test_objects)} objetos.")
if val_objects & test_objects:
    raise ValueError(f"CRUCE val-test: {len(val_objects & test_objects)} objetos.")

print(f"Train: {len(train_paths):,} | Val: {len(val_paths):,} | Test: {len(test_paths):,}")
print("\nDistribución binaria:")
for name, labels in [("train", train_labels), ("val", val_labels), ("test", test_labels)]:
    t4 = int((labels == 1).sum()); otros = int((labels == 0).sum())
    print(f"  {name}: T4={t4}, Otros={otros}, ratio={otros/t4:.2f}×")
print("\nVALIDACIÓN ANTI-CRUCE: APROBADA")
# Out:
# Train: 401 | Val: 85 | Test: 91
#
# Distribución binaria:
#   train: T4=77, Otros=324, ratio=4.21×
#   val: T4=16, Otros=69, ratio=4.31×
#   test: T4=18, Otros=73, ratio=4.06×
#
# VALIDACIÓN ANTI-CRUCE: APROBADA

# %% [markdown]
# ## 4. Pipeline tf.data

# %%
def _read_npy_tensor(path_bytes):

    path = path_bytes.decode("utf-8")
    arr = np.load(path).astype(np.float32)

    if arr.ndim != 3:
        raise ValueError(f"Tensor inválido en {path}. shape={arr.shape}")
    return arr

def load_and_preprocess_tensor(path, label):

    tensor = tf.numpy_function(_read_npy_tensor, [path], tf.float32)
    tensor.set_shape([None, None, NUM_CHANNELS])

    mask_pre = tf.cast(tf.reduce_any(tensor != 0, axis=-1, keepdims=True), tf.float32)
    mask_pre = tf.image.resize(mask_pre, [IMG_HEIGHT, IMG_WIDTH], method="nearest")
    mask_pre.set_shape([IMG_HEIGHT, IMG_WIDTH, 1])

    # Redimensionar de 240x240 nativo a 128x128
    tensor = tf.image.resize(tensor, [IMG_HEIGHT, IMG_WIDTH], method="bilinear")
    tensor.set_shape([IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS])

    # Sanitización: NaN/Inf -> 0
    tensor = tf.where(tf.math.is_finite(tensor), tensor, tf.zeros_like(tensor))

    tensor = tensor * mask_pre
    mask = mask_pre

    n_leaf = tf.maximum(tf.reduce_sum(mask), 1.0)
    mean   = tf.reduce_sum(tensor * mask, axis=[0, 1], keepdims=True) / n_leaf
    diff   = (tensor - mean) * mask
    var    = tf.reduce_sum(tf.square(diff), axis=[0, 1], keepdims=True) / n_leaf
    std    = tf.sqrt(var + 1e-6)
    tensor = diff / std

    return tensor, tf.cast(label, tf.float32)


def make_dataset(paths, labels, training=False):

    ds = tf.data.Dataset.from_tensor_slices((paths, labels))

    if training:
        ds = ds.shuffle(buffer_size=len(paths), seed=123, reshuffle_each_iteration=True)

    ds = ds.map(load_and_preprocess_tensor, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return ds

n_t4 = int((train_labels == 1).sum())
n_otros = int((train_labels == 0).sum())

train_ds = make_dataset(train_paths, train_labels, training=True)
val_ds   = make_dataset(val_paths,   val_labels,   training=False)
test_ds  = make_dataset(test_paths,  test_labels,  training=False)

# Verificación rápida
for x_batch, y_batch in train_ds.take(1):
    print("Rango X: min=", float(tf.reduce_min(x_batch)), " max=", float(tf.reduce_max(x_batch)))
# Out:
# Rango X: min= -5.610742092132568  max= 6.306039810180664

# %% [markdown]
# ## 5. Modelo CNN 2D binario

# %%
reg = tf.keras.regularizers.l2(L2_LAMBDA)

# Aumentación geométrica
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.12),
    layers.RandomZoom(0.12),
], name="data_augmentation")

n_pos = int((train_labels == 1).sum())
n_neg = int((train_labels == 0).sum())
bias_init_value = float(np.log(n_pos / n_neg))

inputs = layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, NUM_CHANNELS))

x = data_augmentation(inputs)

# Mezcla espectral
x = layers.Conv2D(NUM_CHANNELS * 2, 1, padding="same", activation="elu",
                  kernel_initializer="he_normal",
                  kernel_regularizer=reg, name="spectral_mixing")(x)

# Bloque 1: 128x128 -> 64x64
x = layers.SeparableConv2D(32, 3, padding="same", activation="elu",
                            depthwise_initializer="he_normal",
                            depthwise_regularizer=reg, pointwise_regularizer=reg)(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(DROPOUT_BLOCK1)(x)

# Bloque 2: 64x64 -> 32x32
x = layers.SeparableConv2D(64, 3, padding="same", activation="elu",
                            depthwise_initializer="he_normal",
                            depthwise_regularizer=reg, pointwise_regularizer=reg)(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(DROPOUT_BLOCK2)(x)

# Bloque 3: 32x32 -> 16x16
x = layers.SeparableConv2D(128, 3, padding="same", activation="elu",
                            depthwise_initializer="he_normal",
                            depthwise_regularizer=reg, pointwise_regularizer=reg)(x)
x = layers.MaxPooling2D()(x)
x = layers.Dropout(DROPOUT_BLOCK3)(x)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(64, activation="elu", 
                 kernel_initializer="he_normal",
                 kernel_regularizer=reg)(x)
x = layers.Dropout(DROPOUT_DENSE)(x)

outputs = layers.Dense(1,
                       bias_initializer=tf.keras.initializers.Constant(bias_init_value))(x)

model = tf.keras.Model(inputs, outputs, name="maiz_binary_spectral_cnn")

n_total = n_pos+n_neg
alpha_focal = n_neg/n_total

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=alpha_focal,
        gamma=2.0,
        from_logits=True,
    ),

    metrics=[
        tf.keras.metrics.BinaryAccuracy(name="acc", threshold=0.0),
        tf.keras.metrics.AUC(name="auc_roc", from_logits=True),
        tf.keras.metrics.AUC(name="auc_pr", curve="PR", from_logits=True),
    ],
)

model.summary()
# Out:
# Model: "maiz_binary_spectral_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 10)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 128, 128, 10)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spectral_mixing (Conv2D)        │ (None, 128, 128, 20)   │           220 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d                │ (None, 128, 128, 32)   │           852 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_1              │ (None, 64, 64, 64)     │         2,400 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ separable_conv2d_2              │ (None, 32, 32, 128)    │         8,896 │
# │ (SeparableConv2D)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,689 (80.82 KB)
#  Trainable params: 20,689 (80.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 6. Entrenamiento

# %%
os.makedirs("models/maiz", exist_ok=True)
os.makedirs("results", exist_ok=True)

best_model_path = "models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras"
history_csv     = "results/training_history_maiz_t4_vs_otros.csv"

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_auc_roc",
        patience=25,
        min_delta=0.002,
        start_from_epoch=15,
        restore_best_weights=True,
        mode="max",
        verbose=1,
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=7,
        min_lr=1e-6,
        verbose=1,
    ),

    tf.keras.callbacks.ModelCheckpoint(
        best_model_path,
        monitor="val_auc_roc",
        save_best_only=True,
        mode="max",
        verbose=1,
    ),

    tf.keras.callbacks.CSVLogger(history_csv),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

print(f"\nCheckpoint guardado en: {best_model_path}")
print(f"Historial en: {history_csv}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - acc: 0.7878 - auc_pr: 0.1963 - auc_roc: 0.4565 - loss: 0.1983
# Epoch 1: val_auc_roc improved from None to 0.48053, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 1: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 360ms/step - acc: 0.8080 - auc_pr: 0.1828 - auc_roc: 0.4535 - loss: 0.1778 - val_acc: 0.8118 - val_auc_pr: 0.1744 - val_auc_roc: 0.4805 - val_loss: 0.1649 - learning_rate: 3.0000e-04
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.8227 - auc_pr: 0.2190 - auc_roc: 0.5830 - loss: 0.1511
# Epoch 2: val_auc_roc improved from 0.48053 to 0.50000, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 2: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.8080 - auc_pr: 0.1954 - auc_roc: 0.5351 - loss: 0.1582 - val_acc: 0.8118 - val_auc_pr: 0.1882 - val_auc_roc: 0.5000 - val_loss: 0.1434 - learning_rate: 3.0000e-04
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - acc: 0.8391 - auc_pr: 0.2395 - auc_roc: 0.5995 - loss: 0.1172
# Epoch 3: val_auc_roc did not improve from 0.50000
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 340ms/step - acc: 0.8080 - auc_pr: 0.2150 - auc_roc: 0.5856 - loss: 0.1307 - val_acc: 0.8118 - val_auc_pr: 0.1649 - val_auc_roc: 0.4411 - val_loss: 0.1141 - learning_rate: 3.0000e-04
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - acc: 0.8180 - auc_pr: 0.2351 - auc_roc: 0.5442 - loss: 0.1019
# Epoch 4: val_auc_roc improved from 0.50000 to 0.51721, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 4: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - acc: 0.8080 - auc_pr: 0.1857 - auc_roc: 0.5036 - loss: 0.1001 - val_acc: 0.8118 - val_auc_pr: 0.1836 - val_auc_roc: 0.5172 - val_loss: 0.0810 - learning_rate: 3.0000e-04
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - acc: 0.8092 - auc_pr: 0.1649 - auc_roc: 0.5091 - loss: 0.0703
# Epoch 5: val_auc_roc did not improve from 0.51721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 361ms/step - acc: 0.7232 - auc_pr: 0.2065 - auc_roc: 0.5279 - loss: 0.0733 - val_acc: 0.2471 - val_auc_pr: 0.1683 - val_auc_roc: 0.4620 - val_loss: 0.0690 - learning_rate: 3.0000e-04
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - acc: 0.3561 - auc_pr: 0.2465 - auc_roc: 0.5692 - loss: 0.0693
# Epoch 6: val_auc_roc did not improve from 0.51721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - acc: 0.3367 - auc_pr: 0.2276 - auc_roc: 0.5591 - loss: 0.0704 - val_acc: 0.1882 - val_auc_pr: 0.1703 - val_auc_roc: 0.4928 - val_loss: 0.0692 - learning_rate: 3.0000e-04
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - acc: 0.3838 - auc_pr: 0.1879 - auc_roc: 0.4834 - loss: 0.0721
# Epoch 7: val_auc_roc did not improve from 0.51721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 342ms/step - acc: 0.4414 - auc_pr: 0.1816 - auc_roc: 0.5074 - loss: 0.0700 - val_acc: 0.8118 - val_auc_pr: 0.1803 - val_auc_roc: 0.5109 - val_loss: 0.0686 - learning_rate: 3.0000e-04
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - acc: 0.5976 - auc_pr: 0.1740 - auc_roc: 0.4474 - loss: 0.0705
# Epoch 8: val_auc_roc did not improve from 0.51721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - acc: 0.5885 - auc_pr: 0.1697 - auc_roc: 0.4376 - loss: 0.0718 - val_acc: 0.8000 - val_auc_pr: 0.1684 - val_auc_roc: 0.4701 - val_loss: 0.0682 - learning_rate: 3.0000e-04
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - acc: 0.5611 - auc_pr: 0.1621 - auc_roc: 0.4663 - loss: 0.0697
# Epoch 9: val_auc_roc did not improve from 0.51721
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 333ms/step - acc: 0.5736 - auc_pr: 0.2018 - auc_roc: 0.5254 - loss: 0.0692 - val_acc: 0.8118 - val_auc_pr: 0.1670 - val_auc_roc: 0.4642 - val_loss: 0.0680 - learning_rate: 3.0000e-04
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - acc: 0.5555 - auc_pr: 0.1814 - auc_roc: 0.4812 - loss: 0.0666
# Epoch 10: val_auc_roc improved from 0.51721 to 0.53487, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 10: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - acc: 0.5561 - auc_pr: 0.1862 - auc_roc: 0.4895 - loss: 0.0697 - val_acc: 0.7294 - val_auc_pr: 0.1912 - val_auc_roc: 0.5349 - val_loss: 0.0678 - learning_rate: 3.0000e-04
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5590 - auc_pr: 0.2362 - auc_roc: 0.5948 - loss: 0.0652
# Epoch 11: val_auc_roc did not improve from 0.53487
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5262 - auc_pr: 0.1965 - auc_roc: 0.5305 - loss: 0.0686 - val_acc: 0.6235 - val_auc_pr: 0.2043 - val_auc_roc: 0.5249 - val_loss: 0.0676 - learning_rate: 3.0000e-04
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - acc: 0.4102 - auc_pr: 0.1656 - auc_roc: 0.4447 - loss: 0.0688
# Epoch 12: val_auc_roc improved from 0.53487 to 0.54529, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 12: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 341ms/step - acc: 0.4239 - auc_pr: 0.1712 - auc_roc: 0.4600 - loss: 0.0697 - val_acc: 0.7412 - val_auc_pr: 0.1983 - val_auc_roc: 0.5453 - val_loss: 0.0674 - learning_rate: 3.0000e-04
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - acc: 0.5170 - auc_pr: 0.1960 - auc_roc: 0.4685 - loss: 0.0677
# Epoch 13: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 357ms/step - acc: 0.5287 - auc_pr: 0.2157 - auc_roc: 0.4537 - loss: 0.0695 - val_acc: 0.8118 - val_auc_pr: 0.1826 - val_auc_roc: 0.4900 - val_loss: 0.0673 - learning_rate: 3.0000e-04
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - acc: 0.5650 - auc_pr: 0.2334 - auc_roc: 0.5342 - loss: 0.0690
# Epoch 14: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 336ms/step - acc: 0.5337 - auc_pr: 0.2110 - auc_roc: 0.5073 - loss: 0.0683 - val_acc: 0.7294 - val_auc_pr: 0.1857 - val_auc_roc: 0.5018 - val_loss: 0.0670 - learning_rate: 3.0000e-04
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - acc: 0.4738 - auc_pr: 0.1522 - auc_roc: 0.4511 - loss: 0.0679
# Epoch 15: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - acc: 0.5012 - auc_pr: 0.1604 - auc_roc: 0.4395 - loss: 0.0697 - val_acc: 0.8118 - val_auc_pr: 0.1755 - val_auc_roc: 0.4760 - val_loss: 0.0668 - learning_rate: 3.0000e-04
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - acc: 0.5231 - auc_pr: 0.2025 - auc_roc: 0.5123 - loss: 0.0693
# Epoch 16: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 339ms/step - acc: 0.5237 - auc_pr: 0.1874 - auc_roc: 0.5002 - loss: 0.0683 - val_acc: 0.8118 - val_auc_pr: 0.2034 - val_auc_roc: 0.5217 - val_loss: 0.0666 - learning_rate: 3.0000e-04
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - acc: 0.4736 - auc_pr: 0.1981 - auc_roc: 0.4492 - loss: 0.0736
# Epoch 17: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 343ms/step - acc: 0.4713 - auc_pr: 0.1794 - auc_roc: 0.4819 - loss: 0.0687 - val_acc: 0.8118 - val_auc_pr: 0.1794 - val_auc_roc: 0.4751 - val_loss: 0.0665 - learning_rate: 3.0000e-04
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - acc: 0.5522 - auc_pr: 0.1499 - auc_roc: 0.4396 - loss: 0.0665
# Epoch 18: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - acc: 0.5985 - auc_pr: 0.1852 - auc_roc: 0.4823 - loss: 0.0685 - val_acc: 0.8118 - val_auc_pr: 0.1766 - val_auc_roc: 0.4882 - val_loss: 0.0665 - learning_rate: 3.0000e-04
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - acc: 0.5027 - auc_pr: 0.2343 - auc_roc: 0.4565 - loss: 0.0727
# Epoch 19: val_auc_roc did not improve from 0.54529
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - acc: 0.4514 - auc_pr: 0.1856 - auc_roc: 0.4616 - loss: 0.0690 - val_acc: 0.5882 - val_auc_pr: 0.2143 - val_auc_roc: 0.5421 - val_loss: 0.0661 - learning_rate: 3.0000e-04
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - acc: 0.4518 - auc_pr: 0.1151 - auc_roc: 0.3331 - loss: 0.0665
# Epoch 20: val_auc_roc improved from 0.54529 to 0.55072, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 20: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 398ms/step - acc: 0.4963 - auc_pr: 0.1623 - auc_roc: 0.4038 - loss: 0.0698 - val_acc: 0.8118 - val_auc_pr: 0.2227 - val_auc_roc: 0.5507 - val_loss: 0.0660 - learning_rate: 3.0000e-04
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - acc: 0.5431 - auc_pr: 0.1710 - auc_roc: 0.5071 - loss: 0.0648
# Epoch 21: val_auc_roc did not improve from 0.55072
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - acc: 0.4938 - auc_pr: 0.1692 - auc_roc: 0.4252 - loss: 0.0692 - val_acc: 0.8000 - val_auc_pr: 0.1700 - val_auc_roc: 0.4588 - val_loss: 0.0658 - learning_rate: 3.0000e-04
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - acc: 0.4927 - auc_pr: 0.1713 - auc_roc: 0.4599 - loss: 0.0647
# Epoch 22: val_auc_roc did not improve from 0.55072
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 367ms/step - acc: 0.4589 - auc_pr: 0.2002 - auc_roc: 0.4936 - loss: 0.0672 - val_acc: 0.5294 - val_auc_pr: 0.2027 - val_auc_roc: 0.5322 - val_loss: 0.0656 - learning_rate: 3.0000e-04
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - acc: 0.4462 - auc_pr: 0.1516 - auc_roc: 0.3866 - loss: 0.0694
# Epoch 23: val_auc_roc did not improve from 0.55072
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 392ms/step - acc: 0.5037 - auc_pr: 0.1879 - auc_roc: 0.4789 - loss: 0.0680 - val_acc: 0.8235 - val_auc_pr: 0.2149 - val_auc_roc: 0.5448 - val_loss: 0.0655 - learning_rate: 3.0000e-04
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - acc: 0.5136 - auc_pr: 0.2349 - auc_roc: 0.5409 - loss: 0.0680
# Epoch 24: val_auc_roc did not improve from 0.55072
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 366ms/step - acc: 0.4613 - auc_pr: 0.1906 - auc_roc: 0.5003 - loss: 0.0668 - val_acc: 0.4353 - val_auc_pr: 0.1936 - val_auc_roc: 0.5231 - val_loss: 0.0653 - learning_rate: 3.0000e-04
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - acc: 0.4954 - auc_pr: 0.2834 - auc_roc: 0.5019 - loss: 0.0703
# Epoch 25: val_auc_roc improved from 0.55072 to 0.55208, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 25: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - acc: 0.5337 - auc_pr: 0.2285 - auc_roc: 0.5055 - loss: 0.0665 - val_acc: 0.8118 - val_auc_pr: 0.2166 - val_auc_roc: 0.5521 - val_loss: 0.0654 - learning_rate: 3.0000e-04
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - acc: 0.6178 - auc_pr: 0.2103 - auc_roc: 0.5223 - loss: 0.0686
# Epoch 26: val_auc_roc did not improve from 0.55208
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - acc: 0.6259 - auc_pr: 0.2010 - auc_roc: 0.5358 - loss: 0.0661 - val_acc: 0.8118 - val_auc_pr: 0.2166 - val_auc_roc: 0.5521 - val_loss: 0.0651 - learning_rate: 3.0000e-04
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - acc: 0.5887 - auc_pr: 0.1916 - auc_roc: 0.4772 - loss: 0.0647
# Epoch 27: val_auc_roc improved from 0.55208 to 0.57382, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 27: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5686 - auc_pr: 0.2025 - auc_roc: 0.4792 - loss: 0.0668 - val_acc: 0.8118 - val_auc_pr: 0.2433 - val_auc_roc: 0.5738 - val_loss: 0.0649 - learning_rate: 3.0000e-04
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - acc: 0.5192 - auc_pr: 0.2160 - auc_roc: 0.5463 - loss: 0.0652
# Epoch 28: val_auc_roc did not improve from 0.57382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 361ms/step - acc: 0.4988 - auc_pr: 0.1934 - auc_roc: 0.5119 - loss: 0.0663 - val_acc: 0.7059 - val_auc_pr: 0.2735 - val_auc_roc: 0.5380 - val_loss: 0.0647 - learning_rate: 3.0000e-04
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.5068 - auc_pr: 0.2047 - auc_roc: 0.5267 - loss: 0.0641
# Epoch 29: val_auc_roc did not improve from 0.57382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5486 - auc_pr: 0.2032 - auc_roc: 0.5379 - loss: 0.0652 - val_acc: 0.8118 - val_auc_pr: 0.1738 - val_auc_roc: 0.4764 - val_loss: 0.0646 - learning_rate: 3.0000e-04
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - acc: 0.5628 - auc_pr: 0.1859 - auc_roc: 0.4871 - loss: 0.0670
# Epoch 30: val_auc_roc did not improve from 0.57382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 342ms/step - acc: 0.5237 - auc_pr: 0.1714 - auc_roc: 0.4739 - loss: 0.0671 - val_acc: 0.8118 - val_auc_pr: 0.2706 - val_auc_roc: 0.5312 - val_loss: 0.0645 - learning_rate: 3.0000e-04
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - acc: 0.5792 - auc_pr: 0.2110 - auc_roc: 0.5518 - loss: 0.0642
# Epoch 31: val_auc_roc did not improve from 0.57382
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - acc: 0.5611 - auc_pr: 0.2206 - auc_roc: 0.5415 - loss: 0.0648 - val_acc: 0.6706 - val_auc_pr: 0.2335 - val_auc_roc: 0.5403 - val_loss: 0.0643 - learning_rate: 3.0000e-04
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - acc: 0.4627 - auc_pr: 0.1715 - auc_roc: 0.4392 - loss: 0.0666
# Epoch 32: val_auc_roc improved from 0.57382 to 0.57654, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 32: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - acc: 0.4813 - auc_pr: 0.1744 - auc_roc: 0.4492 - loss: 0.0668 - val_acc: 0.8235 - val_auc_pr: 0.2670 - val_auc_roc: 0.5765 - val_loss: 0.0642 - learning_rate: 3.0000e-04
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - acc: 0.4662 - auc_pr: 0.2283 - auc_roc: 0.5002 - loss: 0.0669
# Epoch 33: val_auc_roc did not improve from 0.57654
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - acc: 0.4613 - auc_pr: 0.2069 - auc_roc: 0.4959 - loss: 0.0658 - val_acc: 0.8118 - val_auc_pr: 0.2191 - val_auc_roc: 0.5639 - val_loss: 0.0641 - learning_rate: 3.0000e-04
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5278 - auc_pr: 0.1871 - auc_roc: 0.4374 - loss: 0.0698
# Epoch 34: val_auc_roc did not improve from 0.57654
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 344ms/step - acc: 0.5187 - auc_pr: 0.1730 - auc_roc: 0.4547 - loss: 0.0667 - val_acc: 0.8235 - val_auc_pr: 0.1980 - val_auc_roc: 0.5140 - val_loss: 0.0639 - learning_rate: 3.0000e-04
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5131 - auc_pr: 0.2264 - auc_roc: 0.4961 - loss: 0.0693
# Epoch 35: val_auc_roc did not improve from 0.57654
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5187 - auc_pr: 0.2110 - auc_roc: 0.5111 - loss: 0.0657 - val_acc: 0.8118 - val_auc_pr: 0.2216 - val_auc_roc: 0.5756 - val_loss: 0.0639 - learning_rate: 3.0000e-04
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.6364 - auc_pr: 0.1391 - auc_roc: 0.4638 - loss: 0.0620
# Epoch 36: val_auc_roc did not improve from 0.57654
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.6359 - auc_pr: 0.1717 - auc_roc: 0.4682 - loss: 0.0660 - val_acc: 0.8118 - val_auc_pr: 0.1927 - val_auc_roc: 0.5068 - val_loss: 0.0639 - learning_rate: 3.0000e-04
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5346 - auc_pr: 0.2927 - auc_roc: 0.5233 - loss: 0.0644
# Epoch 37: val_auc_roc improved from 0.57654 to 0.57926, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 37: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - acc: 0.4888 - auc_pr: 0.1945 - auc_roc: 0.4712 - loss: 0.0661 - val_acc: 0.5059 - val_auc_pr: 0.3075 - val_auc_roc: 0.5793 - val_loss: 0.0636 - learning_rate: 3.0000e-04
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - acc: 0.4660 - auc_pr: 0.2328 - auc_roc: 0.5110 - loss: 0.0658
# Epoch 38: val_auc_roc did not improve from 0.57926
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 353ms/step - acc: 0.4838 - auc_pr: 0.2021 - auc_roc: 0.5090 - loss: 0.0646 - val_acc: 0.8235 - val_auc_pr: 0.1980 - val_auc_roc: 0.5140 - val_loss: 0.0634 - learning_rate: 3.0000e-04
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5357 - auc_pr: 0.1718 - auc_roc: 0.4772 - loss: 0.0639
# Epoch 39: val_auc_roc did not improve from 0.57926
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5337 - auc_pr: 0.1799 - auc_roc: 0.4605 - loss: 0.0655 - val_acc: 0.8118 - val_auc_pr: 0.2801 - val_auc_roc: 0.5584 - val_loss: 0.0635 - learning_rate: 3.0000e-04
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - acc: 0.5570 - auc_pr: 0.1896 - auc_roc: 0.5412 - loss: 0.0632
# Epoch 40: val_auc_roc improved from 0.57926 to 0.58514, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 40: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.5536 - auc_pr: 0.1883 - auc_roc: 0.5277 - loss: 0.0644 - val_acc: 0.8118 - val_auc_pr: 0.3094 - val_auc_roc: 0.5851 - val_loss: 0.0633 - learning_rate: 3.0000e-04
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - acc: 0.5295 - auc_pr: 0.2098 - auc_roc: 0.5231 - loss: 0.0645
# Epoch 41: val_auc_roc did not improve from 0.58514
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 376ms/step - acc: 0.5237 - auc_pr: 0.2095 - auc_roc: 0.5308 - loss: 0.0642 - val_acc: 0.8235 - val_auc_pr: 0.1980 - val_auc_roc: 0.5140 - val_loss: 0.0631 - learning_rate: 3.0000e-04
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5092 - auc_pr: 0.2167 - auc_roc: 0.5501 - loss: 0.0636
# Epoch 42: val_auc_roc improved from 0.58514 to 0.58560, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 42: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - acc: 0.4988 - auc_pr: 0.1886 - auc_roc: 0.4842 - loss: 0.0653 - val_acc: 0.8118 - val_auc_pr: 0.2905 - val_auc_roc: 0.5856 - val_loss: 0.0630 - learning_rate: 3.0000e-04
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - acc: 0.5280 - auc_pr: 0.2429 - auc_roc: 0.5936 - loss: 0.0619
# Epoch 43: val_auc_roc improved from 0.58560 to 0.61639, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 43: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 367ms/step - acc: 0.4888 - auc_pr: 0.1957 - auc_roc: 0.5093 - loss: 0.0646 - val_acc: 0.8118 - val_auc_pr: 0.2391 - val_auc_roc: 0.6164 - val_loss: 0.0629 - learning_rate: 3.0000e-04
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - acc: 0.5259 - auc_pr: 0.1914 - auc_roc: 0.5173 - loss: 0.0645
# Epoch 44: val_auc_roc did not improve from 0.61639
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - acc: 0.5337 - auc_pr: 0.1796 - auc_roc: 0.4961 - loss: 0.0648 - val_acc: 0.8118 - val_auc_pr: 0.2905 - val_auc_roc: 0.5856 - val_loss: 0.0628 - learning_rate: 3.0000e-04
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5670 - auc_pr: 0.1806 - auc_roc: 0.4974 - loss: 0.0637
# Epoch 45: val_auc_roc improved from 0.61639 to 0.63361, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 45: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 351ms/step - acc: 0.5362 - auc_pr: 0.1665 - auc_roc: 0.4515 - loss: 0.0656 - val_acc: 0.8118 - val_auc_pr: 0.2581 - val_auc_roc: 0.6336 - val_loss: 0.0627 - learning_rate: 3.0000e-04
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - acc: 0.5279 - auc_pr: 0.1646 - auc_roc: 0.4881 - loss: 0.0616
# Epoch 46: val_auc_roc did not improve from 0.63361
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - acc: 0.5362 - auc_pr: 0.1909 - auc_roc: 0.4953 - loss: 0.0643 - val_acc: 0.8118 - val_auc_pr: 0.2078 - val_auc_roc: 0.5580 - val_loss: 0.0626 - learning_rate: 3.0000e-04
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - acc: 0.5304 - auc_pr: 0.1702 - auc_roc: 0.4897 - loss: 0.0627
# Epoch 47: val_auc_roc did not improve from 0.63361
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.5362 - auc_pr: 0.2070 - auc_roc: 0.5139 - loss: 0.0638 - val_acc: 0.8118 - val_auc_pr: 0.3075 - val_auc_roc: 0.5793 - val_loss: 0.0625 - learning_rate: 3.0000e-04
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.4744 - auc_pr: 0.2000 - auc_roc: 0.4905 - loss: 0.0650
# Epoch 48: val_auc_roc improved from 0.63361 to 0.66712, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 48: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 352ms/step - acc: 0.4564 - auc_pr: 0.1814 - auc_roc: 0.4813 - loss: 0.0643 - val_acc: 0.8235 - val_auc_pr: 0.2720 - val_auc_roc: 0.6671 - val_loss: 0.0624 - learning_rate: 3.0000e-04
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - acc: 0.5436 - auc_pr: 0.2816 - auc_roc: 0.5555 - loss: 0.0621
# Epoch 49: val_auc_roc did not improve from 0.66712
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - acc: 0.5411 - auc_pr: 0.2311 - auc_roc: 0.5468 - loss: 0.0628 - val_acc: 0.8118 - val_auc_pr: 0.2674 - val_auc_roc: 0.6291 - val_loss: 0.0624 - learning_rate: 3.0000e-04
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5272 - auc_pr: 0.1850 - auc_roc: 0.4637 - loss: 0.0649
# Epoch 50: val_auc_roc did not improve from 0.66712
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5062 - auc_pr: 0.1634 - auc_roc: 0.4361 - loss: 0.0650 - val_acc: 0.8118 - val_auc_pr: 0.2720 - val_auc_roc: 0.6671 - val_loss: 0.0622 - learning_rate: 3.0000e-04
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.5322 - auc_pr: 0.1598 - auc_roc: 0.4923 - loss: 0.0614
# Epoch 51: val_auc_roc did not improve from 0.66712
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - acc: 0.5312 - auc_pr: 0.1738 - auc_roc: 0.4784 - loss: 0.0640 - val_acc: 0.8118 - val_auc_pr: 0.2424 - val_auc_roc: 0.6377 - val_loss: 0.0621 - learning_rate: 3.0000e-04
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - acc: 0.5523 - auc_pr: 0.2285 - auc_roc: 0.5230 - loss: 0.0614
# Epoch 52: val_auc_roc improved from 0.66712 to 0.73188, saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
#
# Epoch 52: finished saving model to models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5137 - auc_pr: 0.2062 - auc_roc: 0.4928 - loss: 0.0637 - val_acc: 0.2471 - val_auc_pr: 0.3019 - val_auc_roc: 0.7319 - val_loss: 0.0620 - learning_rate: 3.0000e-04
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - acc: 0.4842 - auc_pr: 0.1842 - auc_roc: 0.5300 - loss: 0.0623
# Epoch 53: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - acc: 0.4688 - auc_pr: 0.1863 - auc_roc: 0.5141 - loss: 0.0634 - val_acc: 0.8118 - val_auc_pr: 0.2905 - val_auc_roc: 0.5856 - val_loss: 0.0619 - learning_rate: 3.0000e-04
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5748 - auc_pr: 0.2025 - auc_roc: 0.5053 - loss: 0.0605
# Epoch 54: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5860 - auc_pr: 0.2163 - auc_roc: 0.5189 - loss: 0.0630 - val_acc: 0.8118 - val_auc_pr: 0.2801 - val_auc_roc: 0.5584 - val_loss: 0.0619 - learning_rate: 3.0000e-04
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5806 - auc_pr: 0.2650 - auc_roc: 0.6092 - loss: 0.0606
# Epoch 55: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 344ms/step - acc: 0.5212 - auc_pr: 0.2413 - auc_roc: 0.5814 - loss: 0.0618 - val_acc: 0.5059 - val_auc_pr: 0.2933 - val_auc_roc: 0.5924 - val_loss: 0.0617 - learning_rate: 3.0000e-04
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - acc: 0.4520 - auc_pr: 0.2652 - auc_roc: 0.5291 - loss: 0.0628
# Epoch 56: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - acc: 0.4638 - auc_pr: 0.2239 - auc_roc: 0.5032 - loss: 0.0631 - val_acc: 0.8118 - val_auc_pr: 0.1893 - val_auc_roc: 0.5054 - val_loss: 0.0618 - learning_rate: 3.0000e-04
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - acc: 0.5890 - auc_pr: 0.2219 - auc_roc: 0.5409 - loss: 0.0633
# Epoch 57: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - acc: 0.5536 - auc_pr: 0.2017 - auc_roc: 0.5091 - loss: 0.0629 - val_acc: 0.8118 - val_auc_pr: 0.2216 - val_auc_roc: 0.5575 - val_loss: 0.0616 - learning_rate: 3.0000e-04
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - acc: 0.4754 - auc_pr: 0.1798 - auc_roc: 0.4212 - loss: 0.0665
# Epoch 58: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.4838 - auc_pr: 0.1928 - auc_roc: 0.4789 - loss: 0.0637 - val_acc: 0.8118 - val_auc_pr: 0.2903 - val_auc_roc: 0.7083 - val_loss: 0.0615 - learning_rate: 3.0000e-04
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5543 - auc_pr: 0.2576 - auc_roc: 0.5452 - loss: 0.0639
# Epoch 59: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5536 - auc_pr: 0.2237 - auc_roc: 0.5406 - loss: 0.0622 - val_acc: 0.8118 - val_auc_pr: 0.2507 - val_auc_roc: 0.6322 - val_loss: 0.0615 - learning_rate: 3.0000e-04
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.5453 - auc_pr: 0.1680 - auc_roc: 0.4552 - loss: 0.0642
# Epoch 60: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.5536 - auc_pr: 0.1726 - auc_roc: 0.4700 - loss: 0.0643 - val_acc: 0.8118 - val_auc_pr: 0.2581 - val_auc_roc: 0.6667 - val_loss: 0.0614 - learning_rate: 3.0000e-04
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.5064 - auc_pr: 0.1856 - auc_roc: 0.4233 - loss: 0.0663
# Epoch 61: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5037 - auc_pr: 0.1826 - auc_roc: 0.4574 - loss: 0.0638 - val_acc: 0.8118 - val_auc_pr: 0.2388 - val_auc_roc: 0.6304 - val_loss: 0.0612 - learning_rate: 3.0000e-04
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - acc: 0.5190 - auc_pr: 0.2199 - auc_roc: 0.5268 - loss: 0.0637
# Epoch 62: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - acc: 0.4713 - auc_pr: 0.1886 - auc_roc: 0.5154 - loss: 0.0626 - val_acc: 0.8118 - val_auc_pr: 0.2581 - val_auc_roc: 0.6667 - val_loss: 0.0611 - learning_rate: 3.0000e-04
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - acc: 0.5669 - auc_pr: 0.2911 - auc_roc: 0.6050 - loss: 0.0625
# Epoch 63: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 351ms/step - acc: 0.5736 - auc_pr: 0.2220 - auc_roc: 0.5399 - loss: 0.0620 - val_acc: 0.8118 - val_auc_pr: 0.2388 - val_auc_roc: 0.6304 - val_loss: 0.0615 - learning_rate: 3.0000e-04
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - acc: 0.5829 - auc_pr: 0.2040 - auc_roc: 0.4621 - loss: 0.0654
# Epoch 64: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 350ms/step - acc: 0.5337 - auc_pr: 0.1811 - auc_roc: 0.4640 - loss: 0.0635 - val_acc: 0.4353 - val_auc_pr: 0.2653 - val_auc_roc: 0.6712 - val_loss: 0.0610 - learning_rate: 3.0000e-04
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - acc: 0.4104 - auc_pr: 0.1955 - auc_roc: 0.4350 - loss: 0.0646
# Epoch 65: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 344ms/step - acc: 0.4564 - auc_pr: 0.1771 - auc_roc: 0.4690 - loss: 0.0628 - val_acc: 0.8118 - val_auc_pr: 0.2303 - val_auc_roc: 0.6304 - val_loss: 0.0610 - learning_rate: 3.0000e-04
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5434 - auc_pr: 0.2169 - auc_roc: 0.5017 - loss: 0.0643
# Epoch 66: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.5187 - auc_pr: 0.1845 - auc_roc: 0.4961 - loss: 0.0629 - val_acc: 0.8118 - val_auc_pr: 0.1870 - val_auc_roc: 0.5534 - val_loss: 0.0609 - learning_rate: 3.0000e-04
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - acc: 0.4833 - auc_pr: 0.1890 - auc_roc: 0.4239 - loss: 0.0646
# Epoch 67: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - acc: 0.4913 - auc_pr: 0.1815 - auc_roc: 0.4575 - loss: 0.0633 - val_acc: 0.8118 - val_auc_pr: 0.2500 - val_auc_roc: 0.6522 - val_loss: 0.0608 - learning_rate: 3.0000e-04
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - acc: 0.5235 - auc_pr: 0.2623 - auc_roc: 0.5411 - loss: 0.0626
# Epoch 68: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.4838 - auc_pr: 0.2098 - auc_roc: 0.4953 - loss: 0.0623 - val_acc: 0.8118 - val_auc_pr: 0.1867 - val_auc_roc: 0.5326 - val_loss: 0.0607 - learning_rate: 3.0000e-04
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - acc: 0.5129 - auc_pr: 0.1920 - auc_roc: 0.4513 - loss: 0.0630
# Epoch 69: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - acc: 0.5212 - auc_pr: 0.1820 - auc_roc: 0.4508 - loss: 0.0632 - val_acc: 0.8118 - val_auc_pr: 0.2712 - val_auc_roc: 0.6884 - val_loss: 0.0607 - learning_rate: 3.0000e-04
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - acc: 0.5495 - auc_pr: 0.2626 - auc_roc: 0.5479 - loss: 0.0638
# Epoch 70: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 352ms/step - acc: 0.5362 - auc_pr: 0.2526 - auc_roc: 0.5589 - loss: 0.0611 - val_acc: 0.8118 - val_auc_pr: 0.2292 - val_auc_roc: 0.6377 - val_loss: 0.0605 - learning_rate: 3.0000e-04
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5841 - auc_pr: 0.1842 - auc_roc: 0.5078 - loss: 0.0612
# Epoch 71: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5935 - auc_pr: 0.2244 - auc_roc: 0.5540 - loss: 0.0615 - val_acc: 0.8118 - val_auc_pr: 0.2581 - val_auc_roc: 0.6667 - val_loss: 0.0605 - learning_rate: 3.0000e-04
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - acc: 0.5233 - auc_pr: 0.2131 - auc_roc: 0.5096 - loss: 0.0615
# Epoch 72: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - acc: 0.5337 - auc_pr: 0.2343 - auc_roc: 0.5245 - loss: 0.0615 - val_acc: 0.4706 - val_auc_pr: 0.2162 - val_auc_roc: 0.6087 - val_loss: 0.0604 - learning_rate: 3.0000e-04
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - acc: 0.4481 - auc_pr: 0.1791 - auc_roc: 0.4622 - loss: 0.0624
# Epoch 73: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 356ms/step - acc: 0.4788 - auc_pr: 0.1948 - auc_roc: 0.4733 - loss: 0.0627 - val_acc: 0.8118 - val_auc_pr: 0.2228 - val_auc_roc: 0.6304 - val_loss: 0.0605 - learning_rate: 3.0000e-04
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - acc: 0.5342 - auc_pr: 0.2289 - auc_roc: 0.5001 - loss: 0.0650
# Epoch 74: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - acc: 0.5237 - auc_pr: 0.1843 - auc_roc: 0.4928 - loss: 0.0623 - val_acc: 0.8118 - val_auc_pr: 0.1951 - val_auc_roc: 0.5562 - val_loss: 0.0603 - learning_rate: 3.0000e-04
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - acc: 0.5963 - auc_pr: 0.2258 - auc_roc: 0.5616 - loss: 0.0597
# Epoch 75: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 357ms/step - acc: 0.6160 - auc_pr: 0.2373 - auc_roc: 0.5350 - loss: 0.0615 - val_acc: 0.8118 - val_auc_pr: 0.2578 - val_auc_roc: 0.6626 - val_loss: 0.0603 - learning_rate: 3.0000e-04
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - acc: 0.5828 - auc_pr: 0.2548 - auc_roc: 0.5304 - loss: 0.0619
# Epoch 76: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - acc: 0.5436 - auc_pr: 0.2079 - auc_roc: 0.5392 - loss: 0.0611 - val_acc: 0.6471 - val_auc_pr: 0.2582 - val_auc_roc: 0.6639 - val_loss: 0.0601 - learning_rate: 3.0000e-04
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - acc: 0.5117 - auc_pr: 0.1715 - auc_roc: 0.5020 - loss: 0.0587
# Epoch 77: val_auc_roc did not improve from 0.73188
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - acc: 0.5486 - auc_pr: 0.1948 - auc_roc: 0.4932 - loss: 0.0624 - val_acc: 0.8118 - val_auc_pr: 0.2171 - val_auc_roc: 0.5978 - val_loss: 0.0600 - learning_rate: 3.0000e-04
# Epoch 77: early stopping
# Restoring model weights from the end of the best epoch: 52.
#
# Checkpoint guardado en: models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# Historial en: results/training_history_maiz_t4_vs_otros.csv

# %% [markdown]
# ## 7. Evaluación

# %%
trained_model = model

def predict_binary(ds, model, threshold=0.5):

    y_true, y_prob = [], []

    for xb, yb in ds:

        logits = model(xb, training=False,).numpy().reshape(-1)
        prob = tf.sigmoid(logits).numpy()
        y_true.extend(yb.numpy().astype(int).tolist())
        y_prob.extend(prob.tolist())

    y_true = np.array(y_true, dtype=int)
    y_prob = np.array(y_prob, dtype=float)
    y_pred = (y_prob >= threshold).astype(int)

    return y_true, y_pred, y_prob

print("Prediciendo val...")
y_val_true,  y_val_pred,  y_val_prob  = predict_binary(val_ds,  trained_model)

print("Prediciendo test...")
y_test_true, y_test_pred, y_test_prob = predict_binary(test_ds, trained_model)

metrics_rows = []
for split, yt, yp, yprob in [
    ("val",  y_val_true,  y_val_pred,  y_val_prob),
    ("test", y_test_true, y_test_pred, y_test_prob),
]:

    metrics_rows.append({
        "split":     split,
        "acc":       accuracy_score(yt, yp),
        "precision": precision_score(yt, yp, zero_division=0),
        "recall":    recall_score(yt, yp, zero_division=0),
        "f1":        f1_score(yt, yp, zero_division=0),
        "auc":       roc_auc_score(yt, yprob),
        "kappa":     cohen_kappa_score(yt, yp),
    })

metrics_df = pd.DataFrame(metrics_rows)

display(metrics_df.round(4))

print("\nReporte de clasificación (Test):")
print(classification_report(y_test_true, y_test_pred,
                             target_names=["Otros", "T4"], zero_division=0))
# Out:
# Prediciendo val...
# Prediciendo test...
#   split     acc  precision  recall      f1     auc   kappa
# 0   val  0.2471     0.2000     1.0  0.3333  0.7011  0.0286
# 1  test  0.2967     0.2195     1.0  0.3600  0.7694  0.0527
# Reporte de clasificación (Test):
#               precision    recall  f1-score   support
#
#        Otros       1.00      0.12      0.22        73
#           T4       0.22      1.00      0.36        18
#
#     accuracy                           0.30        91
#    macro avg       0.61      0.56      0.29        91
# weighted avg       0.85      0.30      0.25        91

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 5))

h = history.history

train_acc_key = "acc" if "acc" in h else "accuracy"
val_acc_key = "val_acc" if "val_acc" in h else "val_accuracy"
train_auc_key = "auc_roc" if "auc_roc" in h else "auc"
val_auc_key = "val_auc_roc" if "val_auc_roc" in h else "val_auc"

# Curvas de entrenamiento
axes[0].plot(h[train_acc_key], label="train acc")
axes[0].plot(h[val_acc_key], label="val acc")
axes[0].plot(h[train_auc_key], label="train AUC-ROC")
axes[0].plot(h[val_auc_key], label="val AUC-ROC")

if "auc_pr" in h and "val_auc_pr" in h:
    axes[0].plot(h["auc_pr"], label="train AUC-PR", alpha=0.7)
    axes[0].plot(h["val_auc_pr"], label="val AUC-PR", alpha=0.7)

axes[0].set_title("Accuracy / AUC")
axes[0].set_xlabel("Epoch")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

cm_val  = confusion_matrix(y_val_true,  y_val_pred)
cm_test = confusion_matrix(y_test_true, y_test_pred)

ConfusionMatrixDisplay(cm_val,  display_labels=["Otros", "T4"]).plot(
    ax=axes[1], colorbar=False, cmap="Blues")
axes[1].set_title("Matriz de confusión - Val")
axes[1].grid(False)

ConfusionMatrixDisplay(cm_test, display_labels=["Otros", "T4"]).plot(
    ax=axes[2], colorbar=False, cmap="Blues")
axes[2].set_title("Matriz de confusión - Test")
axes[2].grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Grad-CAM: visualización de zonas de activación
#
# Grad-CAM muestra qué zonas espaciales de la hoja activaron más la predicción **T4** (deficiencia severa de P en maíz).

# %%
def _get_last_conv_layer_name(model):
    for layer in reversed(model.layers):
        if isinstance(layer, (tf.keras.layers.SeparableConv2D, tf.keras.layers.Conv2D)):
            return layer.name
    raise ValueError("No se encontró capa convolucional en el modelo.")


def gradcam_heatmap_binary(img_array, model, conv_layer_name):
    """
    Grad-CAM para clasificación binaria con logit de salida único.
    El gradiente se toma respecto al único logit (positivo = T4).
    """
    grad_model = tf.keras.Model(
        inputs=model.inputs,
        outputs=[model.get_layer(conv_layer_name).output, model.output],
    )
    img_tensor = tf.cast(img_array, tf.float32)

    with tf.GradientTape() as tape:
        conv_out, logit = grad_model(img_tensor, training=False)
        score = logit[0, 0]  # único logit; positivo = T4

    grads  = tape.gradient(score, conv_out)
    pooled = tf.reduce_mean(grads, axis=(0, 1, 2))
    cam    = tf.squeeze(conv_out[0] @ pooled[..., tf.newaxis])
    cam    = tf.nn.relu(cam).numpy()
    if cam.max() > 0:
        cam = cam / cam.max()
    prob = float(tf.sigmoid(logit[0, 0]).numpy())
    return cam, prob


def overlay_heatmap(img_rgb, heatmap, alpha=0.50):
    H, W = img_rgb.shape[:2]
    cam_resized = tf.image.resize(
        heatmap[..., np.newaxis], [H, W], method="bilinear"
    ).numpy().squeeze()
    colored = plt.cm.jet(cam_resized)[:, :, :3]
    return np.clip((1 - alpha) * img_rgb + alpha * colored, 0, 1)


last_conv_layer = _get_last_conv_layer_name(trained_model)
print(f"Capa objetivo Grad-CAM: '{last_conv_layer}'")

target_layer = trained_model.get_layer(last_conv_layer)
activation_shape = getattr(target_layer, "output_shape", None)
if activation_shape is None:
    activation_shape = tuple(target_layer.output.shape)
print(f"Shape de activaciones: {activation_shape}")
# Out:
# Capa objetivo Grad-CAM: 'separable_conv2d_2'
# Shape de activaciones: (None, 32, 32, 128)

# %%
# Parámetros de visualización
N_PER_CLASS   = 4
ALPHA_OVERLAY = 0.50
BANDS_RGB     = (8, 4, 1)  # falso color: NIR, Red-Edge, Blue

# Recolectar tensores de test por clase binaria
samples_by_label = {0: [], 1: []}
for xb, yb in test_ds:
    for xi, yi in zip(xb.numpy(), yb.numpy()):
        lbl = int(yi)
        if len(samples_by_label[lbl]) < N_PER_CLASS:
            samples_by_label[lbl].append(xi)
    if all(len(v) >= N_PER_CLASS for v in samples_by_label.values()):
        break

label_display = {0: "Otros", 1: "T4"}
total_rows = 2 * N_PER_CLASS
fig, axes = plt.subplots(total_rows, 3, figsize=(11, 2.6 * total_rows))

col_titles = ["RGB falso color\n(bandas NIR-RE-Blue)", "Grad-CAM (heatmap)", "Superposición"]
for col, ct in enumerate(col_titles):
    axes[0, col].set_title(ct, fontsize=10, fontweight="bold")

row = 0
for lbl in [0, 1]:
    for sample_i, tensor in enumerate(samples_by_label[lbl][:N_PER_CLASS]):
        img_input = tensor[np.newaxis]

        cam, prob = gradcam_heatmap_binary(img_input, trained_model, last_conv_layer)
        pred_lbl  = 1 if prob >= 0.5 else 0
        is_correct = pred_lbl == lbl
        result_str = f"✓ p={prob:.2f}" if is_correct else f"✗ p={prob:.2f}"

        b0, b1, b2 = BANDS_RGB
        rgb = np.stack([tensor[:, :, b0], tensor[:, :, b1], tensor[:, :, b2]], axis=-1)
        rmin, rmax = rgb.min(), rgb.max()
        rgb_norm = np.clip((rgb - rmin) / (rmax - rmin + 1e-6), 0, 1)

        overlay = overlay_heatmap(rgb_norm, cam, alpha=ALPHA_OVERLAY)

        axes[row, 0].imshow(rgb_norm)
        axes[row, 0].set_ylabel(f"{label_display[lbl]}  #{sample_i + 1}\n({result_str})",
                                fontsize=8, labelpad=4)
        axes[row, 0].axis("off")

        im = axes[row, 1].imshow(cam, cmap="jet", vmin=0, vmax=1)
        axes[row, 1].axis("off")

        axes[row, 2].imshow(overlay)
        axes[row, 2].axis("off")

        row += 1

cbar_ax = fig.add_axes([0.37, 0.01, 0.27, 0.008])
plt.colorbar(im, cax=cbar_ax, orientation="horizontal").set_label(
    "Activación Grad-CAM (0 = baja, 1 = alta)", fontsize=8
)
plt.suptitle(
    f"Grad-CAM — T4 vs Otros (Maíz)  |  capa: '{last_conv_layer}'  |  "
    f"falso color bandas {BANDS_RGB}\n"
    "p = probabilidad de ser T4 (≥0.5 → predicción T4)",
    fontsize=10, y=1.003,
)
plt.tight_layout(rect=[0, 0.02, 1, 1])
plt.show()
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_19300\3978437923.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.02, 1, 1])

# %% [markdown]
# ## 9. Guardado de artefactos

# %%
final_model_path = "models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_final.keras"
metrics_path     = "results/training_results_maiz_t4_vs_otros.csv"

trained_model.save(final_model_path)
metrics_df.to_csv(metrics_path, index=False)

print(f"Modelo final:      {final_model_path}")
print(f"Mejor checkpoint:  {best_model_path}")
print(f"Historial:         {history_csv}")
print(f"Métricas:          {metrics_path}")
# Out:
# Modelo final:      models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_final.keras
# Mejor checkpoint:  models/maiz/maiz_model_cnn_multispectral_tensor_t4_vs_otros_best.keras
# Historial:         results/training_history_maiz_t4_vs_otros.csv
# Métricas:          results/training_results_maiz_t4_vs_otros.csv
