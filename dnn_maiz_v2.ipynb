# %% [markdown]
# <div style="font-family:'Georgia','Times New Roman',Times,serif; width:80%; margin:20px auto; padding:10px 20px 20px 20px; background:#ffffff; border-left:20px solid #003366; box-shadow:0 5px 20px rgba(0,0,0,0.1); text-align:center; border-radius:8px;">
#
#   <div style="display:flex; align-items:center; justify-content:center; gap:20px; margin-bottom:15px; padding-bottom:1px; border-bottom:2px solid #eeeeee;">
#     <img src="assets/Logotipo_de_la_Universidad_Nacional_de_Colombia.svg.png" alt="Logo Universidad" style="max-width:80px; height:auto;">
#     <div style="font-size:1.1em; color:#003366; font-weight:bold; text-align:left;">Universidad Nacional de Colombia</div>
#   </div>
#
#   <h1 style="color:#003366; font-size:2.2em; margin:0.6em 0; font-weight:bold; line-height:1.2;">Detección de enfermedades en plantas de maíz y fríjol común con Inteligencia Artificial e imágenes multiespectrales</h1>
#   <h2 style="color:#444444; font-size:1.4em; margin-bottom:0.8em; font-weight:normal; font-style:italic;">Entrenamiento de red neuronal densa con datos de maíz</h2>
#
#   <div style="margin-bottom:0em; font-size:1.1em; color:#222222;">
#     <p style="text-align:center; margin:0;"><strong>Autor:</strong> Selene Solano Vera</p>
#   </div>
#
#   <div style="margin:1.0em 0 1.0em 0; padding:0.8em 0; color:#666666; font-size:1em;">Medellín, Febrero de 2026</div>
#
#   <div style="height:0.1rem;"></div>
#
# </div>

# %% [markdown]
# # Utilidades y Configuración Inicial
#
# Esta sección incluye la importación de bibliotecas necesarias para el entrenamiento de una red neuronal profunda (DNN) con TensorFlow/Keras para la clasificación de deficiencia de nitrógeno en plantas de maíz.

# %%
# TensorFlow y Keras para construcción y entrenamiento de redes neuronales
import tensorflow as tf                     
from tensorflow.keras import Model          

# Manipulación de datos
import pandas as pd                         
import numpy as np                          
import pickle                               
import warnings
import joblib  
import os                           

# Visualizaciones
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn para preprocesamiento y evaluación
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import StandardScaler        
from sklearn.preprocessing import LabelEncoder          
from sklearn.metrics import accuracy_score              
from sklearn.metrics import precision_score             
from sklearn.metrics import f1_score                    
from sklearn.metrics import cohen_kappa_score           
from sklearn.metrics import confusion_matrix            
from sklearn.metrics import classification_report       
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Configuración del tema visual de seaborn
sns.set_theme(style="whitegrid", palette="viridis")

# Configuración de parámetros globales de matplotlib
plt.rcParams['figure.figsize'] = (12, 7)    # Tamaño de figura predeterminado en pulgadas
plt.rcParams['axes.titlesize'] = 18         # Tamaño de fuente para títulos
plt.rcParams['axes.labelsize'] = 14         # Tamaño de fuente para etiquetas de ejes

# Suprimir advertencias para mantener limpia la salida del notebook
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Carga de dataset
#
# Se carga el conjunto de datos de plantas de maíz con información multiespectral para el entrenamiento de la red neuronal profunda.

# %%
# Carga del dataset desde archivo CSV


v2_path = "datasets/new/dataset_maiz_v2.csv"
legacy_path = "datasets/dataset_maiz.csv"
data_path = v2_path if os.path.exists(v2_path) else legacy_path

df = pd.read_csv(data_path)
print(f"Dataset cargado: {data_path}")

# Verificación de la estructura y dimensiones del dataset
print(f"Dataset shape: {df.shape}")
print(f"Columnas: {df.columns.tolist()}")
print(f"\nDistribución de la clase objetivo:")
print(df['tratamiento'].value_counts().sort_index())
print(f"\nData info:")
print(df.info())
# Out:
# Dataset shape: (38676640, 6)
# Columnas: ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'tratamiento', 'banda']
#
# Distribución de la clase objetivo:
# tratamiento
# 1    12232170
# 2    11784660
# 3     6909690
# 4     7750120
# Name: count, dtype: int64
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38676640 entries, 0 to 38676639
# Data columns (total 6 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   pixel_relativo_x  float64
#  1   pixel_relativo_y  float64
#  2   intensidad        int64
#  3   genotipo          int64
#  4   tratamiento       int64
#  5   banda             int64
# dtypes: float64(2), int64(4)
# memory usage: 1.7 GB
# None

# %% [markdown]
# # 2. preparación de los datos

# %% [markdown]
# Esta fase comprende la transformación de los datos crudos al formato requerido por la red neuronal.

# %% [markdown]
# ## 2.1 Codificación de la clase objetivo
#
# Las redes neuronales requieren que las etiquetas de clase sean enteros consecutivos comenzando desde 0. Se utiliza `LabelEncoder` para transformar los tratamientos [1, 2, 3, 4] a [0, 1, 2, 3].

# %%
# Definición de características predictoras
# Nota: si el CSV incluye columnas de identificación (image_id/object_id/plant_id),
# no se usan como predictores.
feature_columns = ['pixel_relativo_x', 'pixel_relativo_y', 'intensidad', 'genotipo', 'banda']
X = df[feature_columns]         # Matriz de características (DataFrame)
y = df['tratamiento'].values    # Vector de etiquetas de clase

print(f"Features shape: {X.shape}")
print(f"Target shape: {y.shape}")

# Encode labels (tratamiento: 1,2,3,4 -> 0,1,2,3 for neural network)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

print(f"Original labels: {np.unique(y)}")
print(f"Encoded labels: {np.unique(y_encoded)}")
print(f"Label mapping: {dict(zip(label_encoder.classes_, range(len(label_encoder.classes_))))}")
# Out:
# Features shape: (38676640, 5)
# Target shape: (38676640,)
# Original labels: [1 2 3 4]
# Encoded labels: [0 1 2 3]
# Label mapping: {1: 0, 2: 1, 3: 2, 4: 3}

# %% [markdown]
# ## 2.2 División del dataset en entrenamiento y prueba

# %%
# División del dataset (80% entrenamiento, 20% prueba)
# Si existe 'plant_id', se usa split por grupos para evitar fuga de información por píxel.
if 'plant_id' in df.columns:
    from sklearn.model_selection import GroupShuffleSplit
    groups = df['plant_id']
    splitter = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
    train_idx, test_idx = next(splitter.split(X, y_encoded, groups=groups))
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]
    print("Split por grupos (plant_id) aplicado.")
else:
    X_train, X_test, y_train, y_test = train_test_split(
        X, y_encoded,
        test_size=0.2,          # 20% para prueba
        random_state=42,        # Semilla para reproducibilidad
        stratify=y_encoded,     # Mantiene proporciones de clases en ambos conjuntos
        shuffle=True            # Mezcla aleatoria antes de dividir
    )
    print("Split por filas aplicado (ADVERTENCIA: posible fuga por píxel).")

print(f"Training set - Features: {X_train.shape}, Labels: {y_train.shape}")
print(f"Test set - Features: {X_test.shape}, Labels: {y_test.shape}")

# Verificación de distribución de clases en los conjuntos divididos
print(f"\nTraining set class distribution:")
train_unique, train_counts = np.unique(y_train, return_counts=True)
for class_label, count in zip(train_unique, train_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_train)*100:.1f}%)")

print(f"\nTest set class distribution:")
test_unique, test_counts = np.unique(y_test, return_counts=True)
for class_label, count in zip(test_unique, test_counts):
    print(f"  Class {class_label}: {count} ({count/len(y_test)*100:.1f}%)")
# Out:
# Training set - Features: (30941312, 5), Labels: (30941312,)
# Test set - Features: (7735328, 5), Labels: (7735328,)
#
# Training set class distribution:
#   Class 0: 9785736 (31.6%)
#   Class 1: 9427728 (30.5%)
#   Class 2: 5527752 (17.9%)
#   Class 3: 6200096 (20.0%)
#
# Test set class distribution:
#   Class 0: 2446434 (31.6%)
#   Class 1: 2356932 (30.5%)
#   Class 2: 1381938 (17.9%)
#   Class 3: 1550024 (20.0%)

# %% [markdown]
# ## 2.3 Estandarización de características

# %%
# Inicialización y aplicación del estandarizador
scaler = StandardScaler()

# Ajuste con datos de entrenamiento y transformación
X_train_scaled = scaler.fit_transform(X_train)
# Transformación del conjunto de prueba usando los mismos parámetros
X_test_scaled = scaler.transform(X_test)

# Conversión a tipos de datos compatibles con TensorFlow
X_train_scaled = X_train_scaled.astype(np.float32)
X_test_scaled = X_test_scaled.astype(np.float32)
y_train = y_train.astype(np.int32)
y_test = y_test.astype(np.int32)

print(f"\nData types after conversion:")
print(f"X_train: {X_train_scaled.dtype}, y_train: {y_train.dtype}")
print(f"X_test: {X_test_scaled.dtype}, y_test: {y_test.dtype}")
# Out:
# Data types after conversion:
# X_train: float32, y_train: int32
# X_test: float32, y_test: int32

# %% [markdown]
# ## 2.3 Convertir a formato dataset de TensorFlow

# %%
# Definición del tamaño de batch para el entrenamiento
BATCH_SIZE = 1000 # Número de muestras procesadas simultáneamente

# Creación del dataset de entrenamiento con optimizaciones
train_ds = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
train_ds = train_ds.shuffle(buffer_size=10000, seed=42) # Mezcla con buffer para aleatoriedad  
train_ds = train_ds.batch(BATCH_SIZE)                   # Agrupa en batches
train_ds = train_ds.prefetch(tf.data.AUTOTUNE)          # Carga anticipada automática

# Creación del dataset de prueba (sin shuffling)
test_ds = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print(f"Training dataset created with batch size: {BATCH_SIZE}")
print(f"Test dataset created with batch size: {BATCH_SIZE}")

# Verificación de la estructura del dataset
for batch_features, batch_labels in train_ds.take(1):
    print(f"\nBatch verification:")
    print(f"Features batch shape: {batch_features.shape}")
    print(f"Labels batch shape: {batch_labels.shape}")
    print(f"Features dtype: {batch_features.dtype}")
    print(f"Labels dtype: {batch_labels.dtype}")
    break
# Out:
# Training dataset created with batch size: 1000
# Test dataset created with batch size: 1000
#
# Batch verification:
# Features batch shape: (1000, 5)
# Labels batch shape: (1000,)
# Features dtype: <dtype: 'float32'>
# Labels dtype: <dtype: 'int32'>

# %% [markdown]
# # 3. Construcción de la Arquitectura de Red Neuronal
#
# Se implementa una Red Neuronal Profunda (Deep Neural Network - DNN) utilizando la API funcional de Keras.

# %%
class InitialModel(Model):
  def __init__(self, input_shape=(5,), num_classes=4, **kwargs):
    super(InitialModel, self).__init__(**kwargs)
    self.input_shape_val = input_shape
    self.num_classes = num_classes

    # Input layer
    self.input_layer = tf.keras.layers.InputLayer(input_shape=input_shape)
    
    # First hidden layer
    self.dense1 = tf.keras.layers.Dense(512, activation='relu')

    # Second hidden layer
    self.dense2 = tf.keras.layers.Dense(256, activation='relu')

    # Second hidden layer
    self.dense3 = tf.keras.layers.Dense(128, activation='relu')

     # Second hidden layer
    self.dense4 = tf.keras.layers.Dense(128, activation='relu')

    # Third hidden layer
    self.dense5 = tf.keras.layers.Dense(64, activation='relu')
    
    # Output layer
    self.out = tf.keras.layers.Dense(num_classes, activation='softmax')

  def call(self, inputs, training=None):
    
    x = self.dense1(inputs)
    x = self.dense2(x)
    x = self.dense3(x)
    x = self.dense4(x)
    x = self.dense5(x)
    return self.out(x)

def get_config(self):
    config = super(InitialModel, self).get_config()
    config.update({
        "input_shape": self.input_shape_val,
        "num_classes": self.num_classes,
    })
    return config

# Instanciar el modelo
model = InitialModel(input_shape=(5,), num_classes=4)

# %%
# Definición de la función de pérdida y optimizador
loss_object = tf.keras.losses.SparseCategoricalCrossentropy()   # Para clasificación multiclase con etiquetas enteras
optimizer = tf.keras.optimizers.Adam()                          # Optimizador Adam con learning rate adaptativo

# %%
# Definición de métricas para monitorear el entrenamiento
train_loss = tf.keras.metrics.Mean(name='train_loss')                               # Pérdida promedio de entrenamiento
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')  # Exactitud de entrenamiento

test_loss = tf.keras.metrics.Mean(name='test_loss')                                 # Pérdida promedio de validación
test_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='test_accuracy')    # Exactitud de validación

# %%
# Implementación manual de callbacks para control del entrenamiento

best_val_loss = float('inf')   # Mejor pérdida de validación observada
best_weights = None            # Pesos del modelo con mejor rendimiento
patience_lr = 3                # Épocas sin mejora antes de reducir LR
patience_es = 4                # Épocas sin mejora antes de detener entrenamiento
lr_counter = 0                 # Contador para reducción de LR
es_counter = 0                 # Contador para early stopping
lr_factor = 0.2                # Factor de reducción del learning rate (nuevo_lr = lr × 0.2)
min_lr = 0.00001               # Learning rate mínimo permitido

print("Manual callbacks initialized:")
print(f"  LR reduction: patience={patience_lr}, factor={lr_factor}, min_lr={min_lr}")
print(f"  Early stopping: patience={patience_es}, restore_best_weights=True")
# Out:
# Manual callbacks initialized:
#   LR reduction: patience=3, factor=0.2, min_lr=1e-05
#   Early stopping: patience=4, restore_best_weights=True

# %% [markdown]
# # 4. Entrenamiento del Modelo
#
# Esta sección implementa el loop de entrenamiento personalizado con TensorFlow.

# %%
@tf.function
def train_step(data, labels):
  """
  Ejecuta un paso de entrenamiento: forward pass, cálculo de pérdida y backpropagation.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  with tf.GradientTape() as tape:
    predictions = model(data, training=True)  # Forward pass con modo entrenamiento
    loss = loss_object(labels, predictions)   # Cálculo de pérdida
  gradients = tape.gradient(loss, model.trainable_variables)  # Backpropagation
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))  # Actualización de pesos

  train_loss(loss)                     # Actualización de métrica de pérdida
  train_accuracy(labels, predictions)  # Actualización de métrica de exactitud

# %%
@tf.function
def test_step(data, labels):
  """
  Ejecuta evaluación en conjunto de validación/prueba sin actualización de pesos.
  
  Args:
    data: Batch de características de entrada
    labels: Batch de etiquetas verdaderas
  """
  predictions = model(data, training=False)  # Forward pass sin dropout/regularización
  t_loss = loss_object(labels, predictions)  # Cálculo de pérdida

  test_loss(t_loss)                   # Actualización de métrica de pérdida
  test_accuracy(labels, predictions)  # Actualización de métrica de exactitud

# %%
EPOCHS = 100

train_batches = len(X_train_scaled) // BATCH_SIZE + (1 if len(X_train_scaled) % BATCH_SIZE != 0 else 0)
test_batches = len(X_test_scaled) // BATCH_SIZE + (1 if len(X_test_scaled) % BATCH_SIZE != 0 else 0)

print(f"Training for up to {EPOCHS} epochs (with early stopping)")
print(f"Training batches per epoch: {train_batches}")
print(f"Test batches per epoch: {test_batches}")

# Resetear métricasa antes del entrenamiento
train_loss.reset_state()
train_accuracy.reset_state()
test_loss.reset_state()
test_accuracy.reset_state()

for epoch in range(EPOCHS):
  print(f"\nEpoch {epoch+1}/{EPOCHS}")
  
  # Entrenamiento
  for batch_idx, (data, labels) in enumerate(train_ds):
    train_step(data, labels)

  # Prueba
  for test_data, test_labels in test_ds:
    test_step(test_data, test_labels)

  # Obtener métricas actuales
  current_train_loss = train_loss.result().numpy()
  current_train_acc = train_accuracy.result().numpy() * 100
  current_test_loss = test_loss.result().numpy()
  current_test_acc = test_accuracy.result().numpy() * 100
  current_lr = optimizer.learning_rate.numpy()

  # Resultados épocas
  template = 'Epoch {}, Loss: {:.4f}, Accuracy: {:.2f}%, Test Loss: {:.4f}, Test Accuracy: {:.2f}%, LR: {:.6f}'
  print(template.format(epoch+1,
                        current_train_loss,
                        current_train_acc,
                        current_test_loss,
                        current_test_acc,
                        current_lr))

  # Verificar si la pérdida en validación mejora
  if current_test_loss < best_val_loss:
    print(f"  ✓ Validation loss improved from {best_val_loss:.4f} to {current_test_loss:.4f}")
    best_val_loss = current_test_loss
    best_weights = model.get_weights()  # Salvar mejores pesos
    lr_counter = 0  # Resetear contador LR
    es_counter = 0  # Resetear contador early stopping
  else:
    lr_counter += 1
    es_counter += 1
    print(f"  ✗ Validation loss did not improve (best: {best_val_loss:.4f})")
    
     # Reducción del Learning rate
    if lr_counter >= patience_lr:
      old_lr = optimizer.learning_rate.numpy()
      new_lr = max(old_lr * lr_factor, min_lr)
      if new_lr != old_lr:
        optimizer.learning_rate.assign(new_lr)
        print(f"  → Reducing learning rate from {old_lr:.6f} to {new_lr:.6f}")
        lr_counter = 0  # Resetear contador LR
      else:
        print(f"  → Learning rate already at minimum ({min_lr:.6f})")
    
    # Lógica de Early stopping
    if es_counter >= patience_es:
      print(f"\n⚠ Early stopping triggered! No improvement for {patience_es} epochs.")
      print(f"  Restoring best weights from epoch {epoch+1-patience_es}")
      model.set_weights(best_weights)  # Restaurar lo pesos
      break

  # Resetear las métricas para la siguiente época
  train_loss.reset_state()
  train_accuracy.reset_state()
  test_loss.reset_state()
  test_accuracy.reset_state()

print("\nTraining completed!")
print(f"Best validation loss: {best_val_loss:.4f}")
# Out:
# Training for up to 100 epochs (with early stopping)
# Training batches per epoch: 30942
# Test batches per epoch: 7736
#
# Epoch 1/100
# Epoch 1, Loss: 0.7574, Accuracy: 63.90%, Test Loss: 0.6955, Test Accuracy: 66.87%, LR: 0.001000
#   ✓ Validation loss improved from inf to 0.6955
#
# Epoch 2/100
# Epoch 2, Loss: 0.6675, Accuracy: 67.96%, Test Loss: 0.6552, Test Accuracy: 68.55%, LR: 0.001000
#   ✓ Validation loss improved from 0.6955 to 0.6552
#
# Epoch 3/100
# Epoch 3, Loss: 0.6438, Accuracy: 69.01%, Test Loss: 0.6411, Test Accuracy: 69.18%, LR: 0.001000
#   ✓ Validation loss improved from 0.6552 to 0.6411
#
# Epoch 4/100
# Epoch 4, Loss: 0.6298, Accuracy: 69.63%, Test Loss: 0.6310, Test Accuracy: 69.56%, LR: 0.001000
#   ✓ Validation loss improved from 0.6411 to 0.6310
#
# Epoch 5/100
# Epoch 5, Loss: 0.6203, Accuracy: 70.04%, Test Loss: 0.6222, Test Accuracy: 69.97%, LR: 0.001000
#   ✓ Validation loss improved from 0.6310 to 0.6222
#
# Epoch 6/100
# Epoch 6, Loss: 0.6135, Accuracy: 70.34%, Test Loss: 0.6177, Test Accuracy: 70.09%, LR: 0.001000
#   ✓ Validation loss improved from 0.6222 to 0.6177
#
# Epoch 7/100
# Epoch 7, Loss: 0.6084, Accuracy: 70.57%, Test Loss: 0.6104, Test Accuracy: 70.41%, LR: 0.001000
#   ✓ Validation loss improved from 0.6177 to 0.6104
#
# Epoch 8/100
# Epoch 8, Loss: 0.6043, Accuracy: 70.74%, Test Loss: 0.6077, Test Accuracy: 70.65%, LR: 0.001000
#   ✓ Validation loss improved from 0.6104 to 0.6077
#
# Epoch 9/100
# Epoch 9, Loss: 0.6011, Accuracy: 70.88%, Test Loss: 0.6009, Test Accuracy: 70.90%, LR: 0.001000
#   ✓ Validation loss improved from 0.6077 to 0.6009
#
# Epoch 10/100
# Epoch 10, Loss: 0.5984, Accuracy: 71.01%, Test Loss: 0.5965, Test Accuracy: 71.09%, LR: 0.001000
#   ✓ Validation loss improved from 0.6009 to 0.5965
#
# Epoch 11/100
# Epoch 11, Loss: 0.5959, Accuracy: 71.12%, Test Loss: 0.5964, Test Accuracy: 71.04%, LR: 0.001000
#   ✓ Validation loss improved from 0.5965 to 0.5964
#
# Epoch 12/100
# Epoch 12, Loss: 0.5938, Accuracy: 71.21%, Test Loss: 0.5928, Test Accuracy: 71.27%, LR: 0.001000
#   ✓ Validation loss improved from 0.5964 to 0.5928
#
# Epoch 13/100
# Epoch 13, Loss: 0.5919, Accuracy: 71.28%, Test Loss: 0.5948, Test Accuracy: 71.14%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5928)
#
# Epoch 14/100
# Epoch 14, Loss: 0.5903, Accuracy: 71.35%, Test Loss: 0.5893, Test Accuracy: 71.34%, LR: 0.001000
#   ✓ Validation loss improved from 0.5928 to 0.5893
#
# Epoch 15/100
# Epoch 15, Loss: 0.5887, Accuracy: 71.43%, Test Loss: 0.5892, Test Accuracy: 71.37%, LR: 0.001000
#   ✓ Validation loss improved from 0.5893 to 0.5892
#
# Epoch 16/100
# Epoch 16, Loss: 0.5874, Accuracy: 71.48%, Test Loss: 0.5862, Test Accuracy: 71.54%, LR: 0.001000
#   ✓ Validation loss improved from 0.5892 to 0.5862
#
# Epoch 17/100
# Epoch 17, Loss: 0.5860, Accuracy: 71.55%, Test Loss: 0.5867, Test Accuracy: 71.54%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5862)
#
# Epoch 18/100
# Epoch 18, Loss: 0.5847, Accuracy: 71.61%, Test Loss: 0.5855, Test Accuracy: 71.58%, LR: 0.001000
#   ✓ Validation loss improved from 0.5862 to 0.5855
#
# Epoch 19/100
# Epoch 19, Loss: 0.5836, Accuracy: 71.66%, Test Loss: 0.5865, Test Accuracy: 71.53%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5855)
#
# Epoch 20/100
# Epoch 20, Loss: 0.5827, Accuracy: 71.69%, Test Loss: 0.5836, Test Accuracy: 71.61%, LR: 0.001000
#   ✓ Validation loss improved from 0.5855 to 0.5836
#
# Epoch 21/100
# Epoch 21, Loss: 0.5816, Accuracy: 71.73%, Test Loss: 0.5884, Test Accuracy: 71.28%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5836)
#
# Epoch 22/100
# Epoch 22, Loss: 0.5808, Accuracy: 71.77%, Test Loss: 0.5794, Test Accuracy: 71.83%, LR: 0.001000
#   ✓ Validation loss improved from 0.5836 to 0.5794
#
# Epoch 23/100
# Epoch 23, Loss: 0.5800, Accuracy: 71.81%, Test Loss: 0.5843, Test Accuracy: 71.61%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5794)
#
# Epoch 24/100
# Epoch 24, Loss: 0.5792, Accuracy: 71.85%, Test Loss: 0.5763, Test Accuracy: 71.96%, LR: 0.001000
#   ✓ Validation loss improved from 0.5794 to 0.5763
#
# Epoch 25/100
# Epoch 25, Loss: 0.5784, Accuracy: 71.88%, Test Loss: 0.5797, Test Accuracy: 71.82%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5763)
#
# Epoch 26/100
# Epoch 26, Loss: 0.5777, Accuracy: 71.90%, Test Loss: 0.5780, Test Accuracy: 71.89%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5763)
#
# Epoch 27/100
# Epoch 27, Loss: 0.5770, Accuracy: 71.93%, Test Loss: 0.5772, Test Accuracy: 71.91%, LR: 0.001000
#   ✗ Validation loss did not improve (best: 0.5763)
#   → Reducing learning rate from 0.001000 to 0.000200
#
# Epoch 28/100
# Epoch 28, Loss: 0.5428, Accuracy: 73.52%, Test Loss: 0.5430, Test Accuracy: 73.47%, LR: 0.000200
#   ✓ Validation loss improved from 0.5763 to 0.5430
#
# Epoch 29/100
# Epoch 29, Loss: 0.5404, Accuracy: 73.61%, Test Loss: 0.5421, Test Accuracy: 73.51%, LR: 0.000200
#   ✓ Validation loss improved from 0.5430 to 0.5421
#
# Epoch 30/100
# Epoch 30, Loss: 0.5393, Accuracy: 73.65%, Test Loss: 0.5418, Test Accuracy: 73.51%, LR: 0.000200
#   ✓ Validation loss improved from 0.5421 to 0.5418
#
# Epoch 31/100
# Epoch 31, Loss: 0.5385, Accuracy: 73.69%, Test Loss: 0.5412, Test Accuracy: 73.51%, LR: 0.000200
#   ✓ Validation loss improved from 0.5418 to 0.5412
#
# Epoch 32/100
# Epoch 32, Loss: 0.5379, Accuracy: 73.71%, Test Loss: 0.5401, Test Accuracy: 73.58%, LR: 0.000200
#   ✓ Validation loss improved from 0.5412 to 0.5401
#
# Epoch 33/100
# Epoch 33, Loss: 0.5374, Accuracy: 73.74%, Test Loss: 0.5397, Test Accuracy: 73.59%, LR: 0.000200
#   ✓ Validation loss improved from 0.5401 to 0.5397
#
# Epoch 34/100
# Epoch 34, Loss: 0.5369, Accuracy: 73.76%, Test Loss: 0.5394, Test Accuracy: 73.59%, LR: 0.000200
#   ✓ Validation loss improved from 0.5397 to 0.5394
#
# Epoch 35/100
# Epoch 35, Loss: 0.5365, Accuracy: 73.77%, Test Loss: 0.5385, Test Accuracy: 73.64%, LR: 0.000200
#   ✓ Validation loss improved from 0.5394 to 0.5385
#
# Epoch 36/100
# Epoch 36, Loss: 0.5361, Accuracy: 73.79%, Test Loss: 0.5385, Test Accuracy: 73.62%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5385)
#
# Epoch 37/100
# Epoch 37, Loss: 0.5357, Accuracy: 73.80%, Test Loss: 0.5383, Test Accuracy: 73.64%, LR: 0.000200
#   ✓ Validation loss improved from 0.5385 to 0.5383
#
# Epoch 38/100
# Epoch 38, Loss: 0.5354, Accuracy: 73.82%, Test Loss: 0.5378, Test Accuracy: 73.68%, LR: 0.000200
#   ✓ Validation loss improved from 0.5383 to 0.5378
#
# Epoch 39/100
# Epoch 39, Loss: 0.5351, Accuracy: 73.83%, Test Loss: 0.5372, Test Accuracy: 73.70%, LR: 0.000200
#   ✓ Validation loss improved from 0.5378 to 0.5372
#
# Epoch 40/100
# Epoch 40, Loss: 0.5348, Accuracy: 73.84%, Test Loss: 0.5368, Test Accuracy: 73.73%, LR: 0.000200
#   ✓ Validation loss improved from 0.5372 to 0.5368
#
# Epoch 41/100
# Epoch 41, Loss: 0.5345, Accuracy: 73.86%, Test Loss: 0.5372, Test Accuracy: 73.70%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5368)
#
# Epoch 42/100
# Epoch 42, Loss: 0.5343, Accuracy: 73.87%, Test Loss: 0.5371, Test Accuracy: 73.69%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5368)
#
# Epoch 43/100
# Epoch 43, Loss: 0.5341, Accuracy: 73.87%, Test Loss: 0.5367, Test Accuracy: 73.71%, LR: 0.000200
#   ✓ Validation loss improved from 0.5368 to 0.5367
#
# Epoch 44/100
# Epoch 44, Loss: 0.5338, Accuracy: 73.89%, Test Loss: 0.5369, Test Accuracy: 73.70%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5367)
#
# Epoch 45/100
# Epoch 45, Loss: 0.5336, Accuracy: 73.90%, Test Loss: 0.5361, Test Accuracy: 73.73%, LR: 0.000200
#   ✓ Validation loss improved from 0.5367 to 0.5361
#
# Epoch 46/100
# Epoch 46, Loss: 0.5334, Accuracy: 73.91%, Test Loss: 0.5361, Test Accuracy: 73.73%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5361)
#
# Epoch 47/100
# Epoch 47, Loss: 0.5332, Accuracy: 73.92%, Test Loss: 0.5358, Test Accuracy: 73.75%, LR: 0.000200
#   ✓ Validation loss improved from 0.5361 to 0.5358
#
# Epoch 48/100
# Epoch 48, Loss: 0.5330, Accuracy: 73.92%, Test Loss: 0.5358, Test Accuracy: 73.74%, LR: 0.000200
#   ✓ Validation loss improved from 0.5358 to 0.5358
#
# Epoch 49/100
# Epoch 49, Loss: 0.5328, Accuracy: 73.94%, Test Loss: 0.5369, Test Accuracy: 73.66%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5358)
#
# Epoch 50/100
# Epoch 50, Loss: 0.5326, Accuracy: 73.94%, Test Loss: 0.5358, Test Accuracy: 73.73%, LR: 0.000200
#   ✓ Validation loss improved from 0.5358 to 0.5358
#
# Epoch 51/100
# Epoch 51, Loss: 0.5324, Accuracy: 73.94%, Test Loss: 0.5354, Test Accuracy: 73.77%, LR: 0.000200
#   ✓ Validation loss improved from 0.5358 to 0.5354
#
# Epoch 52/100
# Epoch 52, Loss: 0.5322, Accuracy: 73.96%, Test Loss: 0.5348, Test Accuracy: 73.80%, LR: 0.000200
#   ✓ Validation loss improved from 0.5354 to 0.5348
#
# Epoch 53/100
# Epoch 53, Loss: 0.5320, Accuracy: 73.96%, Test Loss: 0.5351, Test Accuracy: 73.78%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5348)
#
# Epoch 54/100
# Epoch 54, Loss: 0.5319, Accuracy: 73.97%, Test Loss: 0.5356, Test Accuracy: 73.74%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5348)
#
# Epoch 55/100
# Epoch 55, Loss: 0.5317, Accuracy: 73.98%, Test Loss: 0.5342, Test Accuracy: 73.82%, LR: 0.000200
#   ✓ Validation loss improved from 0.5348 to 0.5342
#
# Epoch 56/100
# Epoch 56, Loss: 0.5316, Accuracy: 73.98%, Test Loss: 0.5342, Test Accuracy: 73.82%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5342)
#
# Epoch 57/100
# Epoch 57, Loss: 0.5314, Accuracy: 73.99%, Test Loss: 0.5362, Test Accuracy: 73.68%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5342)
#
# Epoch 58/100
# Epoch 58, Loss: 0.5313, Accuracy: 74.00%, Test Loss: 0.5347, Test Accuracy: 73.77%, LR: 0.000200
#   ✗ Validation loss did not improve (best: 0.5342)
#   → Reducing learning rate from 0.000200 to 0.000040
#
# Epoch 59/100
# Epoch 59, Loss: 0.5230, Accuracy: 74.42%, Test Loss: 0.5260, Test Accuracy: 74.23%, LR: 0.000040
#   ✓ Validation loss improved from 0.5342 to 0.5260
#
# Epoch 60/100
# Epoch 60, Loss: 0.5225, Accuracy: 74.43%, Test Loss: 0.5258, Test Accuracy: 74.24%, LR: 0.000040
#   ✓ Validation loss improved from 0.5260 to 0.5258
#
# Epoch 61/100
# Epoch 61, Loss: 0.5224, Accuracy: 74.43%, Test Loss: 0.5257, Test Accuracy: 74.24%, LR: 0.000040
#   ✓ Validation loss improved from 0.5258 to 0.5257
#
# Epoch 62/100
# Epoch 62, Loss: 0.5223, Accuracy: 74.44%, Test Loss: 0.5255, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5257 to 0.5255
#
# Epoch 63/100
# Epoch 63, Loss: 0.5222, Accuracy: 74.44%, Test Loss: 0.5255, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5255 to 0.5255
#
# Epoch 64/100
# Epoch 64, Loss: 0.5221, Accuracy: 74.44%, Test Loss: 0.5255, Test Accuracy: 74.24%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5255)
#
# Epoch 65/100
# Epoch 65, Loss: 0.5221, Accuracy: 74.45%, Test Loss: 0.5254, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5255 to 0.5254
#
# Epoch 66/100
# Epoch 66, Loss: 0.5220, Accuracy: 74.45%, Test Loss: 0.5254, Test Accuracy: 74.24%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5254)
#
# Epoch 67/100
# Epoch 67, Loss: 0.5219, Accuracy: 74.45%, Test Loss: 0.5254, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5254 to 0.5254
#
# Epoch 68/100
# Epoch 68, Loss: 0.5219, Accuracy: 74.45%, Test Loss: 0.5253, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5254 to 0.5253
#
# Epoch 69/100
# Epoch 69, Loss: 0.5218, Accuracy: 74.46%, Test Loss: 0.5253, Test Accuracy: 74.25%, LR: 0.000040
#   ✓ Validation loss improved from 0.5253 to 0.5253
#
# Epoch 70/100
# Epoch 70, Loss: 0.5217, Accuracy: 74.46%, Test Loss: 0.5252, Test Accuracy: 74.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.5253 to 0.5252
#
# Epoch 71/100
# Epoch 71, Loss: 0.5217, Accuracy: 74.46%, Test Loss: 0.5253, Test Accuracy: 74.24%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5252)
#
# Epoch 72/100
# Epoch 72, Loss: 0.5216, Accuracy: 74.46%, Test Loss: 0.5251, Test Accuracy: 74.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.5252 to 0.5251
#
# Epoch 73/100
# Epoch 73, Loss: 0.5216, Accuracy: 74.46%, Test Loss: 0.5251, Test Accuracy: 74.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.5251 to 0.5251
#
# Epoch 74/100
# Epoch 74, Loss: 0.5215, Accuracy: 74.47%, Test Loss: 0.5251, Test Accuracy: 74.26%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5251)
#
# Epoch 75/100
# Epoch 75, Loss: 0.5215, Accuracy: 74.47%, Test Loss: 0.5250, Test Accuracy: 74.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.5251 to 0.5250
#
# Epoch 76/100
# Epoch 76, Loss: 0.5214, Accuracy: 74.47%, Test Loss: 0.5249, Test Accuracy: 74.26%, LR: 0.000040
#   ✓ Validation loss improved from 0.5250 to 0.5249
#
# Epoch 77/100
# Epoch 77, Loss: 0.5214, Accuracy: 74.47%, Test Loss: 0.5248, Test Accuracy: 74.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.5249 to 0.5248
#
# Epoch 78/100
# Epoch 78, Loss: 0.5213, Accuracy: 74.48%, Test Loss: 0.5248, Test Accuracy: 74.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.5248 to 0.5248
#
# Epoch 79/100
# Epoch 79, Loss: 0.5213, Accuracy: 74.48%, Test Loss: 0.5248, Test Accuracy: 74.27%, LR: 0.000040
#   ✓ Validation loss improved from 0.5248 to 0.5248
#
# Epoch 80/100
# Epoch 80, Loss: 0.5212, Accuracy: 74.48%, Test Loss: 0.5248, Test Accuracy: 74.27%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5248)
#
# Epoch 81/100
# Epoch 81, Loss: 0.5212, Accuracy: 74.48%, Test Loss: 0.5246, Test Accuracy: 74.28%, LR: 0.000040
#   ✓ Validation loss improved from 0.5248 to 0.5246
#
# Epoch 82/100
# Epoch 82, Loss: 0.5211, Accuracy: 74.48%, Test Loss: 0.5248, Test Accuracy: 74.26%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5246)
#
# Epoch 83/100
# Epoch 83, Loss: 0.5211, Accuracy: 74.48%, Test Loss: 0.5247, Test Accuracy: 74.26%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5246)
#
# Epoch 84/100
# Epoch 84, Loss: 0.5210, Accuracy: 74.49%, Test Loss: 0.5247, Test Accuracy: 74.27%, LR: 0.000040
#   ✗ Validation loss did not improve (best: 0.5246)
#   → Reducing learning rate from 0.000040 to 0.000010
#
# Epoch 85/100
# Epoch 85, Loss: 0.5194, Accuracy: 74.57%, Test Loss: 0.5230, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5246 to 0.5230
#
# Epoch 86/100
# Epoch 86, Loss: 0.5193, Accuracy: 74.58%, Test Loss: 0.5230, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5230 to 0.5230
#
# Epoch 87/100
# Epoch 87, Loss: 0.5193, Accuracy: 74.58%, Test Loss: 0.5230, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5230 to 0.5230
#
# Epoch 88/100
# Epoch 88, Loss: 0.5193, Accuracy: 74.58%, Test Loss: 0.5230, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5230 to 0.5230
#
# Epoch 89/100
# Epoch 89, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5230 to 0.5229
#
# Epoch 90/100
# Epoch 90, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 0.5229)
#
# Epoch 91/100
# Epoch 91, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✗ Validation loss did not improve (best: 0.5229)
#
# Epoch 92/100
# Epoch 92, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 93/100
# Epoch 93, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 94/100
# Epoch 94, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 95/100
# Epoch 95, Loss: 0.5192, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.36%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 96/100
# Epoch 96, Loss: 0.5191, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.37%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 97/100
# Epoch 97, Loss: 0.5191, Accuracy: 74.58%, Test Loss: 0.5229, Test Accuracy: 74.37%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5229
#
# Epoch 98/100
# Epoch 98, Loss: 0.5191, Accuracy: 74.58%, Test Loss: 0.5228, Test Accuracy: 74.37%, LR: 0.000010
#   ✓ Validation loss improved from 0.5229 to 0.5228
#
# Epoch 99/100
# Epoch 99, Loss: 0.5191, Accuracy: 74.58%, Test Loss: 0.5228, Test Accuracy: 74.37%, LR: 0.000010
#   ✓ Validation loss improved from 0.5228 to 0.5228
#
# Epoch 100/100
# Epoch 100, Loss: 0.5191, Accuracy: 74.58%, Test Loss: 0.5228, Test Accuracy: 74.37%, LR: 0.000010
#   ✓ Validation loss improved from 0.5228 to 0.5228
#
# Training completed!
# Best validation loss: 0.5228

# %% [markdown]
# ## 4.1 Guardar modelo

# %%
# Guardar el modelo entrenado en formato Keras nativo
model.save("models/maiz_model.keras")
print("Model saved successfully as 'frijol_model.keras'")

# Guardar objetos de preprocesamiento (scaler, encoder) para uso en producción
with open('preprocessing_objects_maiz.pkl', 'wb') as f:
    pickle.dump({
        'scaler': scaler,                   # Estandarizador ajustado
        'label_encoder': label_encoder,     # Codificador de etiquetas
        'feature_columns': feature_columns  # Lista de características esperadas
    }, f)

print("Preprocessing objects saved as 'preprocessing_objects.pkl'")
# Out:
# Model saved successfully as 'frijol_model.keras'
# Preprocessing objects saved as 'preprocessing_objects.pkl'

# %% [markdown]
# # 5. Evaluación del Modelo
#
# Esta sección carga el modelo entrenado y evalúa su rendimiento mediante:
# - **Generación de predicciones**: En conjuntos de entrenamiento y prueba
# - **Métricas de clasificación**: Accuracy, Precision, F1-Score, Kappa
# - **Matrices de confusión**: Visualización de aciertos y errores por clase
# - **Análisis de curvas de aprendizaje**: Evolución de pérdida y exactitud durante entrenamiento

# %%
# Carga del modelo entrenado desde archivo
trained_model = tf.keras.models.load_model('models/maiz/maiz_model_dnn.keras', custom_objects={'InitialModel': InitialModel})
# Out:
# WARNING:tensorflow:From c:\Users\USUARIO\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
# Generación de predicciones en el conjunto de prueba
print("Realizando predicciones en Test...")
y_pred_probs = trained_model.predict(X_test_scaled)  # Probabilidades para cada clase
y_pred = np.argmax(y_pred_probs, axis=1)

# Realizar predicciones en el conjunto de entrenamiento
print("Realizando predicciones en Train...")
y_train_pred_probs = trained_model.predict(X_train_scaled)
y_train_pred = np.argmax(y_train_pred_probs, axis=1)
# Out:
# Realizando predicciones en Test...
# 241729/241729 ━━━━━━━━━━━━━━━━━━━━ 340s 1ms/step
# Realizando predicciones en Train...
# 966916/966916 ━━━━━━━━━━━━━━━━━━━━ 2011s 2ms/step

# %% [markdown]
# ## 5.1. Guardar predicciones

# %%
# Guardar predicciones del conjunto de prueba
joblib.dump(y_pred, "results/predictions/maiz/test/predicciones_dnn_test.pkl")
print("✓ Predicciones de prueba guardadas en: results/predictions/maiz/test/predicciones_dnn_test.pkl")

# Guardar predicciones del conjunto de entrenamiento
joblib.dump(y_train_pred, "results/predictions/maiz/train/predicciones_dnn_train.pkl")
print("✓ Predicciones de entrenamiento guardadas en: results/predictions/maiz/train/predicciones_dnn_train.pkl")

# Guardar probabilidades predichas
joblib.dump(y_pred_probs, "results/predictions/maiz/test/predicciones_dnn_test_probs.pkl")
joblib.dump(y_train_pred_probs, "results/predictions/maiz/train/predicciones_dnn_train_probs.pkl")
print("✓ Probabilidades de predicción guardadas exitosamente")
# Out:
# ✓ Predicciones de prueba guardadas en: results/predictions/maiz/test/predicciones_dnn_test.pkl
# ✓ Predicciones de entrenamiento guardadas en: results/predictions/maiz/train/predicciones_dnn_train.pkl
# ✓ Probabilidades de predicción guardadas exitosamente

# %% [markdown]
# # 6. Resultados

# %%
# Cálculo de métricas para el conjunto de prueba (Test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
kappa = cohen_kappa_score(y_test, y_pred)

# Cálculo de métricas para el conjunto de entrenamiento (Train)
train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred, average='weighted')
train_f1 = f1_score(y_train, y_train_pred, average='weighted')
train_kappa = cohen_kappa_score(y_train, y_train_pred)

# Presentación comparativa de métricas
print("-" * 65)
print(f"{'Métrica':<20} | {'Train':<20} | {'Test':<20}")
print("-" * 65)
print(f"{'Accuracy':<20} | {train_accuracy:<20.4f} | {accuracy:<20.4f}")
print(f"{'Precision':<20} | {train_precision:<20.4f} | {precision:<20.4f}")
print(f"{'F1-Score':<20} | {train_f1:<20.4f} | {f1:<20.4f}")
print(f"{'Kappa Score':<20} | {train_kappa:<20.4f} | {kappa:<20.4f}")
print("-" * 65)
# Out:
# -----------------------------------------------------------------
# Métrica              | Train                | Test
# -----------------------------------------------------------------
# Accuracy             | 0.7459               | 0.7437
# Precision            | 0.7459               | 0.7437
# F1-Score             | 0.7458               | 0.7436
# Kappa Score          | 0.6539               | 0.6509
# -----------------------------------------------------------------

# %%
# Obtención de nombres de clases para los reportes
target_names = label_encoder.classes_.astype(str)

# Reporte de clasificación para conjunto de prueba
print("\nReporte de Clasificación (Test):")
print(classification_report(y_test, y_pred, target_names=target_names))

# Reporte de clasificación para conjunto de entrenamiento
print("\nReporte de Clasificación (Train):")
print(classification_report(y_train, y_train_pred, target_names=target_names))
# Out:
# Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#            1       0.73      0.75      0.74   2446434
#            2       0.76      0.76      0.76   2356932
#            3       0.74      0.73      0.73   1381938
#            4       0.75      0.73      0.74   1550024
#
#     accuracy                           0.74   7735328
#    macro avg       0.74      0.74      0.74   7735328
# weighted avg       0.74      0.74      0.74   7735328
#
#
# Reporte de Clasificación (Train):
#               precision    recall  f1-score   support
#
#            1       0.74      0.75      0.74   9785736
#            2       0.76      0.76      0.76   9427728
#            3       0.74      0.73      0.74   5527752
#            4       0.75      0.73      0.74   6200096
#
#     accuracy                           0.75  30941312
#    macro avg       0.75      0.74      0.74  30941312
# weighted avg       0.75      0.75      0.75  30941312

# %%
# Visualización comparativa de matrices de confusión
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
tratamiento_labels = ['T1', 'T2', 'T3', 'T4']

# Matriz de confusión para conjunto de entrenamiento
cm_train = confusion_matrix(y_train, y_train_pred)
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=tratamiento_labels)
disp_train.plot(ax=axes[0], cmap='Blues', colorbar=False)
axes[0].set_title('Matriz de Confusión DNN - Entrenamiento', fontsize=14)
axes[0].set_xlabel('Etiqueta predicha', fontsize=12)
axes[0].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[0].grid(False)

# Matriz de confusión para conjunto de prueba
cm_test = confusion_matrix(y_test, y_pred)
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=tratamiento_labels)
disp_test.plot(ax=axes[1], cmap='Blues', colorbar=False)
axes[1].set_title('Matriz de Confusión DNN - Testing', fontsize=14)
axes[1].set_xlabel('Etiqueta predicha', fontsize=12)
axes[1].set_ylabel('Etiqueta verdadera', fontsize=12)
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
# Carga del historial de entrenamiento desde archivo CSV
history_data = pd.read_csv("results/training_history_maiz.csv")

# Extracción de épocas para el eje X
epochs = history_data['epoch']

# Creación de visualización de métricas de entrenamiento
plt.figure(figsize=(15, 6))

# Gráfico de evolución de la pérdida (Loss)
plt.subplot(1, 2, 1)
plt.plot(epochs, history_data['loss'], label='Pérdida entrenamiento', linewidth=2, color='#1f77b4')
plt.plot(epochs, history_data['val_loss'], label='Pérdida validación', linewidth=2, color='#ff7f0e')
plt.title('Pérdidas en entrenamiento y validación', fontsize=14, pad=15)
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.grid(True, alpha=0.3)

# Gráfico de evolución de la exactitud (Accuracy)
plt.subplot(1, 2, 2)
plt.plot(epochs, history_data['accuracy'], label='Accuracy entrenamiento', linewidth=2, color='#1f77b4')
plt.plot(epochs, history_data['val_accuracy'], label='Accuracy validación', linewidth=2, color='#ff7f0e')
plt.title('Accuracy de entrenamiento y validación', fontsize=14, pad=15)
plt.xlabel('Épocas')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
